# %%
# K-CV法を用いた心疾患予測モデルの学習と評価,マスクなしでの学習，BMIなし
import pandas as pd
import torch
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from torch.utils.data import Dataset, DataLoader
from tab_transformer_pytorch import TabTransformer
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import (
    accuracy_score, f1_score, precision_score,
    recall_score, roc_auc_score, roc_curve,
    confusion_matrix
)
import numpy as np
import sys
import matplotlib.pyplot as plt

# --------------------------------------------
# 定数設定
# --------------------------------------------
EPOCHS = 300
THRESHOLD = 0.73
BATCH_SIZE = 256
K_FOLDS = 5

# --------------------------------------------
# 0. デバイス設定
# --------------------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# --------------------------------------------
# 1. データ読み込み & 前処理
# --------------------------------------------

# データ読み込み
data = pd.read_csv("cardio_train.csv", sep=';')

# age_years のみ算出（BMI 削除）
data['age_years'] = (data['age'] / 365).astype(int)

# カテゴリ・連続量特徴量の定義
categorical_cols = ['gender', 'cholesterol', 'gluc', 'smoke', 'alco', 'active']
continuous_cols  = ['age_years', 'height', 'weight', 'ap_hi', 'ap_lo']
target_col = 'cardio'

# ラベルエンコーディング
from sklearn.preprocessing import LabelEncoder, StandardScaler
for col in categorical_cols:
    data[col] = LabelEncoder().fit_transform(data[col])

# 標準化
scaler = StandardScaler()
data[continuous_cols] = scaler.fit_transform(data[continuous_cols])


# --------------------------------------------
# 2. Dataset クラス定義
# --------------------------------------------
class CardioDataset(Dataset):
    def __init__(self, df):
        self.categ  = df[categorical_cols].values.astype(np.int64)
        self.cont   = df[continuous_cols].values.astype(np.float32)
        self.labels = df[target_col].values.astype(np.float32)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return (
            torch.tensor(self.categ[idx], dtype=torch.int64),
            torch.tensor(self.cont[idx],  dtype=torch.float32),
            torch.tensor(self.labels[idx], dtype=torch.float32),
        )

# --------------------------------------------
# 3. データ分割 (Train+Val / Test = 80/20)
# --------------------------------------------
train_val_data, test_data = train_test_split(data, test_size=0.2, random_state=42)
test_loader = DataLoader(CardioDataset(test_data), batch_size=BATCH_SIZE, shuffle=False)

# --------------------------------------------
# 4. 学習・検証ループ用関数定義
# --------------------------------------------
def train_with_validation(model, train_loader, val_loader, epochs, threshold):
    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    loss_history, train_acc_history, val_acc_history = [], [], []

    for epoch in range(1, epochs + 1):
        model.train()
        total_loss, correct, total = 0.0, 0, 0
        print(f"\nEpoch {epoch}/{epochs}")
        for batch_idx, (x_cat, x_cont, y) in enumerate(train_loader, 1):
            x_cat, x_cont, y = x_cat.to(device), x_cont.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(x_cat, x_cont).squeeze(1)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            prob = torch.sigmoid(out)
            pred = (prob > 0.5).int()
            correct += (pred == y.int()).sum().item()
            total += y.size(0)
            # 進捗バー
            progress = batch_idx / len(train_loader) * 100
            bar_len = 30
            filled = int(bar_len * progress / 100)
            bar = '█' * filled + '-' * (bar_len - filled)
            sys.stdout.write(f"\r [{bar}] {progress:5.1f}%")
            sys.stdout.flush()

        loss_history.append(total_loss)
        train_acc_history.append(correct / total)
        print(f"\nTrain Loss: {total_loss:.4f} | Train Acc: {train_acc_history[-1]:.4f}")

        # 検証
        model.eval()
        val_preds, val_trues = [], []
        with torch.no_grad():
            for x_cat_v, x_cont_v, y_v in val_loader:
                x_cat_v, x_cont_v, y_v = x_cat_v.to(device), x_cont_v.to(device), y_v.to(device)
                out_v = model(x_cat_v, x_cont_v).squeeze(1)
                prob_v = torch.sigmoid(out_v)
                pred_v = (prob_v > 0.5).int()
                val_preds.extend(pred_v.cpu().tolist())
                val_trues.extend(y_v.cpu().int().tolist())

        val_acc = accuracy_score(val_trues, val_preds)
        val_acc_history.append(val_acc)
        print(f"Validation Acc: {val_acc:.4f}")

        if val_acc >= threshold:
            print(f"Threshold {threshold:.4f} reached at epoch {epoch}. Stopping training.")
            break

    return loss_history, train_acc_history, val_acc_history


# --------------------------------------------
# 5. テストデータ評価用関数定義
# --------------------------------------------
def evaluate_model(model, loader):
    model.eval()
    preds, trues, probs = [], [], []
    with torch.no_grad():
        for x_cat, x_cont, y in loader:
            x_cat, x_cont, y = x_cat.to(device), x_cont.to(device), y.to(device)
            out = model(x_cat, x_cont).squeeze(1)
            prob = torch.sigmoid(out)
            preds.extend((prob > 0.5).int().cpu().tolist())
            trues.extend(y.int().cpu().tolist())
            probs.extend(prob.cpu().tolist())

    print("\nTest Metrics:")
    print(f"Accuracy : {accuracy_score(trues, preds):.4f}")
    print(f"F1 Score : {f1_score(trues, preds):.4f}")
    print(f"Precision: {precision_score(trues, preds):.4f}")
    print(f"Recall   : {recall_score(trues, preds):.4f}")
    print(f"AUC      : {roc_auc_score(trues, probs):.4f}")


# --------------------------------------------
# 6. まとめて4つのグラフを描画＆保存する関数定義
# --------------------------------------------
# --------------------------------------------
# 8. K-Fold Cross Validation
# --------------------------------------------
kf = KFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
fold_scores = []
for fold, (train_idx, val_idx) in enumerate(kf.split(train_val_data), 1):
    print(f"\n=== Fold {fold}/{K_FOLDS} ===")
    train_df = train_val_data.iloc[train_idx].reset_index(drop=True)
    val_df   = train_val_data.iloc[val_idx].reset_index(drop=True)

    train_loader = DataLoader(CardioDataset(train_df), batch_size=BATCH_SIZE, shuffle=True)
    val_loader   = DataLoader(CardioDataset(val_df),   batch_size=BATCH_SIZE, shuffle=False)

    # モデル初期化
    cont_mean_std = torch.tensor([[0., 1.]] * len(continuous_cols)).to(device)
    model = TabTransformer(
        categories=tuple(data[col].nunique() for col in categorical_cols),
        num_continuous=len(continuous_cols),
        dim=32, dim_out=1, depth=4, heads=4,
        attn_dropout=0.1, ff_dropout=0.1,
        mlp_hidden_mults=(4, 2), mlp_act=nn.ReLU(),
        continuous_mean_std=cont_mean_std
    ).to(device)
    model.categories_offset = model.categories_offset.to(device)

    _, _, val_accs = train_with_validation(
        model,
        DataLoader(CardioDataset(train_df), batch_size=BATCH_SIZE, shuffle=True),
        DataLoader(CardioDataset(val_df),   batch_size=BATCH_SIZE, shuffle=False),
        EPOCHS, THRESHOLD
    )
    fold_scores.append(val_accs[-1])

mean_acc = np.mean(fold_scores)
std_acc  = np.std(fold_scores)
print(f"\nK-Fold CV Result (K={K_FOLDS}): Mean Val Acc = {mean_acc:.4f}, Std = {std_acc:.4f}")


# --------------------------------------------
# 9. 全訓練データでの最終学習 → 履歴取得
# --------------------------------------------
final_train_df, final_val_df = train_test_split(train_val_data, test_size=0.2, random_state=42)
final_train_loader = DataLoader(CardioDataset(final_train_df), batch_size=BATCH_SIZE, shuffle=True)
final_val_loader   = DataLoader(CardioDataset(final_val_df),   batch_size=BATCH_SIZE, shuffle=False)

cont_mean_std = torch.tensor([[0., 1.]] * len(continuous_cols)).to(device)
final_model = TabTransformer(
    categories=tuple(data[col].nunique() for col in categorical_cols),
    num_continuous=len(continuous_cols),
    dim=32, dim_out=1, depth=4, heads=4,
    attn_dropout=0.1, ff_dropout=0.1,
    mlp_hidden_mults=(4, 2), mlp_act=nn.ReLU(),
    continuous_mean_std=cont_mean_std
).to(device)
final_model.categories_offset = final_model.categories_offset.to(device)

# 学習＆履歴取得
loss_history, train_acc_history, val_acc_history = train_with_validation(
    final_model, final_train_loader, final_val_loader, EPOCHS, THRESHOLD
)
# --------------------------------------------
# 7. 学習曲線プロット
# --------------------------------------------
def plot_all_metrics(losses, train_accs, val_accs, model, loader):
    # 1) データ収集
    preds, trues, probs = [], [], []
    model.eval()
    with torch.no_grad():
        for x_cat, x_cont, y in loader:
            x_cat, x_cont, y = x_cat.to(device), x_cont.to(device), y.to(device)
            out = model(x_cat, x_cont).squeeze(1)
            p = torch.sigmoid(out)
            preds.extend((p > 0.5).int().cpu().tolist())
            trues.extend(y.int().cpu().tolist())
            probs.extend(p.cpu().tolist())

    # 指標計算
    cm    = confusion_matrix(trues, preds)
    fpr, tpr, _ = roc_curve(trues, probs)
    auc   = roc_auc_score(trues, probs)
    acc   = accuracy_score(trues, preds)
    f1    = f1_score(trues, preds)
    prec  = precision_score(trues, preds)
    rec   = recall_score(trues, preds)

    epochs = range(1, len(losses) + 1)

    # 2x2 レイアウト作成
    fig, axes = plt.subplots(2, 2, figsize=(12, 10))

    # (0,0) Training Loss
    ax00 = axes[0,0]
    ax00.plot(epochs, losses, marker='o')
    ax00.set_title('Training Loss')
    ax00.set_xlabel('Epoch'); ax00.set_ylabel('Loss')
    ax00.grid(True)

    # (0,1) Accuracy 曲線
    ax01 = axes[0,1]
    ax01.plot(epochs, train_accs, marker='o', label='Train Acc')
    ax01.plot(epochs, val_accs,   marker='x', label='Val Acc')
    ax01.set_title('Accuracy')
    ax01.set_xlabel('Epoch'); ax01.set_ylabel('Accuracy')
    ax01.legend(); ax01.grid(True)

    # (1,0) Confusion Matrix
    ax10 = axes[1,0]
    im = ax10.imshow(cm, cmap='Blues')
    classes = ['No Cardio','Cardio']
    ax10.set_xticks(np.arange(len(classes))); ax10.set_xticklabels(classes)
    ax10.set_yticks(np.arange(len(classes))); ax10.set_yticklabels(classes)
    ax10.set_title('Confusion Matrix'); ax10.set_xlabel('Predicted'); ax10.set_ylabel('True')
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            color = 'white' if cm[i,j] > cm.max()/2 else 'black'
            ax10.text(j, i, cm[i,j], ha='center', va='center', color=color)
    fig.colorbar(im, ax=ax10)

    # (1,1) ROC + 指標テキスト
    ax11 = axes[1,1]
    ax11.plot(fpr, tpr, label=f'AUC = {auc:.3f}')
    ax11.plot([0,1],[0,1],'k--')
    ax11.set_title('ROC Curve'); ax11.set_xlabel('FPR'); ax11.set_ylabel('TPR')
    ax11.legend(loc='lower right')

    # テキストボックス
    metrics_text = (
        f"Acc : {acc:.3f}\n"
        f"F1  : {f1:.3f}\n"
        f"Prec: {prec:.3f}\n"
        f"Rec : {rec:.3f}"
    )
    ax11.text(
        0.05, 0.05, metrics_text,
        transform=ax11.transAxes,
        fontsize=10,
        verticalalignment='bottom',
        bbox=dict(facecolor='white', alpha=0.6, edgecolor='gray')
    )

    plt.tight_layout()

    # 保存
    Epoch_str = str(EPOCHS)
    fname = f"output2/Nomask Epoch:{Epoch_str}_all.png"
    fig.savefig(fname, dpi=300)

    plt.show()

# --------------------------------------------
# 9. テストデータで最終評価 + まとめて４プロット
# --------------------------------------------
print("\n=== Final Evaluation on Test Data ===")
evaluate_model(final_model, test_loader)

# ここで一発描画＆保存
plot_all_metrics(
    loss_history,
    train_acc_history,
    val_acc_history,
    final_model,
    test_loader
)
# Out:
# Using device: cuda
#
# === Fold 1/5 ===
#
# Epoch 1/300
#  [██████████████████████████████] 100.0%
# Train Loss: 117.1504 | Train Acc: 0.6001
# Validation Acc: 0.6216
#
# Epoch 2/300
#  [██████████████████████████████] 100.0%
# Train Loss: 113.1401 | Train Acc: 0.6237
# Validation Acc: 0.6318
#
# Epoch 3/300
#  [██████████████████████████████] 100.0%
# Train Loss: 112.7519 | Train Acc: 0.6267
# Validation Acc: 0.6224
#
# Epoch 4/300
#  [██████████████████████████████] 100.0%
# Train Loss: 112.7870 | Train Acc: 0.6261
# Validation Acc: 0.6346
#
# Epoch 5/300
#  [██████████████████████████████] 100.0%
# Train Loss: 112.5871 | Train Acc: 0.6303
# Validation Acc: 0.6355
#
# Epoch 6/300
#  [██████████████████████████████] 100.0%
# Train Loss: 112.2972 | Train Acc: 0.6302
# Validation Acc: 0.6348
#
# Epoch 7/300
#  [██████████████████████████████] 100.0%
# Train Loss: 110.5870 | Train Acc: 0.6438
# Validation Acc: 0.6696
#
# Epoch 8/300
#  [██████████████████████████████] 100.0%
# Train Loss: 107.1405 | Train Acc: 0.6678
# Validation Acc: 0.6663
#
# Epoch 9/300
#  [██████████████████████████████] 100.0%
# Train Loss: 105.3350 | Train Acc: 0.6779
# Validation Acc: 0.6869
#
# Epoch 10/300
#  [██████████████████████████████] 100.0%
# Train Loss: 104.5330 | Train Acc: 0.6824
# Validation Acc: 0.6924
#
# Epoch 11/300
#  [██████████████████████████████] 100.0%
# Train Loss: 104.2796 | Train Acc: 0.6829
# Validation Acc: 0.6926
#
# Epoch 12/300
#  [██████████████████████████████] 100.0%
# Train Loss: 103.7755 | Train Acc: 0.6865
# Validation Acc: 0.6946
#
# Epoch 13/300
#  [██████████████████████████████] 100.0%
# Train Loss: 103.5211 | Train Acc: 0.6857
# Validation Acc: 0.6970
#
# Epoch 14/300
#  [██████████████████████████████] 100.0%
# Train Loss: 103.2393 | Train Acc: 0.6885
# Validation Acc: 0.6984
#
# Epoch 15/300
#  [██████████████████████████████] 100.0%
# Train Loss: 103.1913 | Train Acc: 0.6891
# Validation Acc: 0.6966
#
# Epoch 16/300
#  [██████████████████████████████] 100.0%
# Train Loss: 103.2008 | Train Acc: 0.6882
# Validation Acc: 0.6961
#
# Epoch 17/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.9557 | Train Acc: 0.6889
# Validation Acc: 0.6946
#
# Epoch 18/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.9568 | Train Acc: 0.6901
# Validation Acc: 0.6968
#
# Epoch 19/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.8279 | Train Acc: 0.6901
# Validation Acc: 0.6971
#
# Epoch 20/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.6646 | Train Acc: 0.6895
# Validation Acc: 0.6987
#
# Epoch 21/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.8959 | Train Acc: 0.6907
# Validation Acc: 0.6984
#
# Epoch 22/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.8954 | Train Acc: 0.6899
# Validation Acc: 0.6989
#
# Epoch 23/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.6348 | Train Acc: 0.6901
# Validation Acc: 0.7006
#
# Epoch 24/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.5000 | Train Acc: 0.6902
# Validation Acc: 0.6996
#
# Epoch 25/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.2921 | Train Acc: 0.6923
# Validation Acc: 0.6995
#
# Epoch 26/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.2420 | Train Acc: 0.6930
# Validation Acc: 0.6941
#
# Epoch 27/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.3266 | Train Acc: 0.6924
# Validation Acc: 0.6961
#
# Epoch 28/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.1047 | Train Acc: 0.6937
# Validation Acc: 0.6904
#
# Epoch 29/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.0181 | Train Acc: 0.6934
# Validation Acc: 0.6969
#
# Epoch 30/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.9447 | Train Acc: 0.6943
# Validation Acc: 0.6969
#
# Epoch 31/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.9132 | Train Acc: 0.6944
# Validation Acc: 0.6949
#
# Epoch 32/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.9206 | Train Acc: 0.6933
# Validation Acc: 0.6955
#
# Epoch 33/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.8906 | Train Acc: 0.6939
# Validation Acc: 0.6980
#
# Epoch 34/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.7412 | Train Acc: 0.6934
# Validation Acc: 0.6961
#
# Epoch 35/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.7300 | Train Acc: 0.6944
# Validation Acc: 0.6979
#
# Epoch 36/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.6561 | Train Acc: 0.6948
# Validation Acc: 0.6997
#
# Epoch 37/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.4630 | Train Acc: 0.6949
# Validation Acc: 0.6935
#
# Epoch 38/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.4092 | Train Acc: 0.6967
# Validation Acc: 0.6952
#
# Epoch 39/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.3057 | Train Acc: 0.6960
# Validation Acc: 0.6991
#
# Epoch 40/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.2842 | Train Acc: 0.6965
# Validation Acc: 0.6972
#
# Epoch 41/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.0840 | Train Acc: 0.6968
# Validation Acc: 0.6952
#
# Epoch 42/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.1623 | Train Acc: 0.6986
# Validation Acc: 0.6953
#
# Epoch 43/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.9437 | Train Acc: 0.6980
# Validation Acc: 0.6973
#
# Epoch 44/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.9480 | Train Acc: 0.6961
# Validation Acc: 0.6945
#
# Epoch 45/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.9154 | Train Acc: 0.6972
# Validation Acc: 0.6984
#
# Epoch 46/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.6036 | Train Acc: 0.6984
# Validation Acc: 0.6956
#
# Epoch 47/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.6746 | Train Acc: 0.6979
# Validation Acc: 0.6939
#
# Epoch 48/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.4816 | Train Acc: 0.6981
# Validation Acc: 0.6987
#
# Epoch 49/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.3909 | Train Acc: 0.6998
# Validation Acc: 0.6957
#
# Epoch 50/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.1324 | Train Acc: 0.6988
# Validation Acc: 0.6980
#
# Epoch 51/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.1468 | Train Acc: 0.7017
# Validation Acc: 0.6959
#
# Epoch 52/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.1257 | Train Acc: 0.7019
# Validation Acc: 0.6928
#
# Epoch 53/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.1378 | Train Acc: 0.7007
# Validation Acc: 0.6961
#
# Epoch 54/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.9443 | Train Acc: 0.7011
# Validation Acc: 0.6964
#
# Epoch 55/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.8300 | Train Acc: 0.7024
# Validation Acc: 0.6935
#
# Epoch 56/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.6536 | Train Acc: 0.7043
# Validation Acc: 0.6956
#
# Epoch 57/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.6564 | Train Acc: 0.7021
# Validation Acc: 0.6930
#
# Epoch 58/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.3541 | Train Acc: 0.7025
# Validation Acc: 0.6910
#
# Epoch 59/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.2421 | Train Acc: 0.7045
# Validation Acc: 0.6963
#
# Epoch 60/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.0579 | Train Acc: 0.7051
# Validation Acc: 0.6949
#
# Epoch 61/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.0594 | Train Acc: 0.7048
# Validation Acc: 0.6921
#
# Epoch 62/300
#  [██████████████████████████████] 100.0%
# Train Loss: 98.9582 | Train Acc: 0.7022
# Validation Acc: 0.6884
#
# Epoch 63/300
#  [██████████████████████████████] 100.0%
# Train Loss: 98.8744 | Train Acc: 0.7034
# Validation Acc: 0.6920
#
# Epoch 64/300
#  [██████████████████████████████] 100.0%
# Train Loss: 98.7969 | Train Acc: 0.7051
# Validation Acc: 0.6905
#
# Epoch 65/300
#  [██████████████████████████████] 100.0%
# Train Loss: 98.6095 | Train Acc: 0.7047
# Validation Acc: 0.6932
#
# Epoch 66/300
#  [██████████████████████████████] 100.0%
# Train Loss: 98.4784 | Train Acc: 0.7056
# Validation Acc: 0.6927
#
# Epoch 67/300
#  [██████████████████████████████] 100.0%
# Train Loss: 98.2607 | Train Acc: 0.7065
# Validation Acc: 0.6920
#
# Epoch 68/300
#  [██████████████████████████████] 100.0%
# Train Loss: 98.2311 | Train Acc: 0.7069
# Validation Acc: 0.6902
#
# Epoch 69/300
#  [██████████████████████████████] 100.0%
# Train Loss: 98.0331 | Train Acc: 0.7078
# Validation Acc: 0.6887
#
# Epoch 70/300
#  [██████████████████████████████] 100.0%
# Train Loss: 97.8654 | Train Acc: 0.7095
# Validation Acc: 0.6893
#
# Epoch 71/300
#  [██████████████████████████████] 100.0%
# Train Loss: 97.8574 | Train Acc: 0.7092
# Validation Acc: 0.6913
#
# Epoch 72/300
#  [██████████████████████████████] 100.0%
# Train Loss: 97.7173 | Train Acc: 0.7102
# Validation Acc: 0.6935
#
# Epoch 73/300
#  [██████████████████████████████] 100.0%
# Train Loss: 97.5834 | Train Acc: 0.7095
# Validation Acc: 0.6854
#
# Epoch 74/300
#  [██████████████████████████████] 100.0%
# Train Loss: 97.6205 | Train Acc: 0.7105
# Validation Acc: 0.6915
#
# Epoch 75/300
#  [██████████████████████████████] 100.0%
# Train Loss: 97.3658 | Train Acc: 0.7100
# Validation Acc: 0.6909
#
# Epoch 76/300
#  [██████████████████████████████] 100.0%
# Train Loss: 97.4158 | Train Acc: 0.7090
# Validation Acc: 0.6864
#
# Epoch 77/300
#  [██████████████████████████████] 100.0%
# Train Loss: 97.0907 | Train Acc: 0.7108
# Validation Acc: 0.6890
#
# Epoch 78/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.9983 | Train Acc: 0.7120
# Validation Acc: 0.6888
#
# Epoch 79/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.7725 | Train Acc: 0.7125
# Validation Acc: 0.6870
#
# Epoch 80/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.7831 | Train Acc: 0.7115
# Validation Acc: 0.6898
#
# Epoch 81/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.5943 | Train Acc: 0.7136
# Validation Acc: 0.6873
#
# Epoch 82/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.3978 | Train Acc: 0.7135
# Validation Acc: 0.6896
#
# Epoch 83/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.3583 | Train Acc: 0.7129
# Validation Acc: 0.6904
#
# Epoch 84/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.2918 | Train Acc: 0.7139
# Validation Acc: 0.6846
#
# Epoch 85/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.4912 | Train Acc: 0.7133
# Validation Acc: 0.6887
#
# Epoch 86/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.0929 | Train Acc: 0.7137
# Validation Acc: 0.6894
#
# Epoch 87/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.6334 | Train Acc: 0.7161
# Validation Acc: 0.6883
#
# Epoch 88/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.7404 | Train Acc: 0.7162
# Validation Acc: 0.6837
#
# Epoch 89/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.6619 | Train Acc: 0.7164
# Validation Acc: 0.6874
#
# Epoch 90/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.6153 | Train Acc: 0.7160
# Validation Acc: 0.6880
#
# Epoch 91/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.3623 | Train Acc: 0.7168
# Validation Acc: 0.6874
#
# Epoch 92/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.2160 | Train Acc: 0.7182
# Validation Acc: 0.6881
#
# Epoch 93/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.2068 | Train Acc: 0.7187
# Validation Acc: 0.6919
#
# Epoch 94/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.0145 | Train Acc: 0.7183
# Validation Acc: 0.6869
#
# Epoch 95/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.0072 | Train Acc: 0.7186
# Validation Acc: 0.6893
#
# Epoch 96/300
#  [██████████████████████████████] 100.0%
# Train Loss: 94.7191 | Train Acc: 0.7188
# Validation Acc: 0.6901
#
# Epoch 97/300
#  [██████████████████████████████] 100.0%
# Train Loss: 94.6426 | Train Acc: 0.7194
# Validation Acc: 0.6835
#
# Epoch 98/300
#  [██████████████████████████████] 100.0%
# Train Loss: 94.4082 | Train Acc: 0.7208
# Validation Acc: 0.6826
#
# Epoch 99/300
#  [██████████████████████████████] 100.0%
# Train Loss: 94.5798 | Train Acc: 0.7189
# Validation Acc: 0.6868
#
# Epoch 100/300
#  [██████████████████████████████] 100.0%
# Train Loss: 94.2803 | Train Acc: 0.7201
# Validation Acc: 0.6839
#
# Epoch 101/300
#  [██████████████████████████████] 100.0%
# Train Loss: 94.1901 | Train Acc: 0.7209
# Validation Acc: 0.6859
#
# Epoch 102/300
#  [██████████████████████████████] 100.0%
# Train Loss: 94.0151 | Train Acc: 0.7218
# Validation Acc: 0.6859
#
# Epoch 103/300
#  [██████████████████████████████] 100.0%
# Train Loss: 93.7567 | Train Acc: 0.7223
# Validation Acc: 0.6867
#
# Epoch 104/300
#  [██████████████████████████████] 100.0%
# Train Loss: 93.6460 | Train Acc: 0.7218
# Validation Acc: 0.6840
#
# Epoch 105/300
#  [██████████████████████████████] 100.0%
# Train Loss: 93.7297 | Train Acc: 0.7224
# Validation Acc: 0.6828
#
# Epoch 106/300
#  [██████████████████████████████] 100.0%
# Train Loss: 93.5842 | Train Acc: 0.7227
# Validation Acc: 0.6839
#
# Epoch 107/300
#  [██████████████████████████████] 100.0%
# Train Loss: 93.5611 | Train Acc: 0.7224
# Validation Acc: 0.6892
#
# Epoch 108/300
#  [██████████████████████████████] 100.0%
# Train Loss: 93.4590 | Train Acc: 0.7221
# Validation Acc: 0.6844
#
# Epoch 109/300
#  [██████████████████████████████] 100.0%
# Train Loss: 93.2759 | Train Acc: 0.7233
# Validation Acc: 0.6796
#
# Epoch 110/300
#  [██████████████████████████████] 100.0%
# Train Loss: 93.0411 | Train Acc: 0.7252
# Validation Acc: 0.6843
#
# Epoch 111/300
#  [██████████████████████████████] 100.0%
# Train Loss: 93.1442 | Train Acc: 0.7229
# Validation Acc: 0.6846
#
# Epoch 112/300
#  [██████████████████████████████] 100.0%
# Train Loss: 92.8931 | Train Acc: 0.7243
# Validation Acc: 0.6857
#
# Epoch 113/300
#  [██████████████████████████████] 100.0%
# Train Loss: 92.9231 | Train Acc: 0.7235
# Validation Acc: 0.6835
#
# Epoch 114/300
#  [██████████████████████████████] 100.0%
# Train Loss: 92.5899 | Train Acc: 0.7254
# Validation Acc: 0.6861
#
# Epoch 115/300
#  [██████████████████████████████] 100.0%
# Train Loss: 92.5491 | Train Acc: 0.7248
# Validation Acc: 0.6883
#
# Epoch 116/300
#  [██████████████████████████████] 100.0%
# Train Loss: 92.5457 | Train Acc: 0.7262
# Validation Acc: 0.6801
#
# Epoch 117/300
#  [██████████████████████████████] 100.0%
# Train Loss: 92.3000 | Train Acc: 0.7254
# Validation Acc: 0.6857
#
# Epoch 118/300
#  [██████████████████████████████] 100.0%
# Train Loss: 92.3593 | Train Acc: 0.7251
# Validation Acc: 0.6864
#
# Epoch 119/300
#  [██████████████████████████████] 100.0%
# Train Loss: 92.2168 | Train Acc: 0.7268
# Validation Acc: 0.6869
#
# Epoch 120/300
#  [██████████████████████████████] 100.0%
# Train Loss: 92.0461 | Train Acc: 0.7268
# Validation Acc: 0.6875
#
# Epoch 121/300
#  [██████████████████████████████] 100.0%
# Train Loss: 91.8303 | Train Acc: 0.7286
# Validation Acc: 0.6856
#
# Epoch 122/300
#  [██████████████████████████████] 100.0%
# Train Loss: 91.9473 | Train Acc: 0.7270
# Validation Acc: 0.6812
#
# Epoch 123/300
#  [██████████████████████████████] 100.0%
# Train Loss: 91.6935 | Train Acc: 0.7286
# Validation Acc: 0.6805
#
# Epoch 124/300
#  [██████████████████████████████] 100.0%
# Train Loss: 91.4831 | Train Acc: 0.7312
# Validation Acc: 0.6837
#
# Epoch 125/300
#  [██████████████████████████████] 100.0%
# Train Loss: 91.3405 | Train Acc: 0.7296
# Validation Acc: 0.6870
#
# Epoch 126/300
#  [██████████████████████████████] 100.0%
# Train Loss: 91.5533 | Train Acc: 0.7280
# Validation Acc: 0.6788
#
# Epoch 127/300
#  [██████████████████████████████] 100.0%
# Train Loss: 91.3603 | Train Acc: 0.7282
# Validation Acc: 0.6772
#
# Epoch 128/300
#  [██████████████████████████████] 100.0%
# Train Loss: 91.0830 | Train Acc: 0.7299
# Validation Acc: 0.6834
#
# Epoch 129/300
#  [██████████████████████████████] 100.0%
# Train Loss: 90.8294 | Train Acc: 0.7321
# Validation Acc: 0.6806
#
# Epoch 130/300
#  [██████████████████████████████] 100.0%
# Train Loss: 90.8238 | Train Acc: 0.7324
# Validation Acc: 0.6874
#
# Epoch 131/300
#  [██████████████████████████████] 100.0%
# Train Loss: 90.5430 | Train Acc: 0.7318
# Validation Acc: 0.6804
#
# Epoch 132/300
#  [██████████████████████████████] 100.0%
# Train Loss: 90.6020 | Train Acc: 0.7318
# Validation Acc: 0.6810
#
# Epoch 133/300
#  [██████████████████████████████] 100.0%
# Train Loss: 90.5528 | Train Acc: 0.7325
# Validation Acc: 0.6863
#
# Epoch 134/300
#  [██████████████████████████████] 100.0%
# Train Loss: 90.3156 | Train Acc: 0.7320
# Validation Acc: 0.6772
#
# Epoch 135/300
#  [██████████████████████████████] 100.0%
# Train Loss: 90.3629 | Train Acc: 0.7328
# Validation Acc: 0.6844
#
# Epoch 136/300
#  [██████████████████████████████] 100.0%
# Train Loss: 90.2344 | Train Acc: 0.7333
# Validation Acc: 0.6797
#
# Epoch 137/300
#  [██████████████████████████████] 100.0%
# Train Loss: 90.2211 | Train Acc: 0.7333
# Validation Acc: 0.6855
#
# Epoch 138/300
#  [██████████████████████████████] 100.0%
# Train Loss: 90.0698 | Train Acc: 0.7343
# Validation Acc: 0.6781
#
# Epoch 139/300
#  [██████████████████████████████] 100.0%
# Train Loss: 89.9476 | Train Acc: 0.7340
# Validation Acc: 0.6840
#
# Epoch 140/300
#  [██████████████████████████████] 100.0%
# Train Loss: 89.7208 | Train Acc: 0.7348
# Validation Acc: 0.6826
#
# Epoch 141/300
#  [██████████████████████████████] 100.0%
# Train Loss: 90.0179 | Train Acc: 0.7338
# Validation Acc: 0.6825
#
# Epoch 142/300
#  [██████████████████████████████] 100.0%
# Train Loss: 89.7029 | Train Acc: 0.7340
# Validation Acc: 0.6819
#
# Epoch 143/300
#  [██████████████████████████████] 100.0%
# Train Loss: 89.5502 | Train Acc: 0.7358
# Validation Acc: 0.6845
#
# Epoch 144/300
#  [██████████████████████████████] 100.0%
# Train Loss: 89.2123 | Train Acc: 0.7366
# Validation Acc: 0.6775
#
# Epoch 145/300
#  [██████████████████████████████] 100.0%
# Train Loss: 89.3185 | Train Acc: 0.7363
# Validation Acc: 0.6789
#
# Epoch 146/300
#  [██████████████████████████████] 100.0%
# Train Loss: 89.2697 | Train Acc: 0.7367
# Validation Acc: 0.6796
#
# Epoch 147/300
#  [██████████████████████████████] 100.0%
# Train Loss: 88.8992 | Train Acc: 0.7384
# Validation Acc: 0.6755
#
# Epoch 148/300
#  [██████████████████████████████] 100.0%
# Train Loss: 89.0901 | Train Acc: 0.7364
# Validation Acc: 0.6761
#
# Epoch 149/300
#  [██████████████████████████████] 100.0%
# Train Loss: 88.8834 | Train Acc: 0.7388
# Validation Acc: 0.6785
#
# Epoch 150/300
#  [██████████████████████████████] 100.0%
# Train Loss: 88.7297 | Train Acc: 0.7381
# Validation Acc: 0.6763
#
# Epoch 151/300
#  [██████████████████████████████] 100.0%
# Train Loss: 88.7984 | Train Acc: 0.7374
# Validation Acc: 0.6776
#
# Epoch 152/300
#  [██████████████████████████████] 100.0%
# Train Loss: 88.6186 | Train Acc: 0.7380
# Validation Acc: 0.6762
#
# Epoch 153/300
#  [██████████████████████████████] 100.0%
# Train Loss: 88.6046 | Train Acc: 0.7378
# Validation Acc: 0.6807
#
# Epoch 154/300
#  [██████████████████████████████] 100.0%
# Train Loss: 88.7084 | Train Acc: 0.7378
# Validation Acc: 0.6771
#
# Epoch 155/300
#  [██████████████████████████████] 100.0%
# Train Loss: 88.4192 | Train Acc: 0.7378
# Validation Acc: 0.6807
#
# Epoch 156/300
#  [██████████████████████████████] 100.0%
# Train Loss: 88.2715 | Train Acc: 0.7401
# Validation Acc: 0.6779
#
# Epoch 157/300
#  [██████████████████████████████] 100.0%
# Train Loss: 88.0038 | Train Acc: 0.7415
# Validation Acc: 0.6758
#
# Epoch 158/300
#  [██████████████████████████████] 100.0%
# Train Loss: 88.2047 | Train Acc: 0.7397
# Validation Acc: 0.6768
#
# Epoch 159/300
#  [██████████████████████████████] 100.0%
# Train Loss: 87.9808 | Train Acc: 0.7390
# Validation Acc: 0.6752
#
# Epoch 160/300
#  [██████████████████████████████] 100.0%
# Train Loss: 87.8858 | Train Acc: 0.7415
# Validation Acc: 0.6752
#
# Epoch 161/300
#  [██████████████████████████████] 100.0%
# Train Loss: 87.7659 | Train Acc: 0.7412
# Validation Acc: 0.6743
#
# Epoch 162/300
#  [██████████████████████████████] 100.0%
# Train Loss: 87.7244 | Train Acc: 0.7403
# Validation Acc: 0.6796
#
# Epoch 163/300
#  [██████████████████████████████] 100.0%
# Train Loss: 87.7928 | Train Acc: 0.7410
# Validation Acc: 0.6744
#
# Epoch 164/300
#  [██████████████████████████████] 100.0%
# Train Loss: 87.3997 | Train Acc: 0.7425
# Validation Acc: 0.6780
#
# Epoch 165/300
#  [██████████████████████████████] 100.0%
# Train Loss: 87.5293 | Train Acc: 0.7419
# Validation Acc: 0.6668
#
# Epoch 166/300
#  [██████████████████████████████] 100.0%
# Train Loss: 87.4771 | Train Acc: 0.7433
# Validation Acc: 0.6768
#
# Epoch 167/300
#  [██████████████████████████████] 100.0%
# Train Loss: 87.2368 | Train Acc: 0.7419
# Validation Acc: 0.6746
#
# Epoch 168/300
#  [██████████████████████████████] 100.0%
# Train Loss: 87.2091 | Train Acc: 0.7435
# Validation Acc: 0.6766
#
# Epoch 169/300
#  [██████████████████████████████] 100.0%
# Train Loss: 87.2160 | Train Acc: 0.7420
# Validation Acc: 0.6741
#
# Epoch 170/300
#  [██████████████████████████████] 100.0%
# Train Loss: 87.0508 | Train Acc: 0.7425
# Validation Acc: 0.6719
#
# Epoch 171/300
#  [██████████████████████████████] 100.0%
# Train Loss: 86.8517 | Train Acc: 0.7443
# Validation Acc: 0.6766
#
# Epoch 172/300
#  [██████████████████████████████] 100.0%
# Train Loss: 86.7314 | Train Acc: 0.7443
# Validation Acc: 0.6725
#
# Epoch 173/300
#  [██████████████████████████████] 100.0%
# Train Loss: 87.0371 | Train Acc: 0.7436
# Validation Acc: 0.6737
#
# Epoch 174/300
#  [██████████████████████████████] 100.0%
# Train Loss: 86.9355 | Train Acc: 0.7429
# Validation Acc: 0.6787
#
# Epoch 175/300
#  [██████████████████████████████] 100.0%
# Train Loss: 86.5560 | Train Acc: 0.7464
# Validation Acc: 0.6760
#
# Epoch 176/300
#  [██████████████████████████████] 100.0%
# Train Loss: 86.6760 | Train Acc: 0.7438
# Validation Acc: 0.6712
#
# Epoch 177/300
#  [██████████████████████████████] 100.0%
# Train Loss: 86.5536 | Train Acc: 0.7462
# Validation Acc: 0.6758
#
# Epoch 178/300
#  [██████████████████████████████] 100.0%
# Train Loss: 86.1666 | Train Acc: 0.7446
# Validation Acc: 0.6749
#
# Epoch 179/300
#  [██████████████████████████████] 100.0%
# Train Loss: 86.4153 | Train Acc: 0.7448
# Validation Acc: 0.6777
#
# Epoch 180/300
#  [██████████████████████████████] 100.0%
# Train Loss: 86.1434 | Train Acc: 0.7466
# Validation Acc: 0.6771
#
# Epoch 181/300
#  [██████████████████████████████] 100.0%
# Train Loss: 86.4001 | Train Acc: 0.7463
# Validation Acc: 0.6744
#
# Epoch 182/300
#  [██████████████████████████████] 100.0%
# Train Loss: 86.1426 | Train Acc: 0.7466
# Validation Acc: 0.6676
#
# Epoch 183/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.8464 | Train Acc: 0.7462
# Validation Acc: 0.6706
#
# Epoch 184/300
#  [██████████████████████████████] 100.0%
# Train Loss: 86.1448 | Train Acc: 0.7471
# Validation Acc: 0.6726
#
# Epoch 185/300
#  [██████████████████████████████] 100.0%
# Train Loss: 86.0314 | Train Acc: 0.7461
# Validation Acc: 0.6683
#
# Epoch 186/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.7523 | Train Acc: 0.7464
# Validation Acc: 0.6737
#
# Epoch 187/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.7565 | Train Acc: 0.7479
# Validation Acc: 0.6727
#
# Epoch 188/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.6741 | Train Acc: 0.7489
# Validation Acc: 0.6663
#
# Epoch 189/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.6900 | Train Acc: 0.7480
# Validation Acc: 0.6771
#
# Epoch 190/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.4734 | Train Acc: 0.7485
# Validation Acc: 0.6728
#
# Epoch 191/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.3492 | Train Acc: 0.7501
# Validation Acc: 0.6704
#
# Epoch 192/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.5910 | Train Acc: 0.7485
# Validation Acc: 0.6705
#
# Epoch 193/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.4606 | Train Acc: 0.7484
# Validation Acc: 0.6707
#
# Epoch 194/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.1267 | Train Acc: 0.7492
# Validation Acc: 0.6734
#
# Epoch 195/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.0206 | Train Acc: 0.7497
# Validation Acc: 0.6757
#
# Epoch 196/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.1586 | Train Acc: 0.7486
# Validation Acc: 0.6748
#
# Epoch 197/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.1064 | Train Acc: 0.7485
# Validation Acc: 0.6679
#
# Epoch 198/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.0516 | Train Acc: 0.7494
# Validation Acc: 0.6711
#
# Epoch 199/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.0126 | Train Acc: 0.7500
# Validation Acc: 0.6698
#
# Epoch 200/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.6947 | Train Acc: 0.7507
# Validation Acc: 0.6768
#
# Epoch 201/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.4991 | Train Acc: 0.7510
# Validation Acc: 0.6723
#
# Epoch 202/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.8654 | Train Acc: 0.7505
# Validation Acc: 0.6680
#
# Epoch 203/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.8270 | Train Acc: 0.7479
# Validation Acc: 0.6702
#
# Epoch 204/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.4866 | Train Acc: 0.7521
# Validation Acc: 0.6729
#
# Epoch 205/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.4482 | Train Acc: 0.7522
# Validation Acc: 0.6680
#
# Epoch 206/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.3384 | Train Acc: 0.7506
# Validation Acc: 0.6686
#
# Epoch 207/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.4096 | Train Acc: 0.7504
# Validation Acc: 0.6715
#
# Epoch 208/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.3267 | Train Acc: 0.7511
# Validation Acc: 0.6757
#
# Epoch 209/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.0663 | Train Acc: 0.7525
# Validation Acc: 0.6763
#
# Epoch 210/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.3791 | Train Acc: 0.7518
# Validation Acc: 0.6670
#
# Epoch 211/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.2045 | Train Acc: 0.7513
# Validation Acc: 0.6680
#
# Epoch 212/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.9237 | Train Acc: 0.7528
# Validation Acc: 0.6705
#
# Epoch 213/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.8093 | Train Acc: 0.7523
# Validation Acc: 0.6750
#
# Epoch 214/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.0139 | Train Acc: 0.7521
# Validation Acc: 0.6678
#
# Epoch 215/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.6673 | Train Acc: 0.7527
# Validation Acc: 0.6702
#
# Epoch 216/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.6146 | Train Acc: 0.7531
# Validation Acc: 0.6654
#
# Epoch 217/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.6980 | Train Acc: 0.7529
# Validation Acc: 0.6787
#
# Epoch 218/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.7907 | Train Acc: 0.7541
# Validation Acc: 0.6666
#
# Epoch 219/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.7103 | Train Acc: 0.7531
# Validation Acc: 0.6690
#
# Epoch 220/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.5032 | Train Acc: 0.7531
# Validation Acc: 0.6695
#
# Epoch 221/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.4935 | Train Acc: 0.7546
# Validation Acc: 0.6664
#
# Epoch 222/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.5506 | Train Acc: 0.7538
# Validation Acc: 0.6643
#
# Epoch 223/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.4240 | Train Acc: 0.7541
# Validation Acc: 0.6655
#
# Epoch 224/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.3195 | Train Acc: 0.7544
# Validation Acc: 0.6695
#
# Epoch 225/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.2633 | Train Acc: 0.7552
# Validation Acc: 0.6672
#
# Epoch 226/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.0119 | Train Acc: 0.7555
# Validation Acc: 0.6642
#
# Epoch 227/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.3108 | Train Acc: 0.7548
# Validation Acc: 0.6722
#
# Epoch 228/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.9400 | Train Acc: 0.7552
# Validation Acc: 0.6758
#
# Epoch 229/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.9472 | Train Acc: 0.7563
# Validation Acc: 0.6669
#
# Epoch 230/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.7537 | Train Acc: 0.7569
# Validation Acc: 0.6691
#
# Epoch 231/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.8103 | Train Acc: 0.7540
# Validation Acc: 0.6727
#
# Epoch 232/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.9401 | Train Acc: 0.7564
# Validation Acc: 0.6696
#
# Epoch 233/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.8009 | Train Acc: 0.7560
# Validation Acc: 0.6698
#
# Epoch 234/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.8192 | Train Acc: 0.7564
# Validation Acc: 0.6642
#
# Epoch 235/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.1231 | Train Acc: 0.7549
# Validation Acc: 0.6730
#
# Epoch 236/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.6741 | Train Acc: 0.7572
# Validation Acc: 0.6680
#
# Epoch 237/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.4359 | Train Acc: 0.7583
# Validation Acc: 0.6646
#
# Epoch 238/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.3242 | Train Acc: 0.7573
# Validation Acc: 0.6661
#
# Epoch 239/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.4028 | Train Acc: 0.7571
# Validation Acc: 0.6678
#
# Epoch 240/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.2843 | Train Acc: 0.7578
# Validation Acc: 0.6702
#
# Epoch 241/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.3847 | Train Acc: 0.7577
# Validation Acc: 0.6709
#
# Epoch 242/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.3381 | Train Acc: 0.7600
# Validation Acc: 0.6659
#
# Epoch 243/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.0713 | Train Acc: 0.7571
# Validation Acc: 0.6613
#
# Epoch 244/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.1931 | Train Acc: 0.7596
# Validation Acc: 0.6704
#
# Epoch 245/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.1960 | Train Acc: 0.7576
# Validation Acc: 0.6646
#
# Epoch 246/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.1010 | Train Acc: 0.7587
# Validation Acc: 0.6689
#
# Epoch 247/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.0704 | Train Acc: 0.7588
# Validation Acc: 0.6701
#
# Epoch 248/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.8379 | Train Acc: 0.7587
# Validation Acc: 0.6674
#
# Epoch 249/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.9711 | Train Acc: 0.7600
# Validation Acc: 0.6631
#
# Epoch 250/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.0139 | Train Acc: 0.7595
# Validation Acc: 0.6750
#
# Epoch 251/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.9738 | Train Acc: 0.7586
# Validation Acc: 0.6663
#
# Epoch 252/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.6739 | Train Acc: 0.7608
# Validation Acc: 0.6703
#
# Epoch 253/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.8818 | Train Acc: 0.7602
# Validation Acc: 0.6664
#
# Epoch 254/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.8268 | Train Acc: 0.7608
# Validation Acc: 0.6684
#
# Epoch 255/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.5052 | Train Acc: 0.7609
# Validation Acc: 0.6615
#
# Epoch 256/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.4103 | Train Acc: 0.7617
# Validation Acc: 0.6712
#
# Epoch 257/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.9075 | Train Acc: 0.7602
# Validation Acc: 0.6676
#
# Epoch 258/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.4596 | Train Acc: 0.7624
# Validation Acc: 0.6705
#
# Epoch 259/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.6396 | Train Acc: 0.7601
# Validation Acc: 0.6685
#
# Epoch 260/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.5239 | Train Acc: 0.7589
# Validation Acc: 0.6654
#
# Epoch 261/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.3086 | Train Acc: 0.7608
# Validation Acc: 0.6705
#
# Epoch 262/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.4777 | Train Acc: 0.7619
# Validation Acc: 0.6737
#
# Epoch 263/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.3774 | Train Acc: 0.7619
# Validation Acc: 0.6673
#
# Epoch 264/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.2238 | Train Acc: 0.7616
# Validation Acc: 0.6699
#
# Epoch 265/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.8605 | Train Acc: 0.7619
# Validation Acc: 0.6662
#
# Epoch 266/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.1014 | Train Acc: 0.7609
# Validation Acc: 0.6664
#
# Epoch 267/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.0857 | Train Acc: 0.7608
# Validation Acc: 0.6681
#
# Epoch 268/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.7938 | Train Acc: 0.7644
# Validation Acc: 0.6662
#
# Epoch 269/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.7915 | Train Acc: 0.7623
# Validation Acc: 0.6604
#
# Epoch 270/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.8446 | Train Acc: 0.7624
# Validation Acc: 0.6630
#
# Epoch 271/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.7978 | Train Acc: 0.7621
# Validation Acc: 0.6690
#
# Epoch 272/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.4474 | Train Acc: 0.7642
# Validation Acc: 0.6675
#
# Epoch 273/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.5932 | Train Acc: 0.7642
# Validation Acc: 0.6613
#
# Epoch 274/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.4899 | Train Acc: 0.7639
# Validation Acc: 0.6646
#
# Epoch 275/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.4538 | Train Acc: 0.7639
# Validation Acc: 0.6615
#
# Epoch 276/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.7907 | Train Acc: 0.7636
# Validation Acc: 0.6686
#
# Epoch 277/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.5640 | Train Acc: 0.7654
# Validation Acc: 0.6587
#
# Epoch 278/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.6112 | Train Acc: 0.7644
# Validation Acc: 0.6648
#
# Epoch 279/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.6806 | Train Acc: 0.7649
# Validation Acc: 0.6652
#
# Epoch 280/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.6038 | Train Acc: 0.7632
# Validation Acc: 0.6634
#
# Epoch 281/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.8024 | Train Acc: 0.7618
# Validation Acc: 0.6687
#
# Epoch 282/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.3498 | Train Acc: 0.7648
# Validation Acc: 0.6632
#
# Epoch 283/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.1801 | Train Acc: 0.7642
# Validation Acc: 0.6690
#
# Epoch 284/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.1455 | Train Acc: 0.7653
# Validation Acc: 0.6596
#
# Epoch 285/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.1152 | Train Acc: 0.7656
# Validation Acc: 0.6703
#
# Epoch 286/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.0568 | Train Acc: 0.7659
# Validation Acc: 0.6574
#
# Epoch 287/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.2098 | Train Acc: 0.7643
# Validation Acc: 0.6710
#
# Epoch 288/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.1622 | Train Acc: 0.7639
# Validation Acc: 0.6596
#
# Epoch 289/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.8176 | Train Acc: 0.7646
# Validation Acc: 0.6704
#
# Epoch 290/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.1534 | Train Acc: 0.7640
# Validation Acc: 0.6691
#
# Epoch 291/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.0044 | Train Acc: 0.7650
# Validation Acc: 0.6670
#
# Epoch 292/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.1153 | Train Acc: 0.7638
# Validation Acc: 0.6659
#
# Epoch 293/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.6727 | Train Acc: 0.7661
# Validation Acc: 0.6629
#
# Epoch 294/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.5091 | Train Acc: 0.7676
# Validation Acc: 0.6650
#
# Epoch 295/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.8651 | Train Acc: 0.7659
# Validation Acc: 0.6603
#
# Epoch 296/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.7215 | Train Acc: 0.7664
# Validation Acc: 0.6669
#
# Epoch 297/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.0466 | Train Acc: 0.7664
# Validation Acc: 0.6629
#
# Epoch 298/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.7632 | Train Acc: 0.7650
# Validation Acc: 0.6676
#
# Epoch 299/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.8680 | Train Acc: 0.7667
# Validation Acc: 0.6647
#
# Epoch 300/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.6842 | Train Acc: 0.7663
# Validation Acc: 0.6665
#
# === Fold 2/5 ===
#
# Epoch 1/300
#  [██████████████████████████████] 100.0%
# Train Loss: 115.1907 | Train Acc: 0.6096
# Validation Acc: 0.6169
#
# Epoch 2/300
#  [██████████████████████████████] 100.0%
# Train Loss: 112.7360 | Train Acc: 0.6250
# Validation Acc: 0.6152
#
# Epoch 3/300
#  [██████████████████████████████] 100.0%
# Train Loss: 112.4802 | Train Acc: 0.6274
# Validation Acc: 0.6254
#
# Epoch 4/300
#  [██████████████████████████████] 100.0%
# Train Loss: 112.3608 | Train Acc: 0.6301
# Validation Acc: 0.6234
#
# Epoch 5/300
#  [██████████████████████████████] 100.0%
# Train Loss: 112.0711 | Train Acc: 0.6321
# Validation Acc: 0.6238
#
# Epoch 6/300
#  [██████████████████████████████] 100.0%
# Train Loss: 111.8108 | Train Acc: 0.6359
# Validation Acc: 0.6322
#
# Epoch 7/300
#  [██████████████████████████████] 100.0%
# Train Loss: 108.9426 | Train Acc: 0.6551
# Validation Acc: 0.6753
#
# Epoch 8/300
#  [██████████████████████████████] 100.0%
# Train Loss: 105.7514 | Train Acc: 0.6763
# Validation Acc: 0.6706
#
# Epoch 9/300
#  [██████████████████████████████] 100.0%
# Train Loss: 104.3655 | Train Acc: 0.6851
# Validation Acc: 0.6691
#
# Epoch 10/300
#  [██████████████████████████████] 100.0%
# Train Loss: 104.0404 | Train Acc: 0.6850
# Validation Acc: 0.6819
#
# Epoch 11/300
#  [██████████████████████████████] 100.0%
# Train Loss: 103.3454 | Train Acc: 0.6893
# Validation Acc: 0.6866
#
# Epoch 12/300
#  [██████████████████████████████] 100.0%
# Train Loss: 103.1197 | Train Acc: 0.6908
# Validation Acc: 0.6845
#
# Epoch 13/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.7343 | Train Acc: 0.6912
# Validation Acc: 0.6842
#
# Epoch 14/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.8344 | Train Acc: 0.6893
# Validation Acc: 0.6850
#
# Epoch 15/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.5394 | Train Acc: 0.6910
# Validation Acc: 0.6889
#
# Epoch 16/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.4612 | Train Acc: 0.6923
# Validation Acc: 0.6873
#
# Epoch 17/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.3227 | Train Acc: 0.6926
# Validation Acc: 0.6866
#
# Epoch 18/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.3005 | Train Acc: 0.6929
# Validation Acc: 0.6864
#
# Epoch 19/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.0901 | Train Acc: 0.6934
# Validation Acc: 0.6793
#
# Epoch 20/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.1842 | Train Acc: 0.6934
# Validation Acc: 0.6867
#
# Epoch 21/300
#  [██████████████████████████████] 100.0%
# Train Loss: 102.0663 | Train Acc: 0.6949
# Validation Acc: 0.6886
#
# Epoch 22/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.9636 | Train Acc: 0.6942
# Validation Acc: 0.6828
#
# Epoch 23/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.9384 | Train Acc: 0.6939
# Validation Acc: 0.6852
#
# Epoch 24/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.7870 | Train Acc: 0.6943
# Validation Acc: 0.6860
#
# Epoch 25/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.8403 | Train Acc: 0.6954
# Validation Acc: 0.6878
#
# Epoch 26/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.6582 | Train Acc: 0.6950
# Validation Acc: 0.6824
#
# Epoch 27/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.7140 | Train Acc: 0.6950
# Validation Acc: 0.6873
#
# Epoch 28/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.3952 | Train Acc: 0.6964
# Validation Acc: 0.6849
#
# Epoch 29/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.4562 | Train Acc: 0.6963
# Validation Acc: 0.6861
#
# Epoch 30/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.2500 | Train Acc: 0.6979
# Validation Acc: 0.6829
#
# Epoch 31/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.4405 | Train Acc: 0.6966
# Validation Acc: 0.6859
#
# Epoch 32/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.3391 | Train Acc: 0.6964
# Validation Acc: 0.6808
#
# Epoch 33/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.1105 | Train Acc: 0.6962
# Validation Acc: 0.6845
#
# Epoch 34/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.9920 | Train Acc: 0.6985
# Validation Acc: 0.6865
#
# Epoch 35/300
#  [██████████████████████████████] 100.0%
# Train Loss: 101.0079 | Train Acc: 0.6962
# Validation Acc: 0.6855
#
# Epoch 36/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.9453 | Train Acc: 0.6979
# Validation Acc: 0.6854
#
# Epoch 37/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.8781 | Train Acc: 0.6981
# Validation Acc: 0.6850
#
# Epoch 38/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.8092 | Train Acc: 0.6972
# Validation Acc: 0.6854
#
# Epoch 39/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.7199 | Train Acc: 0.6999
# Validation Acc: 0.6857
#
# Epoch 40/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.6462 | Train Acc: 0.6986
# Validation Acc: 0.6846
#
# Epoch 41/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.5434 | Train Acc: 0.6997
# Validation Acc: 0.6836
#
# Epoch 42/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.5103 | Train Acc: 0.6998
# Validation Acc: 0.6829
#
# Epoch 43/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.5238 | Train Acc: 0.7001
# Validation Acc: 0.6826
#
# Epoch 44/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.2841 | Train Acc: 0.7009
# Validation Acc: 0.6860
#
# Epoch 45/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.1206 | Train Acc: 0.7030
# Validation Acc: 0.6845
#
# Epoch 46/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.0918 | Train Acc: 0.7019
# Validation Acc: 0.6870
#
# Epoch 47/300
#  [██████████████████████████████] 100.0%
# Train Loss: 100.0306 | Train Acc: 0.7011
# Validation Acc: 0.6826
#
# Epoch 48/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.7849 | Train Acc: 0.7023
# Validation Acc: 0.6854
#
# Epoch 49/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.7485 | Train Acc: 0.7030
# Validation Acc: 0.6854
#
# Epoch 50/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.8098 | Train Acc: 0.7041
# Validation Acc: 0.6830
#
# Epoch 51/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.5679 | Train Acc: 0.7043
# Validation Acc: 0.6838
#
# Epoch 52/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.4134 | Train Acc: 0.7039
# Validation Acc: 0.6837
#
# Epoch 53/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.4984 | Train Acc: 0.7036
# Validation Acc: 0.6847
#
# Epoch 54/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.2445 | Train Acc: 0.7040
# Validation Acc: 0.6803
#
# Epoch 55/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.1363 | Train Acc: 0.7048
# Validation Acc: 0.6830
#
# Epoch 56/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.1301 | Train Acc: 0.7050
# Validation Acc: 0.6833
#
# Epoch 57/300
#  [██████████████████████████████] 100.0%
# Train Loss: 99.0170 | Train Acc: 0.7059
# Validation Acc: 0.6842
#
# Epoch 58/300
#  [██████████████████████████████] 100.0%
# Train Loss: 98.8399 | Train Acc: 0.7061
# Validation Acc: 0.6804
#
# Epoch 59/300
#  [██████████████████████████████] 100.0%
# Train Loss: 98.8856 | Train Acc: 0.7064
# Validation Acc: 0.6801
#
# Epoch 60/300
#  [██████████████████████████████] 100.0%
# Train Loss: 98.6556 | Train Acc: 0.7058
# Validation Acc: 0.6829
#
# Epoch 61/300
#  [██████████████████████████████] 100.0%
# Train Loss: 98.6335 | Train Acc: 0.7072
# Validation Acc: 0.6838
#
# Epoch 62/300
#  [██████████████████████████████] 100.0%
# Train Loss: 98.3755 | Train Acc: 0.7070
# Validation Acc: 0.6811
#
# Epoch 63/300
#  [██████████████████████████████] 100.0%
# Train Loss: 98.4242 | Train Acc: 0.7072
# Validation Acc: 0.6805
#
# Epoch 64/300
#  [██████████████████████████████] 100.0%
# Train Loss: 98.2494 | Train Acc: 0.7082
# Validation Acc: 0.6792
#
# Epoch 65/300
#  [██████████████████████████████] 100.0%
# Train Loss: 98.0360 | Train Acc: 0.7091
# Validation Acc: 0.6817
#
# Epoch 66/300
#  [██████████████████████████████] 100.0%
# Train Loss: 97.9943 | Train Acc: 0.7096
# Validation Acc: 0.6841
#
# Epoch 67/300
#  [██████████████████████████████] 100.0%
# Train Loss: 97.9013 | Train Acc: 0.7088
# Validation Acc: 0.6821
#
# Epoch 68/300
#  [██████████████████████████████] 100.0%
# Train Loss: 97.8060 | Train Acc: 0.7098
# Validation Acc: 0.6787
#
# Epoch 69/300
#  [██████████████████████████████] 100.0%
# Train Loss: 97.7088 | Train Acc: 0.7097
# Validation Acc: 0.6847
#
# Epoch 70/300
#  [██████████████████████████████] 100.0%
# Train Loss: 97.4959 | Train Acc: 0.7118
# Validation Acc: 0.6821
#
# Epoch 71/300
#  [██████████████████████████████] 100.0%
# Train Loss: 97.3019 | Train Acc: 0.7110
# Validation Acc: 0.6777
#
# Epoch 72/300
#  [██████████████████████████████] 100.0%
# Train Loss: 97.2036 | Train Acc: 0.7116
# Validation Acc: 0.6804
#
# Epoch 73/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.9915 | Train Acc: 0.7121
# Validation Acc: 0.6770
#
# Epoch 74/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.9526 | Train Acc: 0.7127
# Validation Acc: 0.6752
#
# Epoch 75/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.9661 | Train Acc: 0.7125
# Validation Acc: 0.6787
#
# Epoch 76/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.7618 | Train Acc: 0.7136
# Validation Acc: 0.6758
#
# Epoch 77/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.6788 | Train Acc: 0.7119
# Validation Acc: 0.6736
#
# Epoch 78/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.5794 | Train Acc: 0.7131
# Validation Acc: 0.6766
#
# Epoch 79/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.3984 | Train Acc: 0.7147
# Validation Acc: 0.6815
#
# Epoch 80/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.1731 | Train Acc: 0.7155
# Validation Acc: 0.6779
#
# Epoch 81/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.2265 | Train Acc: 0.7149
# Validation Acc: 0.6809
#
# Epoch 82/300
#  [██████████████████████████████] 100.0%
# Train Loss: 96.0618 | Train Acc: 0.7152
# Validation Acc: 0.6760
#
# Epoch 83/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.9909 | Train Acc: 0.7159
# Validation Acc: 0.6765
#
# Epoch 84/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.8863 | Train Acc: 0.7168
# Validation Acc: 0.6791
#
# Epoch 85/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.5861 | Train Acc: 0.7189
# Validation Acc: 0.6771
#
# Epoch 86/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.4951 | Train Acc: 0.7187
# Validation Acc: 0.6770
#
# Epoch 87/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.3911 | Train Acc: 0.7178
# Validation Acc: 0.6789
#
# Epoch 88/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.3242 | Train Acc: 0.7174
# Validation Acc: 0.6758
#
# Epoch 89/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.1926 | Train Acc: 0.7198
# Validation Acc: 0.6748
#
# Epoch 90/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.0593 | Train Acc: 0.7186
# Validation Acc: 0.6766
#
# Epoch 91/300
#  [██████████████████████████████] 100.0%
# Train Loss: 95.0263 | Train Acc: 0.7180
# Validation Acc: 0.6765
#
# Epoch 92/300
#  [██████████████████████████████] 100.0%
# Train Loss: 94.7002 | Train Acc: 0.7201
# Validation Acc: 0.6753
#
# Epoch 93/300
#  [██████████████████████████████] 100.0%
# Train Loss: 94.8307 | Train Acc: 0.7206
# Validation Acc: 0.6736
#
# Epoch 94/300
#  [██████████████████████████████] 100.0%
# Train Loss: 94.5006 | Train Acc: 0.7194
# Validation Acc: 0.6794
#
# Epoch 95/300
#  [██████████████████████████████] 100.0%
# Train Loss: 94.5582 | Train Acc: 0.7205
# Validation Acc: 0.6736
#
# Epoch 96/300
#  [██████████████████████████████] 100.0%
# Train Loss: 94.3473 | Train Acc: 0.7215
# Validation Acc: 0.6759
#
# Epoch 97/300
#  [██████████████████████████████] 100.0%
# Train Loss: 94.1787 | Train Acc: 0.7225
# Validation Acc: 0.6802
#
# Epoch 98/300
#  [██████████████████████████████] 100.0%
# Train Loss: 94.1187 | Train Acc: 0.7208
# Validation Acc: 0.6776
#
# Epoch 99/300
#  [██████████████████████████████] 100.0%
# Train Loss: 94.2073 | Train Acc: 0.7205
# Validation Acc: 0.6782
#
# Epoch 100/300
#  [██████████████████████████████] 100.0%
# Train Loss: 93.7939 | Train Acc: 0.7223
# Validation Acc: 0.6756
#
# Epoch 101/300
#  [██████████████████████████████] 100.0%
# Train Loss: 93.9039 | Train Acc: 0.7232
# Validation Acc: 0.6753
#
# Epoch 102/300
#  [██████████████████████████████] 100.0%
# Train Loss: 93.5909 | Train Acc: 0.7233
# Validation Acc: 0.6747
#
# Epoch 103/300
#  [██████████████████████████████] 100.0%
# Train Loss: 93.4944 | Train Acc: 0.7252
# Validation Acc: 0.6766
#
# Epoch 104/300
#  [██████████████████████████████] 100.0%
# Train Loss: 93.3164 | Train Acc: 0.7241
# ...
# Validation Acc: 0.6708
#
# Epoch 168/300
#  [██████████████████████████████] 100.0%
# Train Loss: 86.1188 | Train Acc: 0.7465
# Validation Acc: 0.6733
#
# Epoch 169/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.9610 | Train Acc: 0.7471
# Validation Acc: 0.6743
#
# Epoch 170/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.9511 | Train Acc: 0.7466
# Validation Acc: 0.6707
#
# Epoch 171/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.8303 | Train Acc: 0.7472
# Validation Acc: 0.6794
#
# Epoch 172/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.8066 | Train Acc: 0.7469
# Validation Acc: 0.6724
#
# Epoch 173/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.6556 | Train Acc: 0.7501
# Validation Acc: 0.6765
#
# Epoch 174/300
#  [██████████████████████████████] 100.0%
# Train Loss: 86.0535 | Train Acc: 0.7467
# Validation Acc: 0.6722
#
# Epoch 175/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.7465 | Train Acc: 0.7480
# Validation Acc: 0.6704
#
# Epoch 176/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.6002 | Train Acc: 0.7472
# Validation Acc: 0.6742
#
# Epoch 177/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.3624 | Train Acc: 0.7491
# Validation Acc: 0.6746
#
# Epoch 178/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.3857 | Train Acc: 0.7493
# Validation Acc: 0.6731
#
# Epoch 179/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.0352 | Train Acc: 0.7489
# Validation Acc: 0.6749
#
# Epoch 180/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.0846 | Train Acc: 0.7500
# Validation Acc: 0.6754
#
# Epoch 181/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.0667 | Train Acc: 0.7494
# Validation Acc: 0.6708
#
# Epoch 182/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.0069 | Train Acc: 0.7511
# Validation Acc: 0.6741
#
# Epoch 183/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.8925 | Train Acc: 0.7508
# Validation Acc: 0.6756
#
# Epoch 184/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.2681 | Train Acc: 0.7491
# Validation Acc: 0.6744
#
# Epoch 185/300
#  [██████████████████████████████] 100.0%
# Train Loss: 85.0468 | Train Acc: 0.7493
# Validation Acc: 0.6686
#
# Epoch 186/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.9392 | Train Acc: 0.7492
# Validation Acc: 0.6739
#
# Epoch 187/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.7691 | Train Acc: 0.7515
# Validation Acc: 0.6745
#
# Epoch 188/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.3560 | Train Acc: 0.7513
# Validation Acc: 0.6681
#
# Epoch 189/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.1521 | Train Acc: 0.7519
# Validation Acc: 0.6736
#
# Epoch 190/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.2962 | Train Acc: 0.7521
# Validation Acc: 0.6733
#
# Epoch 191/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.4946 | Train Acc: 0.7513
# Validation Acc: 0.6718
#
# Epoch 192/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.1819 | Train Acc: 0.7528
# Validation Acc: 0.6796
#
# Epoch 193/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.0859 | Train Acc: 0.7534
# Validation Acc: 0.6713
#
# Epoch 194/300
#  [██████████████████████████████] 100.0%
# Train Loss: 84.1910 | Train Acc: 0.7535
# Validation Acc: 0.6679
#
# Epoch 195/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.8160 | Train Acc: 0.7537
# Validation Acc: 0.6785
#
# Epoch 196/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.9516 | Train Acc: 0.7511
# Validation Acc: 0.6729
#
# Epoch 197/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.7832 | Train Acc: 0.7533
# Validation Acc: 0.6674
#
# Epoch 198/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.7947 | Train Acc: 0.7535
# Validation Acc: 0.6676
#
# Epoch 199/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.6999 | Train Acc: 0.7544
# Validation Acc: 0.6704
#
# Epoch 200/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.8410 | Train Acc: 0.7545
# Validation Acc: 0.6722
#
# Epoch 201/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.6549 | Train Acc: 0.7531
# Validation Acc: 0.6723
#
# Epoch 202/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.5006 | Train Acc: 0.7548
# Validation Acc: 0.6705
#
# Epoch 203/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.4215 | Train Acc: 0.7552
# Validation Acc: 0.6688
#
# Epoch 204/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.5288 | Train Acc: 0.7551
# Validation Acc: 0.6695
#
# Epoch 205/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.3113 | Train Acc: 0.7567
# Validation Acc: 0.6773
#
# Epoch 206/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.1477 | Train Acc: 0.7560
# Validation Acc: 0.6734
#
# Epoch 207/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.3574 | Train Acc: 0.7543
# Validation Acc: 0.6685
#
# Epoch 208/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.8730 | Train Acc: 0.7565
# Validation Acc: 0.6730
#
# Epoch 209/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.9377 | Train Acc: 0.7571
# Validation Acc: 0.6674
#
# Epoch 210/300
#  [██████████████████████████████] 100.0%
# Train Loss: 83.1004 | Train Acc: 0.7558
# Validation Acc: 0.6690
#
# Epoch 211/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.7376 | Train Acc: 0.7570
# Validation Acc: 0.6743
#
# Epoch 212/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.6512 | Train Acc: 0.7575
# Validation Acc: 0.6706
#
# Epoch 213/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.4931 | Train Acc: 0.7573
# Validation Acc: 0.6649
#
# Epoch 214/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.5271 | Train Acc: 0.7567
# Validation Acc: 0.6689
#
# Epoch 215/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.6511 | Train Acc: 0.7581
# Validation Acc: 0.6737
#
# Epoch 216/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.7945 | Train Acc: 0.7580
# Validation Acc: 0.6744
#
# Epoch 217/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.6907 | Train Acc: 0.7566
# Validation Acc: 0.6662
#
# Epoch 218/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.5072 | Train Acc: 0.7579
# Validation Acc: 0.6698
#
# Epoch 219/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.2535 | Train Acc: 0.7590
# Validation Acc: 0.6717
#
# Epoch 220/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.0519 | Train Acc: 0.7598
# Validation Acc: 0.6734
#
# Epoch 221/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.0837 | Train Acc: 0.7594
# Validation Acc: 0.6707
#
# Epoch 222/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.9685 | Train Acc: 0.7597
# Validation Acc: 0.6719
#
# Epoch 223/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.0702 | Train Acc: 0.7590
# Validation Acc: 0.6678
#
# Epoch 224/300
#  [██████████████████████████████] 100.0%
# Train Loss: 82.1124 | Train Acc: 0.7578
# Validation Acc: 0.6729
#
# Epoch 225/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.9633 | Train Acc: 0.7599
# Validation Acc: 0.6721
#
# Epoch 226/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.8883 | Train Acc: 0.7607
# Validation Acc: 0.6732
#
# Epoch 227/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.6263 | Train Acc: 0.7605
# Validation Acc: 0.6652
#
# Epoch 228/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.6931 | Train Acc: 0.7595
# Validation Acc: 0.6671
#
# Epoch 229/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.5853 | Train Acc: 0.7595
# Validation Acc: 0.6704
#
# Epoch 230/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.7825 | Train Acc: 0.7599
# Validation Acc: 0.6737
#
# Epoch 231/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.6609 | Train Acc: 0.7594
# Validation Acc: 0.6696
#
# Epoch 232/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.5473 | Train Acc: 0.7608
# Validation Acc: 0.6717
#
# Epoch 233/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.3170 | Train Acc: 0.7617
# Validation Acc: 0.6689
#
# Epoch 234/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.3419 | Train Acc: 0.7595
# Validation Acc: 0.6679
#
# Epoch 235/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.1902 | Train Acc: 0.7627
# Validation Acc: 0.6696
#
# Epoch 236/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.1321 | Train Acc: 0.7635
# Validation Acc: 0.6685
#
# Epoch 237/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.3385 | Train Acc: 0.7617
# Validation Acc: 0.6651
#
# Epoch 238/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.3391 | Train Acc: 0.7622
# Validation Acc: 0.6701
#
# Epoch 239/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.2578 | Train Acc: 0.7606
# Validation Acc: 0.6725
#
# Epoch 240/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.4020 | Train Acc: 0.7609
# Validation Acc: 0.6696
#
# Epoch 241/300
#  [██████████████████████████████] 100.0%
# Train Loss: 81.0053 | Train Acc: 0.7623
# Validation Acc: 0.6639
#
# Epoch 242/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.8713 | Train Acc: 0.7618
# Validation Acc: 0.6661
#
# Epoch 243/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.7316 | Train Acc: 0.7628
# Validation Acc: 0.6651
#
# Epoch 244/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.9024 | Train Acc: 0.7619
# Validation Acc: 0.6676
#
# Epoch 245/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.5116 | Train Acc: 0.7637
# Validation Acc: 0.6731
#
# Epoch 246/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.7582 | Train Acc: 0.7631
# Validation Acc: 0.6696
#
# Epoch 247/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.6517 | Train Acc: 0.7639
# Validation Acc: 0.6656
#
# Epoch 248/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.6236 | Train Acc: 0.7631
# Validation Acc: 0.6629
#
# Epoch 249/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.5472 | Train Acc: 0.7644
# Validation Acc: 0.6653
#
# Epoch 250/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.2671 | Train Acc: 0.7641
# Validation Acc: 0.6681
#
# Epoch 251/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.2856 | Train Acc: 0.7658
# Validation Acc: 0.6613
#
# Epoch 252/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.2463 | Train Acc: 0.7629
# Validation Acc: 0.6711
#
# Epoch 253/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.2630 | Train Acc: 0.7655
# Validation Acc: 0.6704
#
# Epoch 254/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.2358 | Train Acc: 0.7646
# Validation Acc: 0.6699
#
# Epoch 255/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.8156 | Train Acc: 0.7654
# Validation Acc: 0.6697
#
# Epoch 256/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.1764 | Train Acc: 0.7660
# Validation Acc: 0.6630
#
# Epoch 257/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.2039 | Train Acc: 0.7642
# Validation Acc: 0.6654
#
# Epoch 258/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.0734 | Train Acc: 0.7656
# Validation Acc: 0.6678
#
# Epoch 259/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.2545 | Train Acc: 0.7653
# Validation Acc: 0.6670
#
# Epoch 260/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.8241 | Train Acc: 0.7655
# Validation Acc: 0.6629
#
# Epoch 261/300
#  [██████████████████████████████] 100.0%
# Train Loss: 80.0096 | Train Acc: 0.7642
# Validation Acc: 0.6692
#
# Epoch 262/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.7236 | Train Acc: 0.7653
# Validation Acc: 0.6692
#
# Epoch 263/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.7295 | Train Acc: 0.7664
# Validation Acc: 0.6696
#
# Epoch 264/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.5844 | Train Acc: 0.7675
# Validation Acc: 0.6662
#
# Epoch 265/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.7051 | Train Acc: 0.7682
# Validation Acc: 0.6679
#
# Epoch 266/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.3977 | Train Acc: 0.7681
# Validation Acc: 0.6666
#
# Epoch 267/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.4038 | Train Acc: 0.7674
# Validation Acc: 0.6654
#
# Epoch 268/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.4917 | Train Acc: 0.7671
# Validation Acc: 0.6669
#
# Epoch 269/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.5237 | Train Acc: 0.7668
# Validation Acc: 0.6675
#
# Epoch 270/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.3760 | Train Acc: 0.7682
# Validation Acc: 0.6713
#
# Epoch 271/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.4911 | Train Acc: 0.7675
# Validation Acc: 0.6693
#
# Epoch 272/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.5307 | Train Acc: 0.7659
# Validation Acc: 0.6663
#
# Epoch 273/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.3109 | Train Acc: 0.7659
# Validation Acc: 0.6602
#
# Epoch 274/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.7988 | Train Acc: 0.7656
# Validation Acc: 0.6687
#
# Epoch 275/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.1810 | Train Acc: 0.7683
# Validation Acc: 0.6689
#
# Epoch 276/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.0514 | Train Acc: 0.7689
# Validation Acc: 0.6702
#
# Epoch 277/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.9224 | Train Acc: 0.7689
# Validation Acc: 0.6687
#
# Epoch 278/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.9549 | Train Acc: 0.7684
# Validation Acc: 0.6671
#
# Epoch 279/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.8400 | Train Acc: 0.7694
# Validation Acc: 0.6621
#
# Epoch 280/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.7743 | Train Acc: 0.7686
# Validation Acc: 0.6658
#
# Epoch 281/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.7866 | Train Acc: 0.7710
# Validation Acc: 0.6657
#
# Epoch 282/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.6748 | Train Acc: 0.7698
# Validation Acc: 0.6690
#
# Epoch 283/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.9388 | Train Acc: 0.7678
# Validation Acc: 0.6670
#
# Epoch 284/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.7354 | Train Acc: 0.7702
# Validation Acc: 0.6701
#
# Epoch 285/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.8051 | Train Acc: 0.7701
# Validation Acc: 0.6668
#
# Epoch 286/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.8406 | Train Acc: 0.7673
# Validation Acc: 0.6637
#
# Epoch 287/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.7472 | Train Acc: 0.7694
# Validation Acc: 0.6655
#
# Epoch 288/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.5451 | Train Acc: 0.7702
# Validation Acc: 0.6681
#
# Epoch 289/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.5254 | Train Acc: 0.7703
# Validation Acc: 0.6650
#
# Epoch 290/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.7150 | Train Acc: 0.7705
# Validation Acc: 0.6653
#
# Epoch 291/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.8622 | Train Acc: 0.7685
# Validation Acc: 0.6645
#
# Epoch 292/300
#  [██████████████████████████████] 100.0%
# Train Loss: 79.0645 | Train Acc: 0.7679
# Validation Acc: 0.6654
#
# Epoch 293/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.0984 | Train Acc: 0.7725
# Validation Acc: 0.6713
#
# Epoch 294/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.3848 | Train Acc: 0.7699
# Validation Acc: 0.6692
#
# Epoch 295/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.0974 | Train Acc: 0.7712
# Validation Acc: 0.6671
#
# Epoch 296/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.1138 | Train Acc: 0.7710
# Validation Acc: 0.6647
#
# Epoch 297/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.3473 | Train Acc: 0.7706
# Validation Acc: 0.6654
#
# Epoch 298/300
#  [██████████████████████████████] 100.0%
# Train Loss: 77.8605 | Train Acc: 0.7726
# Validation Acc: 0.6629
#
# Epoch 299/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.0130 | Train Acc: 0.7718
# Validation Acc: 0.6670
#
# Epoch 300/300
#  [██████████████████████████████] 100.0%
# Train Loss: 78.1309 | Train Acc: 0.7706
# Validation Acc: 0.6679
#
# === Final Evaluation on Test Data ===
#
# Test Metrics:
# Accuracy : 0.6596
# F1 Score : 0.6581
# Precision: 0.6622
# Recall   : 0.6540
# AUC      : 0.7001
