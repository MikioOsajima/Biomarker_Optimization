# %%
# K-CV法を用いた心疾患予測モデルの学習と評価,マスクなしでの学習，BMIなし
import pandas as pd
import torch
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from torch.utils.data import Dataset, DataLoader
from tab_transformer_pytorch import TabTransformer
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import (
    accuracy_score, f1_score, precision_score,
    recall_score, roc_auc_score, roc_curve,
    confusion_matrix
)
import numpy as np
import sys
import matplotlib.pyplot as plt

# --------------------------------------------
# 定数設定
# --------------------------------------------
EPOCHS = 100
THRESHOLD = 0.73
BATCH_SIZE = 256
K_FOLDS = 5

# --------------------------------------------
# 0. デバイス設定
# --------------------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# --------------------------------------------
# 1. データ読み込み & 前処理
# --------------------------------------------

# データ読み込み
data = pd.read_csv("cardio_train.csv", sep=';')

# age_years のみ算出（BMI 削除）
data['age_years'] = (data['age'] / 365).astype(int)

# カテゴリ・連続量特徴量の定義
categorical_cols = ['gender', 'cholesterol', 'gluc', 'smoke', 'alco', 'active']
continuous_cols  = ['age_years', 'height', 'weight', 'ap_hi', 'ap_lo']
target_col = 'cardio'

# ラベルエンコーディング
from sklearn.preprocessing import LabelEncoder, StandardScaler
for col in categorical_cols:
    data[col] = LabelEncoder().fit_transform(data[col])

# 標準化
scaler = StandardScaler()
data[continuous_cols] = scaler.fit_transform(data[continuous_cols])


# --------------------------------------------
# 2. Dataset クラス定義
# --------------------------------------------
class CardioDataset(Dataset):
    def __init__(self, df):
        self.categ  = df[categorical_cols].values.astype(np.int64)
        self.cont   = df[continuous_cols].values.astype(np.float32)
        self.labels = df[target_col].values.astype(np.float32)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return (
            torch.tensor(self.categ[idx], dtype=torch.int64),
            torch.tensor(self.cont[idx],  dtype=torch.float32),
            torch.tensor(self.labels[idx], dtype=torch.float32),
        )

# --------------------------------------------
# 3. データ分割 (Train+Val / Test = 80/20)
# --------------------------------------------
train_val_data, test_data = train_test_split(data, test_size=0.2, random_state=42)
test_loader = DataLoader(CardioDataset(test_data), batch_size=BATCH_SIZE, shuffle=False)

# --------------------------------------------
# 4. 学習・検証ループ用関数定義
# --------------------------------------------
def train_with_validation(model, train_loader, val_loader, epochs, threshold):
    criterion = nn.BCEWithLogitsLoss()
    optimizer = optim.AdamW(model.parameters(), lr=1e-3)
    loss_history, train_acc_history, val_acc_history = [], [], []

    for epoch in range(1, epochs + 1):
        model.train()
        total_loss, correct, total = 0.0, 0, 0
        print(f"\nEpoch {epoch}/{epochs}")
        for batch_idx, (x_cat, x_cont, y) in enumerate(train_loader, 1):
            x_cat, x_cont, y = x_cat.to(device), x_cont.to(device), y.to(device)
            optimizer.zero_grad()
            out = model(x_cat, x_cont).squeeze(1)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            prob = torch.sigmoid(out)
            pred = (prob > 0.5).int()
            correct += (pred == y.int()).sum().item()
            total += y.size(0)
            # 進捗バー
            progress = batch_idx / len(train_loader) * 100
            bar_len = 30
            filled = int(bar_len * progress / 100)
            bar = '█' * filled + '-' * (bar_len - filled)
            sys.stdout.write(f"\r [{bar}] {progress:5.1f}%")
            sys.stdout.flush()

        loss_history.append(total_loss)
        train_acc_history.append(correct / total)
        print(f"\nTrain Loss: {total_loss:.4f} | Train Acc: {train_acc_history[-1]:.4f}")

        # 検証
        model.eval()
        val_preds, val_trues = [], []
        with torch.no_grad():
            for x_cat_v, x_cont_v, y_v in val_loader:
                x_cat_v, x_cont_v, y_v = x_cat_v.to(device), x_cont_v.to(device), y_v.to(device)
                out_v = model(x_cat_v, x_cont_v).squeeze(1)
                prob_v = torch.sigmoid(out_v)
                pred_v = (prob_v > 0.5).int()
                val_preds.extend(pred_v.cpu().tolist())
                val_trues.extend(y_v.cpu().int().tolist())

        val_acc = accuracy_score(val_trues, val_preds)
        val_acc_history.append(val_acc)
        print(f"Validation Acc: {val_acc:.4f}")

        if val_acc >= threshold:
            print(f"Threshold {threshold:.4f} reached at epoch {epoch}. Stopping training.")
            break

    return loss_history, train_acc_history, val_acc_history


# --------------------------------------------
# 5. テストデータ評価用関数定義
# --------------------------------------------
def evaluate_model(model, loader):
    model.eval()
    preds, trues, probs = [], [], []
    with torch.no_grad():
        for x_cat, x_cont, y in loader:
            x_cat, x_cont, y = x_cat.to(device), x_cont.to(device), y.to(device)
            out = model(x_cat, x_cont).squeeze(1)
            prob = torch.sigmoid(out)
            preds.extend((prob > 0.5).int().cpu().tolist())
            trues.extend(y.int().cpu().tolist())
            probs.extend(prob.cpu().tolist())

    print("\nTest Metrics:")
    print(f"Accuracy : {accuracy_score(trues, preds):.4f}")
    print(f"F1 Score : {f1_score(trues, preds):.4f}")
    print(f"Precision: {precision_score(trues, preds):.4f}")
    print(f"Recall   : {recall_score(trues, preds):.4f}")
    print(f"AUC      : {roc_auc_score(trues, probs):.4f}")


# --------------------------------------------
# 6. まとめて4つのグラフを描画＆保存する関数定義
# --------------------------------------------
# --------------------------------------------
# 8. K-Fold Cross Validation
# --------------------------------------------
kf = KFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
fold_scores = []
for fold, (train_idx, val_idx) in enumerate(kf.split(train_val_data), 1):
    print(f"\n=== Fold {fold}/{K_FOLDS} ===")
    train_df = train_val_data.iloc[train_idx].reset_index(drop=True)
    val_df   = train_val_data.iloc[val_idx].reset_index(drop=True)

    train_loader = DataLoader(CardioDataset(train_df), batch_size=BATCH_SIZE, shuffle=True)
    val_loader   = DataLoader(CardioDataset(val_df),   batch_size=BATCH_SIZE, shuffle=False)

    # モデル初期化
    cont_mean_std = torch.tensor([[0., 1.]] * len(continuous_cols)).to(device)
    model = TabTransformer(
        categories=tuple(data[col].nunique() for col in categorical_cols),
        num_continuous=len(continuous_cols),
        dim=32, dim_out=1, depth=4, heads=4,
        attn_dropout=0.1, ff_dropout=0.1,
        mlp_hidden_mults=(4, 2), mlp_act=nn.ReLU(),
        continuous_mean_std=cont_mean_std
    ).to(device)
    model.categories_offset = model.categories_offset.to(device)

    _, _, val_accs = train_with_validation(
        model,
        DataLoader(CardioDataset(train_df), batch_size=BATCH_SIZE, shuffle=True),
        DataLoader(CardioDataset(val_df),   batch_size=BATCH_SIZE, shuffle=False),
        EPOCHS, THRESHOLD
    )
    fold_scores.append(val_accs[-1])

mean_acc = np.mean(fold_scores)
std_acc  = np.std(fold_scores)
print(f"\nK-Fold CV Result (K={K_FOLDS}): Mean Val Acc = {mean_acc:.4f}, Std = {std_acc:.4f}")


# --------------------------------------------
# 9. 全訓練データでの最終学習 → 履歴取得
# --------------------------------------------
final_train_df, final_val_df = train_test_split(train_val_data, test_size=0.2, random_state=42)
final_train_loader = DataLoader(CardioDataset(final_train_df), batch_size=BATCH_SIZE, shuffle=True)
final_val_loader   = DataLoader(CardioDataset(final_val_df),   batch_size=BATCH_SIZE, shuffle=False)

cont_mean_std = torch.tensor([[0., 1.]] * len(continuous_cols)).to(device)
final_model = TabTransformer(
    categories=tuple(data[col].nunique() for col in categorical_cols),
    num_continuous=len(continuous_cols),
    dim=32, dim_out=1, depth=4, heads=4,
    attn_dropout=0.1, ff_dropout=0.1,
    mlp_hidden_mults=(4, 2), mlp_act=nn.ReLU(),
    continuous_mean_std=cont_mean_std
).to(device)
final_model.categories_offset = final_model.categories_offset.to(device)

# 学習＆履歴取得
loss_history, train_acc_history, val_acc_history = train_with_validation(
    final_model, final_train_loader, final_val_loader, EPOCHS, THRESHOLD
)
# --------------------------------------------
# 7. 学習曲線プロット
# --------------------------------------------
def plot_all_metrics(losses, train_accs, val_accs, model, loader):
    # 1) データ収集
    preds, trues, probs = [], [], []
    model.eval()
    with torch.no_grad():
        for x_cat, x_cont, y in loader:
            x_cat, x_cont, y = x_cat.to(device), x_cont.to(device), y.to(device)
            out = model(x_cat, x_cont).squeeze(1)
            p = torch.sigmoid(out)
            preds.extend((p > 0.5).int().cpu().tolist())
            trues.extend(y.int().cpu().tolist())
            probs.extend(p.cpu().tolist())

    # 指標計算
    cm    = confusion_matrix(trues, preds)
    fpr, tpr, _ = roc_curve(trues, probs)
    auc   = roc_auc_score(trues, probs)
    acc   = accuracy_score(trues, preds)
    f1    = f1_score(trues, preds)
    prec  = precision_score(trues, preds)
    rec   = recall_score(trues, preds)
    epochs = range(1, len(losses) + 1)

    # 2×2 レイアウト作成
    fig, axes = plt.subplots(2, 2, figsize=(12, 10))

    # (0,0) Training Loss
    ax00 = axes[0, 0]
    ax00.plot(epochs, losses, marker='o')
    ax00.set_title('Training Loss')
    ax00.set_xlabel('Epoch'); ax00.set_ylabel('Loss')
    ax00.grid(True)

    # (0,1) Accuracy 曲線
    ax01 = axes[0, 1]
    ax01.plot(epochs, train_accs, marker='o', label='Train Acc')
    ax01.plot(epochs, val_accs,   marker='x', label='Val Acc')
    ax01.set_title('Accuracy')
    ax01.set_xlabel('Epoch'); ax01.set_ylabel('Accuracy')
    ax01.legend(); ax01.grid(True)

    # (1,0) Confusion Matrix
    ax10 = axes[1, 0]
    im = ax10.imshow(cm, cmap='Blues')
    classes = ['No Cardio', 'Cardio']
    ax10.set_xticks(np.arange(len(classes)))
    ax10.set_xticklabels(classes)
    ax10.set_yticks(np.arange(len(classes)))
    ax10.set_yticklabels(classes)
    ax10.set_title('Confusion Matrix')
    ax10.set_xlabel('Predicted'); ax10.set_ylabel('True')
    for (i, j), v in np.ndenumerate(cm):
        ax10.text(
            j, i, f"{v}",
            ha='center', va='center',
            color='white' if v > cm.max()/2 else 'black'
        )
    fig.colorbar(im, ax=ax10)

    # (1,1) ROC Curve + 指標テキスト
    ax11 = axes[1, 1]
    ax11.plot(fpr, tpr, label=f'AUC = {auc:.3f}')
    ax11.plot([0, 1], [0, 1], 'k--')
    ax11.set_title('ROC Curve'); ax11.set_xlabel('FPR'); ax11.set_ylabel('TPR')
    ax11.legend(loc='lower right')
    metrics_text = (
        f"Acc : {acc:.3f}\n"
        f"F1  : {f1:.3f}\n"
        f"Prec: {prec:.3f}\n"
        f"Rec : {rec:.3f}"
    )
    ax11.text(
        0.05, 0.05, metrics_text,
        transform=ax11.transAxes,
        fontsize=10,
        verticalalignment='bottom',
        bbox=dict(facecolor='white', alpha=0.6, edgecolor='gray')
    )

    plt.tight_layout()
    # 保存
    fname = f"output2/Nomask Epoch:{EPOCHS}_all.png"
    fig.savefig(fname, dpi=300)
    plt.show()


# --------------------------------------------
# 9. テストデータで最終評価 + まとめて４プロット
# --------------------------------------------
print("\n=== Final Evaluation on Test Data ===")
evaluate_model(final_model, test_loader)

# ここで一発描画＆保存
plot_all_metrics(
    loss_history,
    train_acc_history,
    val_acc_history,
    final_model,
    test_loader
)
# Out:
# Using device: cuda
#
# === Fold 1/5 ===
#
# Epoch 1/100
#  [██████████████████████████████] 100.0%
# Train Loss: 117.6388 | Train Acc: 0.5971
# Validation Acc: 0.6337
#
# Epoch 2/100
#  [██████████████████████████████] 100.0%
# Train Loss: 113.0813 | Train Acc: 0.6222
# Validation Acc: 0.6250
#
# Epoch 3/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.8905 | Train Acc: 0.6275
# Validation Acc: 0.6319
#
# Epoch 4/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.7896 | Train Acc: 0.6269
# Validation Acc: 0.6302
#
# Epoch 5/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.5844 | Train Acc: 0.6303
# Validation Acc: 0.6297
#
# Epoch 6/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.3728 | Train Acc: 0.6317
# Validation Acc: 0.6387
#
# Epoch 7/100
#  [██████████████████████████████] 100.0%
# Train Loss: 111.5820 | Train Acc: 0.6354
# Validation Acc: 0.6600
#
# Epoch 8/100
#  [██████████████████████████████] 100.0%
# Train Loss: 107.8579 | Train Acc: 0.6621
# Validation Acc: 0.6859
#
# Epoch 9/100
#  [██████████████████████████████] 100.0%
# Train Loss: 105.6569 | Train Acc: 0.6771
# Validation Acc: 0.6910
#
# Epoch 10/100
#  [██████████████████████████████] 100.0%
# Train Loss: 105.0157 | Train Acc: 0.6808
# Validation Acc: 0.6900
#
# Epoch 11/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.9936 | Train Acc: 0.6854
# Validation Acc: 0.6962
#
# Epoch 12/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.9580 | Train Acc: 0.6866
# Validation Acc: 0.6971
#
# Epoch 13/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.3784 | Train Acc: 0.6873
# Validation Acc: 0.6947
#
# Epoch 14/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.4853 | Train Acc: 0.6881
# Validation Acc: 0.7010
#
# Epoch 15/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.2361 | Train Acc: 0.6878
# Validation Acc: 0.6910
#
# Epoch 16/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.3731 | Train Acc: 0.6869
# Validation Acc: 0.6948
#
# Epoch 17/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.0850 | Train Acc: 0.6875
# Validation Acc: 0.6976
#
# Epoch 18/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.7968 | Train Acc: 0.6898
# Validation Acc: 0.6963
#
# Epoch 19/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.8112 | Train Acc: 0.6888
# Validation Acc: 0.6984
#
# Epoch 20/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.7351 | Train Acc: 0.6899
# Validation Acc: 0.6971
#
# Epoch 21/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.7672 | Train Acc: 0.6923
# Validation Acc: 0.6979
#
# Epoch 22/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.5410 | Train Acc: 0.6922
# Validation Acc: 0.6977
#
# Epoch 23/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.5534 | Train Acc: 0.6913
# Validation Acc: 0.6988
#
# Epoch 24/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.4160 | Train Acc: 0.6916
# Validation Acc: 0.6990
#
# Epoch 25/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.3427 | Train Acc: 0.6922
# Validation Acc: 0.6959
#
# Epoch 26/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.3159 | Train Acc: 0.6932
# Validation Acc: 0.7022
#
# Epoch 27/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.4241 | Train Acc: 0.6917
# Validation Acc: 0.6961
#
# Epoch 28/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.0812 | Train Acc: 0.6944
# Validation Acc: 0.6981
#
# Epoch 29/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.2614 | Train Acc: 0.6926
# Validation Acc: 0.6953
#
# Epoch 30/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.9532 | Train Acc: 0.6941
# Validation Acc: 0.6967
#
# Epoch 31/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.0895 | Train Acc: 0.6926
# Validation Acc: 0.6983
#
# Epoch 32/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.9705 | Train Acc: 0.6938
# Validation Acc: 0.6971
#
# Epoch 33/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.8156 | Train Acc: 0.6942
# Validation Acc: 0.6988
#
# Epoch 34/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.7720 | Train Acc: 0.6970
# Validation Acc: 0.6987
#
# Epoch 35/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.8216 | Train Acc: 0.6937
# Validation Acc: 0.6995
#
# Epoch 36/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.6344 | Train Acc: 0.6952
# Validation Acc: 0.6948
#
# Epoch 37/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.5572 | Train Acc: 0.6954
# Validation Acc: 0.6947
#
# Epoch 38/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.5449 | Train Acc: 0.6965
# Validation Acc: 0.6979
#
# Epoch 39/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.5376 | Train Acc: 0.6968
# Validation Acc: 0.6987
#
# Epoch 40/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.2784 | Train Acc: 0.6969
# Validation Acc: 0.6953
#
# Epoch 41/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.2815 | Train Acc: 0.6964
# Validation Acc: 0.7013
#
# Epoch 42/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.2056 | Train Acc: 0.6965
# Validation Acc: 0.6934
#
# Epoch 43/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.1048 | Train Acc: 0.6973
# Validation Acc: 0.6932
#
# Epoch 44/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.9931 | Train Acc: 0.6978
# Validation Acc: 0.6978
#
# Epoch 45/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.1004 | Train Acc: 0.6972
# Validation Acc: 0.6972
#
# Epoch 46/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.8746 | Train Acc: 0.6983
# Validation Acc: 0.6930
#
# Epoch 47/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.7877 | Train Acc: 0.6988
# Validation Acc: 0.6954
#
# Epoch 48/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.8475 | Train Acc: 0.6979
# Validation Acc: 0.6961
#
# Epoch 49/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.5975 | Train Acc: 0.6984
# Validation Acc: 0.6946
#
# Epoch 50/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.5716 | Train Acc: 0.7006
# Validation Acc: 0.6954
#
# Epoch 51/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.5103 | Train Acc: 0.7008
# Validation Acc: 0.6961
#
# Epoch 52/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.2476 | Train Acc: 0.6997
# Validation Acc: 0.6941
#
# Epoch 53/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.3330 | Train Acc: 0.7012
# Validation Acc: 0.6951
#
# Epoch 54/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.1298 | Train Acc: 0.7003
# Validation Acc: 0.6970
#
# Epoch 55/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.0333 | Train Acc: 0.7013
# Validation Acc: 0.6943
#
# Epoch 56/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.9833 | Train Acc: 0.7016
# Validation Acc: 0.6919
#
# Epoch 57/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.8870 | Train Acc: 0.7018
# Validation Acc: 0.6935
#
# Epoch 58/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.7505 | Train Acc: 0.7029
# Validation Acc: 0.6913
#
# Epoch 59/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.6807 | Train Acc: 0.7034
# Validation Acc: 0.6935
#
# Epoch 60/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.7348 | Train Acc: 0.7030
# Validation Acc: 0.6946
#
# Epoch 61/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.5049 | Train Acc: 0.7028
# Validation Acc: 0.6941
#
# Epoch 62/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.5156 | Train Acc: 0.7041
# Validation Acc: 0.6960
#
# Epoch 63/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.2369 | Train Acc: 0.7043
# Validation Acc: 0.6938
#
# Epoch 64/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.4162 | Train Acc: 0.7030
# Validation Acc: 0.6952
#
# Epoch 65/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.0161 | Train Acc: 0.7070
# Validation Acc: 0.6943
#
# Epoch 66/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.8881 | Train Acc: 0.7068
# Validation Acc: 0.6929
#
# Epoch 67/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.8140 | Train Acc: 0.7077
# Validation Acc: 0.6930
#
# Epoch 68/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.8238 | Train Acc: 0.7082
# Validation Acc: 0.6904
#
# Epoch 69/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.6268 | Train Acc: 0.7069
# Validation Acc: 0.6924
#
# Epoch 70/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.4410 | Train Acc: 0.7068
# Validation Acc: 0.6892
#
# Epoch 71/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.4052 | Train Acc: 0.7075
# Validation Acc: 0.6900
#
# Epoch 72/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.2246 | Train Acc: 0.7103
# Validation Acc: 0.6958
#
# Epoch 73/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.1520 | Train Acc: 0.7088
# Validation Acc: 0.6911
#
# Epoch 74/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.0279 | Train Acc: 0.7101
# Validation Acc: 0.6929
#
# Epoch 75/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.9874 | Train Acc: 0.7094
# Validation Acc: 0.6929
#
# Epoch 76/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.7616 | Train Acc: 0.7084
# Validation Acc: 0.6899
#
# Epoch 77/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.6902 | Train Acc: 0.7107
# Validation Acc: 0.6889
#
# Epoch 78/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.5775 | Train Acc: 0.7107
# Validation Acc: 0.6952
#
# Epoch 79/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.5089 | Train Acc: 0.7102
# Validation Acc: 0.6936
#
# Epoch 80/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.2912 | Train Acc: 0.7107
# Validation Acc: 0.6887
#
# Epoch 81/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.1278 | Train Acc: 0.7125
# Validation Acc: 0.6879
#
# Epoch 82/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.1330 | Train Acc: 0.7115
# Validation Acc: 0.6944
#
# Epoch 83/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.8712 | Train Acc: 0.7128
# Validation Acc: 0.6917
#
# Epoch 84/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.8943 | Train Acc: 0.7145
# Validation Acc: 0.6878
#
# Epoch 85/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.5087 | Train Acc: 0.7142
# Validation Acc: 0.6901
#
# Epoch 86/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.5323 | Train Acc: 0.7129
# Validation Acc: 0.6896
#
# Epoch 87/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.4257 | Train Acc: 0.7138
# Validation Acc: 0.6901
#
# Epoch 88/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.2628 | Train Acc: 0.7157
# Validation Acc: 0.6920
#
# Epoch 89/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.2761 | Train Acc: 0.7139
# Validation Acc: 0.6929
#
# Epoch 90/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.9587 | Train Acc: 0.7157
# Validation Acc: 0.6896
#
# Epoch 91/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.9063 | Train Acc: 0.7161
# Validation Acc: 0.6912
#
# Epoch 92/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.7523 | Train Acc: 0.7166
# Validation Acc: 0.6907
#
# Epoch 93/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.5806 | Train Acc: 0.7163
# Validation Acc: 0.6878
#
# Epoch 94/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.3815 | Train Acc: 0.7173
# Validation Acc: 0.6932
#
# Epoch 95/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.3992 | Train Acc: 0.7165
# Validation Acc: 0.6907
#
# Epoch 96/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.1916 | Train Acc: 0.7185
# Validation Acc: 0.6919
#
# Epoch 97/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.1225 | Train Acc: 0.7190
# Validation Acc: 0.6853
#
# Epoch 98/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.0202 | Train Acc: 0.7196
# Validation Acc: 0.6906
#
# Epoch 99/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.8772 | Train Acc: 0.7202
# Validation Acc: 0.6884
#
# Epoch 100/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.8489 | Train Acc: 0.7194
# Validation Acc: 0.6834
#
# === Fold 2/5 ===
#
# Epoch 1/100
#  [██████████████████████████████] 100.0%
# Train Loss: 116.0985 | Train Acc: 0.6079
# Validation Acc: 0.6182
#
# Epoch 2/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.8807 | Train Acc: 0.6232
# Validation Acc: 0.6210
#
# Epoch 3/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.4740 | Train Acc: 0.6277
# Validation Acc: 0.6183
#
# Epoch 4/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.3589 | Train Acc: 0.6297
# Validation Acc: 0.6183
#
# Epoch 5/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.4231 | Train Acc: 0.6301
# Validation Acc: 0.6285
#
# Epoch 6/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.0095 | Train Acc: 0.6337
# Validation Acc: 0.6279
#
# Epoch 7/100
#  [██████████████████████████████] 100.0%
# Train Loss: 111.1509 | Train Acc: 0.6381
# Validation Acc: 0.6468
#
# Epoch 8/100
#  [██████████████████████████████] 100.0%
# Train Loss: 107.7674 | Train Acc: 0.6611
# Validation Acc: 0.6632
#
# Epoch 9/100
#  [██████████████████████████████] 100.0%
# Train Loss: 105.3931 | Train Acc: 0.6791
# Validation Acc: 0.6697
#
# Epoch 10/100
#  [██████████████████████████████] 100.0%
# Train Loss: 104.3510 | Train Acc: 0.6860
# Validation Acc: 0.6746
#
# Epoch 11/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.7503 | Train Acc: 0.6890
# Validation Acc: 0.6824
#
# Epoch 12/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.9778 | Train Acc: 0.6883
# Validation Acc: 0.6840
#
# Epoch 13/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.0601 | Train Acc: 0.6897
# Validation Acc: 0.6854
#
# Epoch 14/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.7411 | Train Acc: 0.6919
# Validation Acc: 0.6846
#
# Epoch 15/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.7055 | Train Acc: 0.6920
# Validation Acc: 0.6856
#
# Epoch 16/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.4729 | Train Acc: 0.6931
# Validation Acc: 0.6871
#
# Epoch 17/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.3344 | Train Acc: 0.6936
# Validation Acc: 0.6885
#
# Epoch 18/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.4897 | Train Acc: 0.6920
# Validation Acc: 0.6859
#
# Epoch 19/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.2280 | Train Acc: 0.6939
# Validation Acc: 0.6853
#
# Epoch 20/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.2549 | Train Acc: 0.6938
# Validation Acc: 0.6846
#
# Epoch 21/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.1853 | Train Acc: 0.6939
# Validation Acc: 0.6850
#
# Epoch 22/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.2377 | Train Acc: 0.6918
# Validation Acc: 0.6862
#
# Epoch 23/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.8679 | Train Acc: 0.6940
# Validation Acc: 0.6879
#
# Epoch 24/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.9025 | Train Acc: 0.6937
# Validation Acc: 0.6867
#
# Epoch 25/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.7970 | Train Acc: 0.6944
# Validation Acc: 0.6850
#
# Epoch 26/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.6752 | Train Acc: 0.6947
# Validation Acc: 0.6859
#
# Epoch 27/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.7313 | Train Acc: 0.6955
# Validation Acc: 0.6859
#
# Epoch 28/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.5465 | Train Acc: 0.6959
# Validation Acc: 0.6843
#
# Epoch 29/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.6033 | Train Acc: 0.6957
# Validation Acc: 0.6884
#
# Epoch 30/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.6448 | Train Acc: 0.6973
# Validation Acc: 0.6872
#
# Epoch 31/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.3738 | Train Acc: 0.6975
# Validation Acc: 0.6827
#
# Epoch 32/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.2969 | Train Acc: 0.6978
# Validation Acc: 0.6879
#
# Epoch 33/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.3073 | Train Acc: 0.6969
# Validation Acc: 0.6863
#
# Epoch 34/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.0981 | Train Acc: 0.6970
# Validation Acc: 0.6896
#
# Epoch 35/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.1184 | Train Acc: 0.6969
# Validation Acc: 0.6841
#
# Epoch 36/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.9623 | Train Acc: 0.6977
# Validation Acc: 0.6841
#
# Epoch 37/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.1065 | Train Acc: 0.6978
# Validation Acc: 0.6858
#
# Epoch 38/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.0111 | Train Acc: 0.6971
# Validation Acc: 0.6865
#
# Epoch 39/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.7984 | Train Acc: 0.6992
# Validation Acc: 0.6851
#
# Epoch 40/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.7060 | Train Acc: 0.6980
# Validation Acc: 0.6815
#
# Epoch 41/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.7848 | Train Acc: 0.6983
# Validation Acc: 0.6846
#
# Epoch 42/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.5230 | Train Acc: 0.6996
# Validation Acc: 0.6830
#
# Epoch 43/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.6146 | Train Acc: 0.6994
# Validation Acc: 0.6847
#
# Epoch 44/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.3232 | Train Acc: 0.7007
# Validation Acc: 0.6834
#
# Epoch 45/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.2815 | Train Acc: 0.7014
# Validation Acc: 0.6849
#
# Epoch 46/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.1172 | Train Acc: 0.7019
# Validation Acc: 0.6860
#
# Epoch 47/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.1833 | Train Acc: 0.7012
# Validation Acc: 0.6820
#
# Epoch 48/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.0035 | Train Acc: 0.7014
# Validation Acc: 0.6860
#
# Epoch 49/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.8544 | Train Acc: 0.7021
# Validation Acc: 0.6826
#
# Epoch 50/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.8247 | Train Acc: 0.7020
# Validation Acc: 0.6840
#
# Epoch 51/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.6856 | Train Acc: 0.7042
# Validation Acc: 0.6806
#
# Epoch 52/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.6465 | Train Acc: 0.7040
# Validation Acc: 0.6811
#
# Epoch 53/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.5469 | Train Acc: 0.7028
# Validation Acc: 0.6826
#
# Epoch 54/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.2421 | Train Acc: 0.7053
# Validation Acc: 0.6834
#
# Epoch 55/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.3424 | Train Acc: 0.7050
# Validation Acc: 0.6845
#
# Epoch 56/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.2604 | Train Acc: 0.7046
# Validation Acc: 0.6796
#
# Epoch 57/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.1236 | Train Acc: 0.7053
# Validation Acc: 0.6846
#
# Epoch 58/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.9513 | Train Acc: 0.7057
# Validation Acc: 0.6806
#
# Epoch 59/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.7004 | Train Acc: 0.7062
# Validation Acc: 0.6833
#
# Epoch 60/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.6293 | Train Acc: 0.7072
# Validation Acc: 0.6808
#
# Epoch 61/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.3822 | Train Acc: 0.7072
# Validation Acc: 0.6814
#
# Epoch 62/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.5170 | Train Acc: 0.7071
# Validation Acc: 0.6820
#
# Epoch 63/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.3735 | Train Acc: 0.7069
# Validation Acc: 0.6853
#
# Epoch 64/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.1117 | Train Acc: 0.7092
# Validation Acc: 0.6836
#
# Epoch 65/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.1023 | Train Acc: 0.7083
# Validation Acc: 0.6837
#
# Epoch 66/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.7417 | Train Acc: 0.7103
# Validation Acc: 0.6815
#
# Epoch 67/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.6517 | Train Acc: 0.7104
# Validation Acc: 0.6810
#
# Epoch 68/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.4362 | Train Acc: 0.7100
# Validation Acc: 0.6821
#
# Epoch 69/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.5690 | Train Acc: 0.7105
# Validation Acc: 0.6840
#
# Epoch 70/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.3333 | Train Acc: 0.7106
# Validation Acc: 0.6817
#
# Epoch 71/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.3149 | Train Acc: 0.7105
# Validation Acc: 0.6829
#
# Epoch 72/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.1334 | Train Acc: 0.7132
# Validation Acc: 0.6787
#
# Epoch 73/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.0368 | Train Acc: 0.7109
# Validation Acc: 0.6806
#
# Epoch 74/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.7743 | Train Acc: 0.7135
# Validation Acc: 0.6845
#
# Epoch 75/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.7975 | Train Acc: 0.7124
# Validation Acc: 0.6775
#
# Epoch 76/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.5977 | Train Acc: 0.7127
# Validation Acc: 0.6760
#
# Epoch 77/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.4607 | Train Acc: 0.7147
# Validation Acc: 0.6746
#
# Epoch 78/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.2646 | Train Acc: 0.7154
# Validation Acc: 0.6784
#
# Epoch 79/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.1552 | Train Acc: 0.7148
# Validation Acc: 0.6766
#
# Epoch 80/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.9407 | Train Acc: 0.7160
# Validation Acc: 0.6790
#
# Epoch 81/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.0758 | Train Acc: 0.7151
# Validation Acc: 0.6802
#
# Epoch 82/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.7533 | Train Acc: 0.7175
# Validation Acc: 0.6794
#
# Epoch 83/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.4758 | Train Acc: 0.7186
# Validation Acc: 0.6771
#
# Epoch 84/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.5589 | Train Acc: 0.7165
# Validation Acc: 0.6787
#
# Epoch 85/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.3558 | Train Acc: 0.7188
# Validation Acc: 0.6814
#
# Epoch 86/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.1775 | Train Acc: 0.7186
# Validation Acc: 0.6778
#
# Epoch 87/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.1329 | Train Acc: 0.7193
# Validation Acc: 0.6790
#
# Epoch 88/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.8921 | Train Acc: 0.7190
# Validation Acc: 0.6803
#
# Epoch 89/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.6785 | Train Acc: 0.7202
# Validation Acc: 0.6796
#
# Epoch 90/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.6790 | Train Acc: 0.7200
# Validation Acc: 0.6749
#
# Epoch 91/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.7278 | Train Acc: 0.7184
# Validation Acc: 0.6794
#
# Epoch 92/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.4706 | Train Acc: 0.7210
# Validation Acc: 0.6782
#
# Epoch 93/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.3343 | Train Acc: 0.7209
# Validation Acc: 0.6777
#
# Epoch 94/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.1504 | Train Acc: 0.7224
# Validation Acc: 0.6789
#
# Epoch 95/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.2204 | Train Acc: 0.7212
# Validation Acc: 0.6753
#
# Epoch 96/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.0414 | Train Acc: 0.7230
# Validation Acc: 0.6748
#
# Epoch 97/100
#  [██████████████████████████████] 100.0%
# Train Loss: 93.7354 | Train Acc: 0.7248
# Validation Acc: 0.6749
#
# Epoch 98/100
#  [██████████████████████████████] 100.0%
# Train Loss: 93.6686 | Train Acc: 0.7219
# Validation Acc: 0.6781
#
# Epoch 99/100
#  [██████████████████████████████] 100.0%
# Train Loss: 93.5124 | Train Acc: 0.7240
# Validation Acc: 0.6754
#
# Epoch 100/100
#  [██████████████████████████████] 100.0%
# Train Loss: 93.4275 | Train Acc: 0.7235
# Validation Acc: 0.6773
#
# === Fold 3/5 ===
#
# Epoch 1/100
#  [██████████████████████████████] 100.0%
# Train Loss: 116.2225 | Train Acc: 0.6043
# Validation Acc: 0.6289
#
# Epoch 2/100
#  [██████████████████████████████] 100.0%
# Train Loss: 113.0613 | Train Acc: 0.6242
# Validation Acc: 0.6291
#
# Epoch 3/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.7614 | Train Acc: 0.6276
# Validation Acc: 0.6288
#
# Epoch 4/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.5899 | Train Acc: 0.6273
# Validation Acc: 0.6314
#
# Epoch 5/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.2629 | Train Acc: 0.6324
# Validation Acc: 0.6371
#
# Epoch 6/100
#  [██████████████████████████████] 100.0%
# Train Loss: 110.7073 | Train Acc: 0.6430
# Validation Acc: 0.6591
#
# Epoch 7/100
#  [██████████████████████████████] 100.0%
# Train Loss: 106.5516 | Train Acc: 0.6713
# Validation Acc: 0.6757
#
# Epoch 8/100
#  [██████████████████████████████] 100.0%
# Train Loss: 104.9303 | Train Acc: 0.6817
# Validation Acc: 0.6725
#
# Epoch 9/100
#  [██████████████████████████████] 100.0%
# Train Loss: 104.0460 | Train Acc: 0.6860
# Validation Acc: 0.6836
#
# Epoch 10/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.5831 | Train Acc: 0.6874
# Validation Acc: 0.6828
#
# Epoch 11/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.1935 | Train Acc: 0.6891
# Validation Acc: 0.6829
#
# Epoch 12/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.1000 | Train Acc: 0.6901
# Validation Acc: 0.6816
#
# Epoch 13/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.8164 | Train Acc: 0.6924
# Validation Acc: 0.6850
#
# Epoch 14/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.7088 | Train Acc: 0.6909
# Validation Acc: 0.6804
#
# Epoch 15/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.4401 | Train Acc: 0.6923
# Validation Acc: 0.6858
#
# Epoch 16/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.5748 | Train Acc: 0.6919
# Validation Acc: 0.6856
#
# Epoch 17/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.5011 | Train Acc: 0.6919
# Validation Acc: 0.6821
#
# Epoch 18/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.2686 | Train Acc: 0.6938
# Validation Acc: 0.6845
#
# Epoch 19/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.1453 | Train Acc: 0.6943
# Validation Acc: 0.6808
#
# Epoch 20/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.0983 | Train Acc: 0.6949
# Validation Acc: 0.6853
#
# Epoch 21/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.0854 | Train Acc: 0.6941
# Validation Acc: 0.6866
#
# Epoch 22/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.8940 | Train Acc: 0.6951
# Validation Acc: 0.6829
#
# Epoch 23/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.0462 | Train Acc: 0.6938
# Validation Acc: 0.6815
#
# Epoch 24/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.9144 | Train Acc: 0.6956
# Validation Acc: 0.6868
#
# Epoch 25/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.6930 | Train Acc: 0.6953
# Validation Acc: 0.6827
#
# Epoch 26/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.6644 | Train Acc: 0.6951
# Validation Acc: 0.6854
#
# Epoch 27/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.5827 | Train Acc: 0.6963
# Validation Acc: 0.6836
#
# Epoch 28/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.6314 | Train Acc: 0.6952
# Validation Acc: 0.6873
#
# Epoch 29/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.6279 | Train Acc: 0.6962
# Validation Acc: 0.6843
#
# Epoch 30/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.4278 | Train Acc: 0.6977
# Validation Acc: 0.6871
#
# Epoch 31/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.4913 | Train Acc: 0.6973
# Validation Acc: 0.6863
#
# Epoch 32/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.4332 | Train Acc: 0.6974
# Validation Acc: 0.6896
#
# Epoch 33/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.1753 | Train Acc: 0.6964
# Validation Acc: 0.6834
#
# Epoch 34/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.2472 | Train Acc: 0.6976
# Validation Acc: 0.6862
#
# Epoch 35/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.1597 | Train Acc: 0.6965
# Validation Acc: 0.6829
#
# Epoch 36/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.2123 | Train Acc: 0.6963
# Validation Acc: 0.6858
#
# Epoch 37/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.0028 | Train Acc: 0.6988
# Validation Acc: 0.6837
#
# Epoch 38/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.7911 | Train Acc: 0.6985
# Validation Acc: 0.6852
#
# Epoch 39/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.9673 | Train Acc: 0.6992
# Validation Acc: 0.6848
#
# Epoch 40/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.7278 | Train Acc: 0.6977
# Validation Acc: 0.6790
#
# Epoch 41/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.7068 | Train Acc: 0.6979
# Validation Acc: 0.6831
#
# Epoch 42/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.5123 | Train Acc: 0.6996
# Validation Acc: 0.6832
#
# Epoch 43/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.5716 | Train Acc: 0.7006
# Validation Acc: 0.6839
#
# Epoch 44/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.4108 | Train Acc: 0.7003
# Validation Acc: 0.6833
#
# Epoch 45/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.3430 | Train Acc: 0.7001
# Validation Acc: 0.6863
#
# Epoch 46/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.3025 | Train Acc: 0.7013
# Validation Acc: 0.6822
#
# Epoch 47/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.1434 | Train Acc: 0.7006
# Validation Acc: 0.6831
#
# Epoch 48/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.1299 | Train Acc: 0.7016
# Validation Acc: 0.6863
#
# Epoch 49/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.0538 | Train Acc: 0.7023
# Validation Acc: 0.6855
#
# Epoch 50/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.9690 | Train Acc: 0.7029
# Validation Acc: 0.6846
#
# Epoch 51/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.7453 | Train Acc: 0.7042
# Validation Acc: 0.6853
#
# Epoch 52/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.9128 | Train Acc: 0.7029
# Validation Acc: 0.6833
#
# Epoch 53/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.7852 | Train Acc: 0.7036
# Validation Acc: 0.6841
#
# Epoch 54/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.4453 | Train Acc: 0.7031
# Validation Acc: 0.6818
#
# Epoch 55/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.2728 | Train Acc: 0.7047
# Validation Acc: 0.6833
#
# Epoch 56/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.3318 | Train Acc: 0.7037
# Validation Acc: 0.6822
#
# Epoch 57/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.2900 | Train Acc: 0.7051
# Validation Acc: 0.6813
#
# Epoch 58/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.0614 | Train Acc: 0.7054
# Validation Acc: 0.6793
#
# Epoch 59/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.0169 | Train Acc: 0.7056
# Validation Acc: 0.6854
#
# Epoch 60/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.9595 | Train Acc: 0.7042
# Validation Acc: 0.6824
#
# Epoch 61/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.8206 | Train Acc: 0.7073
# Validation Acc: 0.6791
#
# Epoch 62/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.7335 | Train Acc: 0.7063
# Validation Acc: 0.6831
#
# Epoch 63/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.5991 | Train Acc: 0.7070
# Validation Acc: 0.6857
#
# Epoch 64/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.5315 | Train Acc: 0.7059
# Validation Acc: 0.6813
#
# Epoch 65/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.3959 | Train Acc: 0.7067
# Validation Acc: 0.6837
#
# Epoch 66/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.2498 | Train Acc: 0.7057
# Validation Acc: 0.6833
#
# Epoch 67/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.0189 | Train Acc: 0.7081
# Validation Acc: 0.6797
#
# Epoch 68/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.0252 | Train Acc: 0.7095
# Validation Acc: 0.6813
#
# Epoch 69/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.9368 | Train Acc: 0.7090
# Validation Acc: 0.6814
#
# Epoch 70/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.8322 | Train Acc: 0.7083
# Validation Acc: 0.6792
#
# Epoch 71/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.5574 | Train Acc: 0.7109
# Validation Acc: 0.6754
#
# Epoch 72/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.5580 | Train Acc: 0.7125
# Validation Acc: 0.6790
#
# Epoch 73/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.5752 | Train Acc: 0.7111
# Validation Acc: 0.6781
#
# Epoch 74/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.4621 | Train Acc: 0.7105
# Validation Acc: 0.6770
#
# Epoch 75/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.2514 | Train Acc: 0.7116
# Validation Acc: 0.6795
#
# Epoch 76/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.1046 | Train Acc: 0.7107
# Validation Acc: 0.6777
#
# Epoch 77/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.9334 | Train Acc: 0.7136
# Validation Acc: 0.6798
#
# Epoch 78/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.7739 | Train Acc: 0.7118
# Validation Acc: 0.6801
#
# Epoch 79/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.6058 | Train Acc: 0.7140
# Validation Acc: 0.6812
#
# Epoch 80/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.5564 | Train Acc: 0.7142
# Validation Acc: 0.6813
#
# Epoch 81/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.5911 | Train Acc: 0.7131
# Validation Acc: 0.6813
#
# Epoch 82/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.3546 | Train Acc: 0.7150
# Validation Acc: 0.6794
#
# Epoch 83/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.2313 | Train Acc: 0.7147
# Validation Acc: 0.6734
#
# Epoch 84/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.0984 | Train Acc: 0.7162
# Validation Acc: 0.6830
#
# Epoch 85/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.9231 | Train Acc: 0.7178
# Validation Acc: 0.6788
#
# Epoch 86/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.8787 | Train Acc: 0.7158
# Validation Acc: 0.6787
#
# Epoch 87/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.7261 | Train Acc: 0.7167
# Validation Acc: 0.6783
#
# Epoch 88/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.6647 | Train Acc: 0.7167
# Validation Acc: 0.6763
#
# Epoch 89/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.5395 | Train Acc: 0.7168
# Validation Acc: 0.6731
#
# Epoch 90/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.2890 | Train Acc: 0.7172
# Validation Acc: 0.6725
#
# Epoch 91/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.2767 | Train Acc: 0.7191
# Validation Acc: 0.6759
#
# Epoch 92/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.0776 | Train Acc: 0.7191
# Validation Acc: 0.6771
#
# Epoch 93/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.8751 | Train Acc: 0.7187
# Validation Acc: 0.6753
#
# Epoch 94/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.9593 | Train Acc: 0.7201
# Validation Acc: 0.6723
#
# Epoch 95/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.7974 | Train Acc: 0.7210
# Validation Acc: 0.6714
#
# Epoch 96/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.5357 | Train Acc: 0.7211
# Validation Acc: 0.6696
#
# Epoch 97/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.4935 | Train Acc: 0.7210
# Validation Acc: 0.6778
#
# Epoch 98/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.5579 | Train Acc: 0.7224
# Validation Acc: 0.6746
#
# Epoch 99/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.2458 | Train Acc: 0.7221
# Validation Acc: 0.6720
#
# Epoch 100/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.1246 | Train Acc: 0.7232
# Validation Acc: 0.6721
#
# === Fold 4/5 ===
#
# Epoch 1/100
#  [██████████████████████████████] 100.0%
# Train Loss: 116.2497 | Train Acc: 0.6034
# Validation Acc: 0.6196
#
# Epoch 2/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.9619 | Train Acc: 0.6266
# Validation Acc: 0.6233
#
# Epoch 3/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.7334 | Train Acc: 0.6290
# Validation Acc: 0.6221
#
# Epoch 4/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.5154 | Train Acc: 0.6295
# Validation Acc: 0.6266
#
# Epoch 5/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.0847 | Train Acc: 0.6319
# Validation Acc: 0.6314
#
# Epoch 6/100
#  [██████████████████████████████] 100.0%
# Train Loss: 111.2487 | Train Acc: 0.6343
# Validation Acc: 0.6448
#
# Epoch 7/100
#  [██████████████████████████████] 100.0%
# Train Loss: 107.5513 | Train Acc: 0.6635
# Validation Acc: 0.6746
#
# Epoch 8/100
#  [██████████████████████████████] 100.0%
# Train Loss: 105.5075 | Train Acc: 0.6753
# Validation Acc: 0.6822
#
# Epoch 9/100
#  [██████████████████████████████] 100.0%
# Train Loss: 104.6081 | Train Acc: 0.6811
# Validation Acc: 0.6745
#
# Epoch 10/100
#  [██████████████████████████████] 100.0%
# Train Loss: 104.0663 | Train Acc: 0.6842
# Validation Acc: 0.6885
#
# Epoch 11/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.8388 | Train Acc: 0.6867
# Validation Acc: 0.6888
#
# Epoch 12/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.5631 | Train Acc: 0.6877
# Validation Acc: 0.6899
#
# Epoch 13/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.4193 | Train Acc: 0.6878
# Validation Acc: 0.6871
#
# Epoch 14/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.9700 | Train Acc: 0.6908
# Validation Acc: 0.6913
#
# Epoch 15/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.8242 | Train Acc: 0.6901
# Validation Acc: 0.6897
#
# Epoch 16/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.8152 | Train Acc: 0.6902
# Validation Acc: 0.6882
#
# Epoch 17/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.7183 | Train Acc: 0.6910
# Validation Acc: 0.6895
#
# Epoch 18/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.5381 | Train Acc: 0.6909
# Validation Acc: 0.6905
#
# Epoch 19/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.7171 | Train Acc: 0.6916
# Validation Acc: 0.6910
#
# Epoch 20/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.4432 | Train Acc: 0.6916
# Validation Acc: 0.6929
#
# Epoch 21/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.4375 | Train Acc: 0.6911
# Validation Acc: 0.6896
#
# Epoch 22/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.3687 | Train Acc: 0.6921
# Validation Acc: 0.6835
#
# Epoch 23/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.1476 | Train Acc: 0.6936
# Validation Acc: 0.6930
#
# Epoch 24/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.1178 | Train Acc: 0.6932
# Validation Acc: 0.6906
#
# Epoch 25/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.1050 | Train Acc: 0.6931
# Validation Acc: 0.6914
#
# Epoch 26/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.9899 | Train Acc: 0.6935
# Validation Acc: 0.6927
#
# Epoch 27/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.9595 | Train Acc: 0.6963
# Validation Acc: 0.6885
#
# Epoch 28/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.8419 | Train Acc: 0.6956
# Validation Acc: 0.6871
#
# Epoch 29/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.8575 | Train Acc: 0.6950
# Validation Acc: 0.6932
#
# Epoch 30/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.7972 | Train Acc: 0.6967
# Validation Acc: 0.6862
#
# Epoch 31/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.6381 | Train Acc: 0.6955
# Validation Acc: 0.6898
#
# Epoch 32/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.6394 | Train Acc: 0.6967
# Validation Acc: 0.6880
#
# Epoch 33/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.4658 | Train Acc: 0.6952
# Validation Acc: 0.6906
#
# Epoch 34/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.3852 | Train Acc: 0.6965
# Validation Acc: 0.6866
#
# Epoch 35/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.4391 | Train Acc: 0.6958
# Validation Acc: 0.6871
#
# Epoch 36/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.1411 | Train Acc: 0.6977
# Validation Acc: 0.6885
#
# Epoch 37/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.1872 | Train Acc: 0.6963
# Validation Acc: 0.6873
#
# Epoch 38/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.9903 | Train Acc: 0.6972
# Validation Acc: 0.6887
#
# Epoch 39/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.1138 | Train Acc: 0.6983
# Validation Acc: 0.6886
#
# Epoch 40/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.0087 | Train Acc: 0.6980
# Validation Acc: 0.6888
#
# Epoch 41/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.9326 | Train Acc: 0.6988
# Validation Acc: 0.6900
#
# Epoch 42/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.7382 | Train Acc: 0.6988
# Validation Acc: 0.6894
#
# Epoch 43/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.5642 | Train Acc: 0.7004
# Validation Acc: 0.6869
#
# Epoch 44/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.5630 | Train Acc: 0.6994
# Validation Acc: 0.6856
#
# Epoch 45/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.5187 | Train Acc: 0.6994
# Validation Acc: 0.6907
#
# Epoch 46/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.4794 | Train Acc: 0.6997
# Validation Acc: 0.6880
#
# Epoch 47/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.3432 | Train Acc: 0.7013
# Validation Acc: 0.6892
#
# Epoch 48/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.2689 | Train Acc: 0.7014
# Validation Acc: 0.6854
#
# Epoch 49/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.0380 | Train Acc: 0.7019
# Validation Acc: 0.6877
#
# Epoch 50/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.0142 | Train Acc: 0.7019
# Validation Acc: 0.6846
#
# Epoch 51/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.8005 | Train Acc: 0.7025
# Validation Acc: 0.6874
#
# Epoch 52/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.8342 | Train Acc: 0.7022
# Validation Acc: 0.6897
#
# Epoch 53/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.6353 | Train Acc: 0.7035
# Validation Acc: 0.6850
#
# Epoch 54/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.4927 | Train Acc: 0.7032
# Validation Acc: 0.6879
#
# Epoch 55/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.5431 | Train Acc: 0.7038
# Validation Acc: 0.6798
#
# Epoch 56/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.4517 | Train Acc: 0.7040
# Validation Acc: 0.6839
#
# Epoch 57/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.2209 | Train Acc: 0.7046
# Validation Acc: 0.6847
#
# Epoch 58/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.2481 | Train Acc: 0.7048
# Validation Acc: 0.6844
#
# Epoch 59/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.1238 | Train Acc: 0.7054
# Validation Acc: 0.6850
#
# Epoch 60/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.0325 | Train Acc: 0.7070
# Validation Acc: 0.6829
#
# Epoch 61/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.8566 | Train Acc: 0.7070
# Validation Acc: 0.6815
#
# Epoch 62/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.8544 | Train Acc: 0.7065
# Validation Acc: 0.6846
#
# Epoch 63/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.6853 | Train Acc: 0.7051
# Validation Acc: 0.6844
#
# Epoch 64/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.4365 | Train Acc: 0.7082
# Validation Acc: 0.6833
#
# Epoch 65/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.4391 | Train Acc: 0.7080
# Validation Acc: 0.6824
#
# Epoch 66/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.3793 | Train Acc: 0.7083
# Validation Acc: 0.6815
#
# Epoch 67/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.2237 | Train Acc: 0.7089
# Validation Acc: 0.6863
#
# Epoch 68/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.1641 | Train Acc: 0.7077
# Validation Acc: 0.6838
#
# Epoch 69/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.8842 | Train Acc: 0.7102
# Validation Acc: 0.6850
#
# Epoch 70/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.8423 | Train Acc: 0.7098
# Validation Acc: 0.6838
#
# Epoch 71/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.5870 | Train Acc: 0.7098
# Validation Acc: 0.6778
#
# Epoch 72/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.4523 | Train Acc: 0.7098
# Validation Acc: 0.6746
#
# Epoch 73/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.4424 | Train Acc: 0.7113
# Validation Acc: 0.6852
#
# Epoch 74/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.4207 | Train Acc: 0.7100
# Validation Acc: 0.6834
#
# Epoch 75/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.1194 | Train Acc: 0.7116
# Validation Acc: 0.6865
#
# Epoch 76/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.3047 | Train Acc: 0.7105
# Validation Acc: 0.6824
#
# Epoch 77/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.0068 | Train Acc: 0.7130
# Validation Acc: 0.6812
#
# Epoch 78/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.6275 | Train Acc: 0.7135
# Validation Acc: 0.6819
#
# Epoch 79/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.6082 | Train Acc: 0.7130
# Validation Acc: 0.6840
#
# Epoch 80/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.5961 | Train Acc: 0.7127
# Validation Acc: 0.6848
#
# Epoch 81/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.4666 | Train Acc: 0.7134
# Validation Acc: 0.6790
#
# Epoch 82/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.4011 | Train Acc: 0.7143
# Validation Acc: 0.6813
#
# Epoch 83/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.2087 | Train Acc: 0.7146
# Validation Acc: 0.6813
#
# Epoch 84/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.0663 | Train Acc: 0.7154
# Validation Acc: 0.6796
#
# Epoch 85/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.0338 | Train Acc: 0.7158
# Validation Acc: 0.6823
#
# Epoch 86/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.7690 | Train Acc: 0.7172
# Validation Acc: 0.6792
#
# Epoch 87/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.7950 | Train Acc: 0.7171
# Validation Acc: 0.6796
#
# Epoch 88/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.5535 | Train Acc: 0.7161
# Validation Acc: 0.6828
#
# Epoch 89/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.4430 | Train Acc: 0.7175
# Validation Acc: 0.6835
#
# Epoch 90/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.2836 | Train Acc: 0.7183
# Validation Acc: 0.6760
#
# Epoch 91/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.3248 | Train Acc: 0.7195
# Validation Acc: 0.6829
#
# Epoch 92/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.2645 | Train Acc: 0.7178
# Validation Acc: 0.6802
#
# Epoch 93/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.0790 | Train Acc: 0.7188
# Validation Acc: 0.6816
#
# Epoch 94/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.9169 | Train Acc: 0.7185
# Validation Acc: 0.6772
#
# Epoch 95/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.8031 | Train Acc: 0.7200
# Validation Acc: 0.6818
#
# Epoch 96/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.5025 | Train Acc: 0.7204
# Validation Acc: 0.6819
#
# Epoch 97/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.4759 | Train Acc: 0.7213
# Validation Acc: 0.6813
#
# Epoch 98/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.4000 | Train Acc: 0.7214
# Validation Acc: 0.6824
#
# Epoch 99/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.1850 | Train Acc: 0.7215
# Validation Acc: 0.6802
#
# Epoch 100/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.0110 | Train Acc: 0.7228
# Validation Acc: 0.6776
#
# === Fold 5/5 ===
#
# Epoch 1/100
#  [██████████████████████████████] 100.0%
# Train Loss: 116.6549 | Train Acc: 0.6036
# Validation Acc: 0.6280
#
# Epoch 2/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.9408 | Train Acc: 0.6234
# Validation Acc: 0.6204
#
# Epoch 3/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.6621 | Train Acc: 0.6263
# Validation Acc: 0.6334
#
# Epoch 4/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.4426 | Train Acc: 0.6287
# Validation Acc: 0.6260
#
# Epoch 5/100
# ...
# Validation Acc: 0.6878
#
# Epoch 68/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.7679 | Train Acc: 0.7100
# Validation Acc: 0.6794
#
# Epoch 69/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.5673 | Train Acc: 0.7087
# Validation Acc: 0.6807
#
# Epoch 70/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.4680 | Train Acc: 0.7090
# Validation Acc: 0.6853
#
# Epoch 71/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.4137 | Train Acc: 0.7093
# Validation Acc: 0.6835
#
# Epoch 72/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.2682 | Train Acc: 0.7093
# Validation Acc: 0.6797
#
# Epoch 73/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.0896 | Train Acc: 0.7119
# Validation Acc: 0.6825
#
# Epoch 74/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.9183 | Train Acc: 0.7103
# Validation Acc: 0.6850
#
# Epoch 75/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.8080 | Train Acc: 0.7121
# Validation Acc: 0.6837
#
# Epoch 76/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.8154 | Train Acc: 0.7103
# Validation Acc: 0.6816
#
# Epoch 77/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.6122 | Train Acc: 0.7132
# Validation Acc: 0.6821
#
# Epoch 78/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.3916 | Train Acc: 0.7136
# Validation Acc: 0.6804
#
# Epoch 79/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.2839 | Train Acc: 0.7138
# Validation Acc: 0.6807
#
# Epoch 80/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.2336 | Train Acc: 0.7122
# Validation Acc: 0.6827
#
# Epoch 81/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.1520 | Train Acc: 0.7129
# Validation Acc: 0.6796
#
# Epoch 82/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.9744 | Train Acc: 0.7141
# Validation Acc: 0.6819
#
# Epoch 83/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.7376 | Train Acc: 0.7155
# Validation Acc: 0.6787
#
# Epoch 84/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.8340 | Train Acc: 0.7148
# Validation Acc: 0.6839
#
# Epoch 85/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.6226 | Train Acc: 0.7154
# Validation Acc: 0.6823
#
# Epoch 86/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.6323 | Train Acc: 0.7147
# Validation Acc: 0.6754
#
# Epoch 87/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.1996 | Train Acc: 0.7167
# Validation Acc: 0.6793
#
# Epoch 88/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.3399 | Train Acc: 0.7161
# Validation Acc: 0.6840
#
# Epoch 89/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.1464 | Train Acc: 0.7177
# Validation Acc: 0.6814
#
# Epoch 90/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.9846 | Train Acc: 0.7171
# Validation Acc: 0.6802
#
# Epoch 91/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.9982 | Train Acc: 0.7161
# Validation Acc: 0.6794
#
# Epoch 92/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.7099 | Train Acc: 0.7184
# Validation Acc: 0.6814
#
# Epoch 93/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.5175 | Train Acc: 0.7204
# Validation Acc: 0.6791
#
# Epoch 94/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.6620 | Train Acc: 0.7199
# Validation Acc: 0.6772
#
# Epoch 95/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.4625 | Train Acc: 0.7203
# Validation Acc: 0.6829
#
# Epoch 96/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.4817 | Train Acc: 0.7213
# Validation Acc: 0.6783
#
# Epoch 97/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.1484 | Train Acc: 0.7201
# Validation Acc: 0.6781
#
# Epoch 98/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.2706 | Train Acc: 0.7214
# Validation Acc: 0.6784
#
# Epoch 99/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.0469 | Train Acc: 0.7216
# Validation Acc: 0.6790
#
# Epoch 100/100
#  [██████████████████████████████] 100.0%
# Train Loss: 93.8257 | Train Acc: 0.7210
# Validation Acc: 0.6787
#
# K-Fold CV Result (K=5): Mean Val Acc = 0.6778, Std = 0.0036
#
# Epoch 1/100
#  [██████████████████████████████] 100.0%
# Train Loss: 116.1388 | Train Acc: 0.6022
# Validation Acc: 0.6293
#
# Epoch 2/100
#  [██████████████████████████████] 100.0%
# Train Loss: 113.1394 | Train Acc: 0.6248
# Validation Acc: 0.6302
#
# Epoch 3/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.9165 | Train Acc: 0.6247
# Validation Acc: 0.6312
#
# Epoch 4/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.7002 | Train Acc: 0.6271
# Validation Acc: 0.6308
#
# Epoch 5/100
#  [██████████████████████████████] 100.0%
# Train Loss: 112.4059 | Train Acc: 0.6300
# Validation Acc: 0.6331
#
# Epoch 6/100
#  [██████████████████████████████] 100.0%
# Train Loss: 111.8377 | Train Acc: 0.6335
# Validation Acc: 0.6487
#
# Epoch 7/100
#  [██████████████████████████████] 100.0%
# Train Loss: 108.7874 | Train Acc: 0.6540
# Validation Acc: 0.6876
#
# Epoch 8/100
#  [██████████████████████████████] 100.0%
# Train Loss: 105.9783 | Train Acc: 0.6770
# Validation Acc: 0.6837
#
# Epoch 9/100
#  [██████████████████████████████] 100.0%
# Train Loss: 105.2694 | Train Acc: 0.6791
# Validation Acc: 0.6931
#
# Epoch 10/100
#  [██████████████████████████████] 100.0%
# Train Loss: 104.5807 | Train Acc: 0.6827
# Validation Acc: 0.6995
#
# Epoch 11/100
#  [██████████████████████████████] 100.0%
# Train Loss: 104.0164 | Train Acc: 0.6861
# Validation Acc: 0.6984
#
# Epoch 12/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.6616 | Train Acc: 0.6868
# Validation Acc: 0.6955
#
# Epoch 13/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.3228 | Train Acc: 0.6871
# Validation Acc: 0.6897
#
# Epoch 14/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.3715 | Train Acc: 0.6891
# Validation Acc: 0.6968
#
# Epoch 15/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.1317 | Train Acc: 0.6889
# Validation Acc: 0.6996
#
# Epoch 16/100
#  [██████████████████████████████] 100.0%
# Train Loss: 103.1479 | Train Acc: 0.6894
# Validation Acc: 0.6958
#
# Epoch 17/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.8681 | Train Acc: 0.6891
# Validation Acc: 0.7006
#
# Epoch 18/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.8890 | Train Acc: 0.6904
# Validation Acc: 0.6999
#
# Epoch 19/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.7258 | Train Acc: 0.6894
# Validation Acc: 0.6974
#
# Epoch 20/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.5615 | Train Acc: 0.6915
# Validation Acc: 0.6973
#
# Epoch 21/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.5214 | Train Acc: 0.6925
# Validation Acc: 0.7006
#
# Epoch 22/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.5452 | Train Acc: 0.6910
# Validation Acc: 0.6995
#
# Epoch 23/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.4404 | Train Acc: 0.6917
# Validation Acc: 0.6986
#
# Epoch 24/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.4883 | Train Acc: 0.6915
# Validation Acc: 0.6968
#
# Epoch 25/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.3162 | Train Acc: 0.6923
# Validation Acc: 0.6955
#
# Epoch 26/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.2995 | Train Acc: 0.6932
# Validation Acc: 0.6985
#
# Epoch 27/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.4129 | Train Acc: 0.6901
# Validation Acc: 0.6976
#
# Epoch 28/100
#  [██████████████████████████████] 100.0%
# Train Loss: 102.0768 | Train Acc: 0.6925
# Validation Acc: 0.6973
#
# Epoch 29/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.9276 | Train Acc: 0.6949
# Validation Acc: 0.6948
#
# Epoch 30/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.9712 | Train Acc: 0.6936
# Validation Acc: 0.6959
#
# Epoch 31/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.8818 | Train Acc: 0.6942
# Validation Acc: 0.6979
#
# Epoch 32/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.8197 | Train Acc: 0.6953
# Validation Acc: 0.6963
#
# Epoch 33/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.7041 | Train Acc: 0.6945
# Validation Acc: 0.6970
#
# Epoch 34/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.7002 | Train Acc: 0.6958
# Validation Acc: 0.6965
#
# Epoch 35/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.5163 | Train Acc: 0.6964
# Validation Acc: 0.6949
#
# Epoch 36/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.4990 | Train Acc: 0.6952
# Validation Acc: 0.6975
#
# Epoch 37/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.4072 | Train Acc: 0.6960
# Validation Acc: 0.6978
#
# Epoch 38/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.4245 | Train Acc: 0.6951
# Validation Acc: 0.6978
#
# Epoch 39/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.2767 | Train Acc: 0.6960
# Validation Acc: 0.6962
#
# Epoch 40/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.1878 | Train Acc: 0.6971
# Validation Acc: 0.6926
#
# Epoch 41/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.1865 | Train Acc: 0.6980
# Validation Acc: 0.6919
#
# Epoch 42/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.0697 | Train Acc: 0.6969
# Validation Acc: 0.6964
#
# Epoch 43/100
#  [██████████████████████████████] 100.0%
# Train Loss: 101.0691 | Train Acc: 0.6968
# Validation Acc: 0.6946
#
# Epoch 44/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.7921 | Train Acc: 0.6983
# Validation Acc: 0.6986
#
# Epoch 45/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.8906 | Train Acc: 0.6979
# Validation Acc: 0.6946
#
# Epoch 46/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.6166 | Train Acc: 0.6998
# Validation Acc: 0.6965
#
# Epoch 47/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.7186 | Train Acc: 0.7008
# Validation Acc: 0.6929
#
# Epoch 48/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.3943 | Train Acc: 0.7000
# Validation Acc: 0.6944
#
# Epoch 49/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.2895 | Train Acc: 0.7008
# Validation Acc: 0.6921
#
# Epoch 50/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.2053 | Train Acc: 0.7010
# Validation Acc: 0.6971
#
# Epoch 51/100
#  [██████████████████████████████] 100.0%
# Train Loss: 100.2792 | Train Acc: 0.7011
# Validation Acc: 0.6963
#
# Epoch 52/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.8763 | Train Acc: 0.7030
# Validation Acc: 0.6986
#
# Epoch 53/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.9227 | Train Acc: 0.7013
# Validation Acc: 0.6938
#
# Epoch 54/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.6418 | Train Acc: 0.7023
# Validation Acc: 0.6956
#
# Epoch 55/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.7254 | Train Acc: 0.7025
# Validation Acc: 0.6951
#
# Epoch 56/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.4526 | Train Acc: 0.7034
# Validation Acc: 0.6948
#
# Epoch 57/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.4026 | Train Acc: 0.7033
# Validation Acc: 0.6898
#
# Epoch 58/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.5982 | Train Acc: 0.7039
# Validation Acc: 0.6937
#
# Epoch 59/100
#  [██████████████████████████████] 100.0%
# Train Loss: 99.2257 | Train Acc: 0.7060
# Validation Acc: 0.6926
#
# Epoch 60/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.9983 | Train Acc: 0.7046
# Validation Acc: 0.6904
#
# Epoch 61/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.9280 | Train Acc: 0.7056
# Validation Acc: 0.6941
#
# Epoch 62/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.8876 | Train Acc: 0.7062
# Validation Acc: 0.6932
#
# Epoch 63/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.6945 | Train Acc: 0.7072
# Validation Acc: 0.6958
#
# Epoch 64/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.5613 | Train Acc: 0.7071
# Validation Acc: 0.6949
#
# Epoch 65/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.4907 | Train Acc: 0.7085
# Validation Acc: 0.6920
#
# Epoch 66/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.2629 | Train Acc: 0.7083
# Validation Acc: 0.6884
#
# Epoch 67/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.1559 | Train Acc: 0.7083
# Validation Acc: 0.6885
#
# Epoch 68/100
#  [██████████████████████████████] 100.0%
# Train Loss: 98.1188 | Train Acc: 0.7075
# Validation Acc: 0.6883
#
# Epoch 69/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.7845 | Train Acc: 0.7093
# Validation Acc: 0.6879
#
# Epoch 70/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.7185 | Train Acc: 0.7096
# Validation Acc: 0.6891
#
# Epoch 71/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.6563 | Train Acc: 0.7104
# Validation Acc: 0.6913
#
# Epoch 72/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.5389 | Train Acc: 0.7103
# Validation Acc: 0.6862
#
# Epoch 73/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.2593 | Train Acc: 0.7107
# Validation Acc: 0.6866
#
# Epoch 74/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.4546 | Train Acc: 0.7101
# Validation Acc: 0.6921
#
# Epoch 75/100
#  [██████████████████████████████] 100.0%
# Train Loss: 97.1200 | Train Acc: 0.7103
# Validation Acc: 0.6884
#
# Epoch 76/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.9520 | Train Acc: 0.7129
# Validation Acc: 0.6909
#
# Epoch 77/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.8639 | Train Acc: 0.7124
# Validation Acc: 0.6884
#
# Epoch 78/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.9507 | Train Acc: 0.7106
# Validation Acc: 0.6904
#
# Epoch 79/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.6791 | Train Acc: 0.7132
# Validation Acc: 0.6862
#
# Epoch 80/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.5444 | Train Acc: 0.7132
# Validation Acc: 0.6890
#
# Epoch 81/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.4557 | Train Acc: 0.7140
# Validation Acc: 0.6864
#
# Epoch 82/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.3392 | Train Acc: 0.7144
# Validation Acc: 0.6849
#
# Epoch 83/100
#  [██████████████████████████████] 100.0%
# Train Loss: 96.1753 | Train Acc: 0.7141
# Validation Acc: 0.6881
#
# Epoch 84/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.9167 | Train Acc: 0.7160
# Validation Acc: 0.6838
#
# Epoch 85/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.8704 | Train Acc: 0.7159
# Validation Acc: 0.6873
#
# Epoch 86/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.7795 | Train Acc: 0.7166
# Validation Acc: 0.6875
#
# Epoch 87/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.5627 | Train Acc: 0.7170
# Validation Acc: 0.6867
#
# Epoch 88/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.4307 | Train Acc: 0.7171
# Validation Acc: 0.6869
#
# Epoch 89/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.3542 | Train Acc: 0.7173
# Validation Acc: 0.6882
#
# Epoch 90/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.4185 | Train Acc: 0.7159
# Validation Acc: 0.6874
#
# Epoch 91/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.1303 | Train Acc: 0.7191
# Validation Acc: 0.6837
#
# Epoch 92/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.8256 | Train Acc: 0.7188
# Validation Acc: 0.6891
#
# Epoch 93/100
#  [██████████████████████████████] 100.0%
# Train Loss: 95.0011 | Train Acc: 0.7193
# Validation Acc: 0.6829
#
# Epoch 94/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.7453 | Train Acc: 0.7208
# Validation Acc: 0.6853
#
# Epoch 95/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.5369 | Train Acc: 0.7208
# Validation Acc: 0.6887
#
# Epoch 96/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.4522 | Train Acc: 0.7215
# Validation Acc: 0.6853
#
# Epoch 97/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.4248 | Train Acc: 0.7206
# Validation Acc: 0.6877
#
# Epoch 98/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.2635 | Train Acc: 0.7220
# Validation Acc: 0.6864
#
# Epoch 99/100
#  [██████████████████████████████] 100.0%
# Train Loss: 94.1359 | Train Acc: 0.7207
# Validation Acc: 0.6873
#
# Epoch 100/100
#  [██████████████████████████████] 100.0%
# Train Loss: 93.9358 | Train Acc: 0.7208
# Validation Acc: 0.6838
#
# === Final Evaluation on Test Data ===
#
# Test Metrics:
# Accuracy : 0.6782
# F1 Score : 0.6744
# Precision: 0.6837
# Recall   : 0.6653
# AUC      : 0.7348
