# %%
import os
import random
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import (
    accuracy_score, f1_score, precision_score,
    recall_score, roc_auc_score, roc_curve, confusion_matrix
)
import matplotlib.pyplot as plt
import seaborn as sns
from fttransformer_mask import FTTransformer

# --------------------------------------------
# 設定
# --------------------------------------------
DATA_PATH = "/home/osajima/ドキュメント/program/Transformer_Study/fttransformer_pytorch/cardio_train.csv"
TEST_RATIO = 0.2
K_FOLDS = 5
EPOCHS = 50
BATCH_SIZE = 128
LR = 1e-4

# 保存ディレクトリ
SAVE_DIR = os.path.join(os.getcwd(), "save_mask_models")
IMAGE_DIR = os.path.join(os.getcwd(), "save_mask_confusion_matrix_images")
os.makedirs(IMAGE_DIR, exist_ok=True)
os.makedirs(SAVE_DIR, exist_ok=True)
# --------------------------------------------
# データ読み込み・前処理
# --------------------------------------------
data = pd.read_csv(DATA_PATH, sep=';')
data.drop(columns=["id"], inplace=True)
X = data.drop(columns=["cardio"])
y = data["cardio"]

categorical_cols = ["gender","cholesterol","gluc","smoke","alco","active"]
continuous_cols = ["age","height","weight","ap_hi","ap_lo"]
mask_cols = ["cholesterol", "gluc", "smoke", "alco", "active"]
for col in categorical_cols:
    X[col] = LabelEncoder().fit_transform(X[col])
X[continuous_cols] = StandardScaler().fit_transform(X[continuous_cols])

# テストセット分離
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y, test_size=TEST_RATIO, random_state=42, stratify=y
)

# DataLoader ヘルパー
class CardioDataset(Dataset):
    def __init__(self, X, y, train_flag):
        self.X_cat = torch.tensor(X[categorical_cols].values, dtype=torch.long)
        self.X_cont = torch.tensor(X[continuous_cols].values, dtype=torch.float32)
        self.y = torch.tensor(y.values, dtype=torch.float32).unsqueeze(1)
        self.train_flag = train_flag

        # ★ 変更点 ① ── 入力トークンの並びを 1 か所で定義
        self.token_order = ["CLS"] + categorical_cols + continuous_cols

        # ★ 変更点 ② ── mask_cols に基づきインデックスを自動抽出
        self.mask_idx = [self.token_order.index(col) for col in mask_cols]
    def __len__(self): return len(self.y)
    def __getitem__(self, idx): 
        mask = torch.zeros(len(self.token_order), dtype=torch.bool)
        if self.train_flag:#trainの時はマスクを1/6でランダムに生成
            choice = random.randint(0, 5)  # 0〜5 の整数をランダムに選ぶ
        # 初めの7列は常に False（マスクしない）
            if choice > 0:
                mask[self.mask_idx[choice-1]] = False
        else:
            mask[self.mask_idx] = True
        return self.X_cat[idx], self.X_cont[idx], self.y[idx], mask

def get_loader(X, y, train_flag=False):
    return DataLoader(CardioDataset(X, y, train_flag), batch_size=BATCH_SIZE, shuffle=train_flag)


def plot_all_metrics(train_losses, train_accs, val_accs,
                    y_true, y_pred, y_prob,
                    fold, val_acc, test_acc, save_dir):
    cm = confusion_matrix(y_true, y_pred)
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    auc = roc_auc_score(y_true, y_prob)
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred)
    rec = recall_score(y_true, y_pred)

    fig, axs = plt.subplots(2, 2, figsize=(12, 10))
    axs[0, 0].plot(range(1, len(train_losses) + 1), train_losses, 'o-')
    axs[0, 0].set_title("Training Loss")
    axs[0, 0].grid(True)

    axs[0, 1].plot(range(1, len(train_accs) + 1), train_accs, 'o-', label='Training Accuracy')
    axs[0, 1].plot(range(1, len(val_accs) + 1), val_accs, 'x-', label='Validation Accuracy')
    axs[0, 1].set_title("Accuracy")
    axs[0, 1].legend()
    axs[0, 1].grid(True)

    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axs[1, 0])
    axs[1, 0].set_title("Confusion Matrix")
    axs[1, 0].set_xticklabels(['No Cardio', 'Cardio'])
    axs[1, 0].set_yticklabels(['No Cardio', 'Cardio'], rotation=0)

    axs[1, 1].plot(fpr, tpr, label=f'AUC = {auc:.3f}')
    axs[1, 1].plot([0, 1], [0, 1], 'k--')
    axs[1, 1].set_title('ROC Curve')
    axs[1, 1].legend(loc='lower right')
    axs[1, 1].text(0.05, 0.2,
                f"Accuracy: {acc:.3f}\nF1 Score: {f1:.3f}\nPrecision: {prec:.3f}\nRecall: {rec:.3f}",
                bbox=dict(facecolor='white', alpha=0.7))

    fig.tight_layout()
    # 保存ファイル名を省略せず作成
    fname = (
        f"confusion_matrix_Epoch{EPOCHS}_Fold{fold}_ValAcc{val_acc:.3f}"
        f"_TestAccuracy{test_acc:.3f}.png"
    )
    save_path = os.path.join(save_dir, fname)
    fig.savefig(save_path, dpi=200, bbox_inches='tight')
    plt.show()
    plt.close(fig)

# K-Fold CV
kf = KFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
fold_results = []

for fold, (tr, va) in enumerate(kf.split(X_train_val, y_train_val), 1):
    print(f"\n--- Fold {fold}/{K_FOLDS} ---")
    X_tr, y_tr = X_train_val.iloc[tr], y_train_val.iloc[tr]
    X_va, y_va = X_train_val.iloc[va], y_train_val.iloc[va]
    train_loader = get_loader(X_tr, y_tr, train_flag=True)
    val_loader   = get_loader(X_va, y_va, train_flag=False)
    test_loader  = get_loader(X_test, y_test, train_flag=False)

    model = FTTransformer(
        categories=[X[c].nunique() for c in categorical_cols],
        num_continuous=len(continuous_cols), dim=64, depth=6, heads=8,
        ff_dropout=0.2, attn_dropout=0.2
    ).to(device)
    optimizer = optim.AdamW(model.parameters(), lr=LR)
    criterion = nn.BCEWithLogitsLoss()

    best_val_acc = 0.0
    best_state = None
    train_losses, train_accs, val_accs = [], [], []

    for epoch in range(1, EPOCHS + 1):
        model.train()
        total_loss = 0.0
        for x_cat, x_cont, labels, mask in train_loader:
                x_cat  = x_cat.to(device)
                x_cont = x_cont.to(device)
                labels = labels.to(device)
                mask   = mask.to(device)
                outputs = model(x_cat, x_cont, mask)
                optimizer.zero_grad()
            # mask_list = (torch.rand(128, 12) > 0.5).bool()
                outputs = model(x_cat, x_cont, mask)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                total_loss += loss.item()
        avg_loss = total_loss / len(train_loader)
        train_losses.append(avg_loss)

        model.eval()
        tc, tt = 0, 0
        with torch.no_grad():
            for x_cat, x_cont, labels, mask in train_loader:
                x_cat, x_cont, labels ,mask = (x_cat.to(device), x_cont.to(device), labels.to(device),mask.to(device))
                preds = (torch.sigmoid(model(x_cat, x_cont,mask)) > 0.5).float()
                tc += (preds.cpu() == labels.cpu()).sum().item()
                tt += labels.size(0)
        train_accs.append(tc / tt)

        preds, probs, labs = [], [], []
        with torch.no_grad():
            for x_cat, x_cont, labels, mask in val_loader:
                x_cat, x_cont, labels, mask = (x_cat.to(device),x_cont.to(device),labels.to(device),mask.to(device))
                pr = torch.sigmoid(model(x_cat, x_cont, mask)).detach().cpu().numpy()
                preds.extend((pr > 0.5).astype(int).flatten())
                probs.extend(pr.flatten())
                labs.extend(labels.cpu().numpy())
            val_acc = accuracy_score(labs, preds)
            val_accs.append(val_acc)

        # Lossと百分率表示
        print(f"Epoch {epoch}/{EPOCHS} - Loss: {avg_loss:.4f} - Validation Accuracy: {val_acc*100:.2f}%")
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_state = model.state_dict().copy()

    # モデル保存
    model_name = (
        f"best_model_epoch{EPOCHS}_fold{fold}_ValAcc{best_val_acc:.3f}.pth"
    )
    model_path = os.path.join(SAVE_DIR, model_name)
    torch.save(best_state, model_path)
    print(f"Saved model file: {model_name}")

    # テスト評価
    best_model = FTTransformer(
        categories=[X[c].nunique() for c in categorical_cols],
        num_continuous=len(continuous_cols), dim=64, depth=6, heads=8,
        ff_dropout=0.2, attn_dropout=0.2
    ).to(device)
    best_model.load_state_dict(torch.load(model_path))
    best_model.eval()

    y_t, y_p, y_pr = [], [], []
    with torch.no_grad():
        for x_cat, x_cont, labels,mask in test_loader:
            x_cat  = x_cat.to(device)
            x_cont = x_cont.to(device)
            labels = labels.to(device)
            mask   = mask.to(device)
# ① モデルを呼び出して Tensor を得る
            out = best_model(x_cat, x_cont, mask)
# ② Tensor に対して sigmoid → detach → cpu → numpy
            pr = torch.sigmoid(out).detach().cpu().numpy()
            y_p.extend((pr > 0.5).astype(int).flatten())
            y_pr.extend(pr.flatten())
            y_t.extend(labels.cpu().numpy())
    test_acc = accuracy_score(y_t, y_p)
    f1s = f1_score(y_t, y_p)
    prec = precision_score(y_t, y_p)
    rec = recall_score(y_t, y_p)
    auc_val = roc_auc_score(y_t, y_pr)
    print(f"Test Fold {fold}: Test Accuracy: {test_acc*100:.2f}%, F1 Score: {f1s:.3f}, Precision: {prec:.3f}, Recall: {rec:.3f}, AUC: {auc_val:.3f}")

    # プロット・保存
    plot_all_metrics(
        train_losses, train_accs, val_accs,
        y_t, y_p, y_pr,
        fold, best_val_acc, test_acc, IMAGE_DIR
    )
    fold_results.append((test_acc, f1s, auc_val, rec))

# 平均結果表示
avg = [np.mean([r[i] for r in fold_results]) for i in range(4)]
print(f"Average test results: Test Accuracy: {avg[0]*100:.2f}%, F1 Score: {avg[1]:.3f}, AUC: {avg[2]:.3f}, Recall: {avg[3]:.3f}")
# Out:
# --- Fold 1/5 ---
# Epoch 1/50 - Loss: 0.5735 - Validation Accuracy: 71.89%
# Epoch 2/50 - Loss: 0.5466 - Validation Accuracy: 72.28%
# Epoch 3/50 - Loss: 0.5450 - Validation Accuracy: 71.92%
# Epoch 4/50 - Loss: 0.5443 - Validation Accuracy: 72.73%
# Epoch 5/50 - Loss: 0.5433 - Validation Accuracy: 72.28%
# Epoch 6/50 - Loss: 0.5421 - Validation Accuracy: 72.72%
# Epoch 7/50 - Loss: 0.5419 - Validation Accuracy: 72.78%
# Epoch 8/50 - Loss: 0.5412 - Validation Accuracy: 72.82%
# Epoch 9/50 - Loss: 0.5406 - Validation Accuracy: 72.66%
# Epoch 10/50 - Loss: 0.5404 - Validation Accuracy: 72.72%
# Epoch 11/50 - Loss: 0.5399 - Validation Accuracy: 72.84%
# Epoch 12/50 - Loss: 0.5400 - Validation Accuracy: 72.77%
# Epoch 13/50 - Loss: 0.5392 - Validation Accuracy: 72.24%
# Epoch 14/50 - Loss: 0.5395 - Validation Accuracy: 73.02%
# Epoch 15/50 - Loss: 0.5385 - Validation Accuracy: 72.28%
# Epoch 16/50 - Loss: 0.5388 - Validation Accuracy: 72.60%
# Epoch 17/50 - Loss: 0.5381 - Validation Accuracy: 73.00%
# Epoch 18/50 - Loss: 0.5377 - Validation Accuracy: 73.04%
# Epoch 19/50 - Loss: 0.5379 - Validation Accuracy: 72.56%
# Epoch 20/50 - Loss: 0.5375 - Validation Accuracy: 73.01%
# Epoch 21/50 - Loss: 0.5373 - Validation Accuracy: 73.07%
# Epoch 22/50 - Loss: 0.5369 - Validation Accuracy: 72.79%
# Epoch 23/50 - Loss: 0.5372 - Validation Accuracy: 73.00%
# Epoch 24/50 - Loss: 0.5362 - Validation Accuracy: 72.75%
# Epoch 25/50 - Loss: 0.5366 - Validation Accuracy: 73.30%
# Epoch 26/50 - Loss: 0.5363 - Validation Accuracy: 73.09%
# Epoch 27/50 - Loss: 0.5363 - Validation Accuracy: 72.91%
# Epoch 28/50 - Loss: 0.5358 - Validation Accuracy: 73.01%
# Epoch 29/50 - Loss: 0.5357 - Validation Accuracy: 72.99%
# Epoch 30/50 - Loss: 0.5353 - Validation Accuracy: 73.12%
# Epoch 31/50 - Loss: 0.5354 - Validation Accuracy: 73.08%
# Epoch 32/50 - Loss: 0.5355 - Validation Accuracy: 72.51%
# Epoch 33/50 - Loss: 0.5357 - Validation Accuracy: 72.96%
# Epoch 34/50 - Loss: 0.5349 - Validation Accuracy: 72.71%
# Epoch 35/50 - Loss: 0.5350 - Validation Accuracy: 72.26%
# Epoch 36/50 - Loss: 0.5350 - Validation Accuracy: 72.92%
# Epoch 37/50 - Loss: 0.5343 - Validation Accuracy: 72.95%
# Epoch 38/50 - Loss: 0.5345 - Validation Accuracy: 72.99%
# Epoch 39/50 - Loss: 0.5341 - Validation Accuracy: 72.84%
# Epoch 40/50 - Loss: 0.5340 - Validation Accuracy: 72.70%
# Epoch 41/50 - Loss: 0.5336 - Validation Accuracy: 72.88%
# Epoch 42/50 - Loss: 0.5334 - Validation Accuracy: 72.83%
# Epoch 43/50 - Loss: 0.5333 - Validation Accuracy: 72.76%
# Epoch 44/50 - Loss: 0.5332 - Validation Accuracy: 72.90%
# Epoch 45/50 - Loss: 0.5327 - Validation Accuracy: 72.89%
# Epoch 46/50 - Loss: 0.5330 - Validation Accuracy: 72.94%
# Epoch 47/50 - Loss: 0.5326 - Validation Accuracy: 72.99%
# Epoch 48/50 - Loss: 0.5325 - Validation Accuracy: 73.04%
# Epoch 49/50 - Loss: 0.5319 - Validation Accuracy: 72.93%
# Epoch 50/50 - Loss: 0.5316 - Validation Accuracy: 72.95%
# Saved model file: best_model_epoch50_fold1_ValAcc0.733.pth
# Test Fold 1: Test Accuracy: 72.76%, F1 Score: 0.710, Precision: 0.759, Recall: 0.666, AUC: 0.792
# --- Fold 2/5 ---
# Epoch 1/50 - Loss: 0.5786 - Validation Accuracy: 73.18%
# Epoch 2/50 - Loss: 0.5487 - Validation Accuracy: 73.26%
# Epoch 3/50 - Loss: 0.5465 - Validation Accuracy: 73.21%
# Epoch 4/50 - Loss: 0.5453 - Validation Accuracy: 73.08%
# Epoch 5/50 - Loss: 0.5447 - Validation Accuracy: 73.38%
# Epoch 6/50 - Loss: 0.5438 - Validation Accuracy: 72.67%
# Epoch 7/50 - Loss: 0.5434 - Validation Accuracy: 73.51%
# Epoch 8/50 - Loss: 0.5426 - Validation Accuracy: 73.42%
# Epoch 9/50 - Loss: 0.5427 - Validation Accuracy: 73.70%
# Epoch 10/50 - Loss: 0.5415 - Validation Accuracy: 73.45%
# Epoch 11/50 - Loss: 0.5413 - Validation Accuracy: 73.59%
# Epoch 12/50 - Loss: 0.5416 - Validation Accuracy: 73.76%
# Epoch 13/50 - Loss: 0.5406 - Validation Accuracy: 73.67%
# Epoch 14/50 - Loss: 0.5408 - Validation Accuracy: 73.52%
# Epoch 15/50 - Loss: 0.5406 - Validation Accuracy: 73.34%
# Epoch 16/50 - Loss: 0.5401 - Validation Accuracy: 72.84%
# Epoch 17/50 - Loss: 0.5399 - Validation Accuracy: 73.66%
# Epoch 18/50 - Loss: 0.5399 - Validation Accuracy: 73.71%
# Epoch 19/50 - Loss: 0.5397 - Validation Accuracy: 73.64%
# Epoch 20/50 - Loss: 0.5388 - Validation Accuracy: 73.73%
# Epoch 21/50 - Loss: 0.5387 - Validation Accuracy: 73.26%
# Epoch 22/50 - Loss: 0.5390 - Validation Accuracy: 73.68%
# Epoch 23/50 - Loss: 0.5386 - Validation Accuracy: 73.24%
# Epoch 24/50 - Loss: 0.5384 - Validation Accuracy: 73.72%
# Epoch 25/50 - Loss: 0.5384 - Validation Accuracy: 73.90%
# Epoch 26/50 - Loss: 0.5382 - Validation Accuracy: 73.69%
# Epoch 27/50 - Loss: 0.5381 - Validation Accuracy: 73.49%
# Epoch 28/50 - Loss: 0.5374 - Validation Accuracy: 74.00%
# Epoch 29/50 - Loss: 0.5375 - Validation Accuracy: 74.03%
# Epoch 30/50 - Loss: 0.5368 - Validation Accuracy: 73.92%
# Epoch 31/50 - Loss: 0.5375 - Validation Accuracy: 73.66%
# Epoch 32/50 - Loss: 0.5376 - Validation Accuracy: 73.60%
# Epoch 33/50 - Loss: 0.5362 - Validation Accuracy: 73.20%
# Epoch 34/50 - Loss: 0.5368 - Validation Accuracy: 73.51%
# Epoch 35/50 - Loss: 0.5362 - Validation Accuracy: 73.35%
# Epoch 36/50 - Loss: 0.5369 - Validation Accuracy: 73.76%
# Epoch 37/50 - Loss: 0.5364 - Validation Accuracy: 73.94%
# Epoch 38/50 - Loss: 0.5360 - Validation Accuracy: 73.80%
# Epoch 39/50 - Loss: 0.5357 - Validation Accuracy: 73.76%
# Epoch 40/50 - Loss: 0.5356 - Validation Accuracy: 73.83%
# Epoch 41/50 - Loss: 0.5354 - Validation Accuracy: 73.67%
# Epoch 42/50 - Loss: 0.5347 - Validation Accuracy: 73.88%
# Epoch 43/50 - Loss: 0.5350 - Validation Accuracy: 73.90%
# Epoch 44/50 - Loss: 0.5350 - Validation Accuracy: 73.84%
# Epoch 45/50 - Loss: 0.5345 - Validation Accuracy: 73.88%
# Epoch 46/50 - Loss: 0.5342 - Validation Accuracy: 73.86%
# Epoch 47/50 - Loss: 0.5344 - Validation Accuracy: 73.46%
# Epoch 48/50 - Loss: 0.5335 - Validation Accuracy: 73.90%
# Epoch 49/50 - Loss: 0.5337 - Validation Accuracy: 73.79%
# Epoch 50/50 - Loss: 0.5338 - Validation Accuracy: 73.71%
# Saved model file: best_model_epoch50_fold2_ValAcc0.740.pth
# Test Fold 2: Test Accuracy: 73.17%, F1 Score: 0.719, Precision: 0.755, Recall: 0.686, AUC: 0.797
# --- Fold 3/5 ---
# Epoch 1/50 - Loss: 0.5876 - Validation Accuracy: 72.68%
# Epoch 2/50 - Loss: 0.5494 - Validation Accuracy: 72.92%
# Epoch 3/50 - Loss: 0.5475 - Validation Accuracy: 71.98%
# Epoch 4/50 - Loss: 0.5459 - Validation Accuracy: 71.99%
# Epoch 5/50 - Loss: 0.5446 - Validation Accuracy: 72.22%
# Epoch 6/50 - Loss: 0.5437 - Validation Accuracy: 72.24%
# Epoch 7/50 - Loss: 0.5431 - Validation Accuracy: 72.27%
# Epoch 8/50 - Loss: 0.5420 - Validation Accuracy: 72.44%
# Epoch 9/50 - Loss: 0.5414 - Validation Accuracy: 72.96%
# Epoch 10/50 - Loss: 0.5417 - Validation Accuracy: 72.30%
# Epoch 11/50 - Loss: 0.5410 - Validation Accuracy: 72.23%
# Epoch 12/50 - Loss: 0.5408 - Validation Accuracy: 72.79%
# Epoch 13/50 - Loss: 0.5398 - Validation Accuracy: 72.77%
# Epoch 14/50 - Loss: 0.5407 - Validation Accuracy: 72.34%
# Epoch 15/50 - Loss: 0.5399 - Validation Accuracy: 72.37%
# Epoch 16/50 - Loss: 0.5396 - Validation Accuracy: 73.11%
# Epoch 17/50 - Loss: 0.5397 - Validation Accuracy: 72.27%
# Epoch 18/50 - Loss: 0.5390 - Validation Accuracy: 72.68%
# Epoch 19/50 - Loss: 0.5389 - Validation Accuracy: 72.14%
# Epoch 20/50 - Loss: 0.5390 - Validation Accuracy: 72.43%
# Epoch 21/50 - Loss: 0.5389 - Validation Accuracy: 72.39%
# Epoch 22/50 - Loss: 0.5376 - Validation Accuracy: 72.78%
# Epoch 23/50 - Loss: 0.5383 - Validation Accuracy: 72.50%
# Epoch 24/50 - Loss: 0.5381 - Validation Accuracy: 72.86%
# Epoch 25/50 - Loss: 0.5385 - Validation Accuracy: 72.18%
# Epoch 26/50 - Loss: 0.5377 - Validation Accuracy: 72.37%
# Epoch 27/50 - Loss: 0.5374 - Validation Accuracy: 72.24%
# Epoch 28/50 - Loss: 0.5378 - Validation Accuracy: 72.52%
# Epoch 29/50 - Loss: 0.5374 - Validation Accuracy: 72.88%
# Epoch 30/50 - Loss: 0.5375 - Validation Accuracy: 72.38%
# Epoch 31/50 - Loss: 0.5371 - Validation Accuracy: 72.86%
# Epoch 32/50 - Loss: 0.5369 - Validation Accuracy: 73.28%
# Epoch 33/50 - Loss: 0.5368 - Validation Accuracy: 72.53%
# Epoch 34/50 - Loss: 0.5365 - Validation Accuracy: 73.00%
# Epoch 35/50 - Loss: 0.5364 - Validation Accuracy: 73.46%
# Epoch 36/50 - Loss: 0.5360 - Validation Accuracy: 72.77%
# Epoch 37/50 - Loss: 0.5360 - Validation Accuracy: 73.13%
# Epoch 38/50 - Loss: 0.5359 - Validation Accuracy: 72.86%
# Epoch 39/50 - Loss: 0.5356 - Validation Accuracy: 72.71%
# Epoch 40/50 - Loss: 0.5358 - Validation Accuracy: 72.87%
# Epoch 41/50 - Loss: 0.5353 - Validation Accuracy: 72.80%
# Epoch 42/50 - Loss: 0.5352 - Validation Accuracy: 72.55%
# Epoch 43/50 - Loss: 0.5346 - Validation Accuracy: 72.88%
# Epoch 44/50 - Loss: 0.5352 - Validation Accuracy: 72.73%
# Epoch 45/50 - Loss: 0.5343 - Validation Accuracy: 72.87%
# Epoch 46/50 - Loss: 0.5342 - Validation Accuracy: 72.63%
# Epoch 47/50 - Loss: 0.5347 - Validation Accuracy: 72.39%
# Epoch 48/50 - Loss: 0.5335 - Validation Accuracy: 73.05%
# Epoch 49/50 - Loss: 0.5337 - Validation Accuracy: 73.12%
# Epoch 50/50 - Loss: 0.5337 - Validation Accuracy: 72.51%
# Saved model file: best_model_epoch50_fold3_ValAcc0.735.pth
# Test Fold 3: Test Accuracy: 72.48%, F1 Score: 0.690, Precision: 0.789, Recall: 0.614, AUC: 0.794
# --- Fold 4/5 ---
# Epoch 1/50 - Loss: 0.5781 - Validation Accuracy: 72.21%
# Epoch 2/50 - Loss: 0.5483 - Validation Accuracy: 68.31%
# Epoch 3/50 - Loss: 0.5461 - Validation Accuracy: 69.24%
# Epoch 4/50 - Loss: 0.5442 - Validation Accuracy: 71.56%
# Epoch 5/50 - Loss: 0.5430 - Validation Accuracy: 72.04%
# Epoch 6/50 - Loss: 0.5431 - Validation Accuracy: 72.19%
# Epoch 7/50 - Loss: 0.5418 - Validation Accuracy: 68.07%
# Epoch 8/50 - Loss: 0.5417 - Validation Accuracy: 72.50%
# Epoch 9/50 - Loss: 0.5414 - Validation Accuracy: 71.85%
# Epoch 10/50 - Loss: 0.5411 - Validation Accuracy: 71.51%
# Epoch 11/50 - Loss: 0.5409 - Validation Accuracy: 72.51%
# Epoch 12/50 - Loss: 0.5403 - Validation Accuracy: 73.53%
# Epoch 13/50 - Loss: 0.5399 - Validation Accuracy: 73.55%
# Epoch 14/50 - Loss: 0.5401 - Validation Accuracy: 72.92%
# Epoch 15/50 - Loss: 0.5398 - Validation Accuracy: 73.50%
# Epoch 16/50 - Loss: 0.5393 - Validation Accuracy: 73.31%
# Epoch 17/50 - Loss: 0.5394 - Validation Accuracy: 73.37%
# Epoch 18/50 - Loss: 0.5390 - Validation Accuracy: 73.38%
# Epoch 19/50 - Loss: 0.5383 - Validation Accuracy: 73.38%
# Epoch 20/50 - Loss: 0.5388 - Validation Accuracy: 73.38%
# Epoch 21/50 - Loss: 0.5389 - Validation Accuracy: 73.45%
# Epoch 22/50 - Loss: 0.5384 - Validation Accuracy: 73.42%
# Epoch 23/50 - Loss: 0.5378 - Validation Accuracy: 73.37%
# Epoch 24/50 - Loss: 0.5384 - Validation Accuracy: 73.23%
# Epoch 25/50 - Loss: 0.5381 - Validation Accuracy: 73.25%
# Epoch 26/50 - Loss: 0.5372 - Validation Accuracy: 73.23%
# Epoch 27/50 - Loss: 0.5372 - Validation Accuracy: 73.29%
# Epoch 28/50 - Loss: 0.5376 - Validation Accuracy: 73.35%
# Epoch 29/50 - Loss: 0.5375 - Validation Accuracy: 73.36%
# Epoch 30/50 - Loss: 0.5372 - Validation Accuracy: 73.54%
# Epoch 31/50 - Loss: 0.5369 - Validation Accuracy: 73.54%
# Epoch 32/50 - Loss: 0.5368 - Validation Accuracy: 73.48%
# Epoch 33/50 - Loss: 0.5367 - Validation Accuracy: 73.52%
# Epoch 34/50 - Loss: 0.5368 - Validation Accuracy: 73.50%
# Epoch 35/50 - Loss: 0.5365 - Validation Accuracy: 73.22%
# Epoch 36/50 - Loss: 0.5361 - Validation Accuracy: 73.40%
# Epoch 37/50 - Loss: 0.5353 - Validation Accuracy: 73.39%
# Epoch 38/50 - Loss: 0.5358 - Validation Accuracy: 73.35%
# Epoch 39/50 - Loss: 0.5355 - Validation Accuracy: 73.46%
# Epoch 40/50 - Loss: 0.5356 - Validation Accuracy: 73.12%
# Epoch 41/50 - Loss: 0.5356 - Validation Accuracy: 73.37%
# Epoch 42/50 - Loss: 0.5351 - Validation Accuracy: 73.35%
# Epoch 43/50 - Loss: 0.5350 - Validation Accuracy: 73.09%
# Epoch 44/50 - Loss: 0.5351 - Validation Accuracy: 73.27%
# Epoch 45/50 - Loss: 0.5344 - Validation Accuracy: 73.34%
# Epoch 46/50 - Loss: 0.5343 - Validation Accuracy: 73.38%
# Epoch 47/50 - Loss: 0.5343 - Validation Accuracy: 73.32%
# Epoch 48/50 - Loss: 0.5340 - Validation Accuracy: 73.10%
# Epoch 49/50 - Loss: 0.5341 - Validation Accuracy: 73.30%
# Epoch 50/50 - Loss: 0.5340 - Validation Accuracy: 73.35%
# Saved model file: best_model_epoch50_fold4_ValAcc0.736.pth
# Test Fold 4: Test Accuracy: 72.96%, F1 Score: 0.721, Precision: 0.743, Recall: 0.701, AUC: 0.798
# --- Fold 5/5 ---
# Epoch 1/50 - Loss: 0.5810 - Validation Accuracy: 72.28%
# Epoch 2/50 - Loss: 0.5489 - Validation Accuracy: 72.20%
# Epoch 3/50 - Loss: 0.5451 - Validation Accuracy: 72.76%
# Epoch 4/50 - Loss: 0.5446 - Validation Accuracy: 73.11%
# Epoch 5/50 - Loss: 0.5431 - Validation Accuracy: 72.73%
# Epoch 6/50 - Loss: 0.5423 - Validation Accuracy: 72.88%
# Epoch 7/50 - Loss: 0.5417 - Validation Accuracy: 72.94%
# Epoch 8/50 - Loss: 0.5423 - Validation Accuracy: 73.09%
# Epoch 9/50 - Loss: 0.5410 - Validation Accuracy: 73.30%
# Epoch 10/50 - Loss: 0.5409 - Validation Accuracy: 73.13%
# Epoch 11/50 - Loss: 0.5402 - Validation Accuracy: 73.19%
# Epoch 12/50 - Loss: 0.5404 - Validation Accuracy: 72.99%
# Epoch 13/50 - Loss: 0.5404 - Validation Accuracy: 72.90%
# Epoch 14/50 - Loss: 0.5399 - Validation Accuracy: 72.97%
# Epoch 15/50 - Loss: 0.5395 - Validation Accuracy: 73.08%
# Epoch 16/50 - Loss: 0.5392 - Validation Accuracy: 72.95%
# Epoch 17/50 - Loss: 0.5388 - Validation Accuracy: 73.04%
# Epoch 18/50 - Loss: 0.5383 - Validation Accuracy: 73.01%
# Epoch 19/50 - Loss: 0.5383 - Validation Accuracy: 72.84%
# Epoch 20/50 - Loss: 0.5384 - Validation Accuracy: 73.24%
# Epoch 21/50 - Loss: 0.5388 - Validation Accuracy: 72.41%
# Epoch 22/50 - Loss: 0.5380 - Validation Accuracy: 72.54%
# Epoch 23/50 - Loss: 0.5375 - Validation Accuracy: 72.88%
# Epoch 24/50 - Loss: 0.5374 - Validation Accuracy: 72.92%
# Epoch 25/50 - Loss: 0.5373 - Validation Accuracy: 73.24%
# Epoch 26/50 - Loss: 0.5368 - Validation Accuracy: 72.71%
# Epoch 27/50 - Loss: 0.5372 - Validation Accuracy: 73.12%
# Epoch 28/50 - Loss: 0.5366 - Validation Accuracy: 73.32%
# Epoch 29/50 - Loss: 0.5366 - Validation Accuracy: 73.13%
# Epoch 30/50 - Loss: 0.5367 - Validation Accuracy: 72.71%
# Epoch 31/50 - Loss: 0.5363 - Validation Accuracy: 73.21%
# Epoch 32/50 - Loss: 0.5366 - Validation Accuracy: 73.03%
# Epoch 33/50 - Loss: 0.5359 - Validation Accuracy: 73.17%
# Epoch 34/50 - Loss: 0.5362 - Validation Accuracy: 73.33%
# Epoch 35/50 - Loss: 0.5353 - Validation Accuracy: 72.97%
# Epoch 36/50 - Loss: 0.5355 - Validation Accuracy: 73.16%
# Epoch 37/50 - Loss: 0.5355 - Validation Accuracy: 73.00%
# Epoch 38/50 - Loss: 0.5348 - Validation Accuracy: 73.11%
# Epoch 39/50 - Loss: 0.5355 - Validation Accuracy: 72.96%
# Epoch 40/50 - Loss: 0.5349 - Validation Accuracy: 73.02%
# Epoch 41/50 - Loss: 0.5343 - Validation Accuracy: 72.66%
# Epoch 42/50 - Loss: 0.5349 - Validation Accuracy: 72.98%
# Epoch 43/50 - Loss: 0.5340 - Validation Accuracy: 72.88%
# Epoch 44/50 - Loss: 0.5338 - Validation Accuracy: 73.09%
# Epoch 45/50 - Loss: 0.5333 - Validation Accuracy: 72.99%
# Epoch 46/50 - Loss: 0.5336 - Validation Accuracy: 73.28%
# Epoch 47/50 - Loss: 0.5335 - Validation Accuracy: 72.81%
# Epoch 48/50 - Loss: 0.5330 - Validation Accuracy: 73.04%
# Epoch 49/50 - Loss: 0.5325 - Validation Accuracy: 73.43%
# Epoch 50/50 - Loss: 0.5322 - Validation Accuracy: 72.87%
# Saved model file: best_model_epoch50_fold5_ValAcc0.734.pth
# Test Fold 5: Test Accuracy: 72.67%, F1 Score: 0.704, Precision: 0.768, Recall: 0.649, AUC: 0.794
# Average test results: Test Accuracy: 72.81%, F1 Score: 0.709, AUC: 0.795, Recall: 0.663
