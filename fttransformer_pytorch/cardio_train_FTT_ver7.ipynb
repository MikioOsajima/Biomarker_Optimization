# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import (
    accuracy_score, f1_score, precision_score,
    recall_score, roc_auc_score, roc_curve, confusion_matrix
)
import matplotlib.pyplot as plt
import seaborn as sns
from fttransformer import FTTransformer

# --------------------------------------------
# 設定
# --------------------------------------------
DATA_PATH = "/home/osajima/ドキュメント/program/Transformer_Study/fttransformer_pytorch/cardio_train.csv"
TEST_RATIO = 0.2
K_FOLDS = 5
EPOCHS = 100
BATCH_SIZE = 128
LR = 1e-4

# 保存ディレクトリ
SAVE_DIR = os.path.join(os.getcwd(), "save_models")
IMAGE_DIR = os.path.join(os.getcwd(), "save_confusion_matrix_images")
os.makedirs(IMAGE_DIR, exist_ok=True)
os.makedirs(SAVE_DIR, exist_ok=True)
# --------------------------------------------
# データ読み込み・前処理
# --------------------------------------------
data = pd.read_csv(DATA_PATH, sep=';')
data.drop(columns=["id"], inplace=True)
X = data.drop(columns=["cardio"])
y = data["cardio"]

categorical_cols = ["gender","cholesterol","gluc","smoke","alco","active"]
continuous_cols = ["age","height","weight","ap_hi","ap_lo"]
for col in categorical_cols:
    X[col] = LabelEncoder().fit_transform(X[col])
X[continuous_cols] = StandardScaler().fit_transform(X[continuous_cols])

# テストセット分離
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y, test_size=TEST_RATIO, random_state=42, stratify=y
)

# DataLoader ヘルパー
class CardioDataset(Dataset):
    def __init__(self, X, y):
        self.X_cat = torch.tensor(X[categorical_cols].values, dtype=torch.long)
        self.X_cont = torch.tensor(X[continuous_cols].values, dtype=torch.float32)
        self.y = torch.tensor(y.values, dtype=torch.float32).unsqueeze(1)
    def __len__(self): return len(self.y)
    def __getitem__(self, idx): return self.X_cat[idx], self.X_cont[idx], self.y[idx]

def get_loader(X, y, shuffle=False):
    return DataLoader(CardioDataset(X, y), batch_size=BATCH_SIZE, shuffle=shuffle)

test_loader = get_loader(X_test, y_test)

def plot_all_metrics(train_losses, train_accs, val_accs,
                    y_true, y_pred, y_prob,
                    fold, val_acc, test_acc, save_dir):
    cm = confusion_matrix(y_true, y_pred)
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    auc = roc_auc_score(y_true, y_prob)
    acc = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred)
    rec = recall_score(y_true, y_pred)

    fig, axs = plt.subplots(2, 2, figsize=(12, 10))
    axs[0, 0].plot(range(1, len(train_losses) + 1), train_losses, 'o-')
    axs[0, 0].set_title("Training Loss")
    axs[0, 0].grid(True)

    axs[0, 1].plot(range(1, len(train_accs) + 1), train_accs, 'o-', label='Training Accuracy')
    axs[0, 1].plot(range(1, len(val_accs) + 1), val_accs, 'x-', label='Validation Accuracy')
    axs[0, 1].set_title("Accuracy")
    axs[0, 1].legend()
    axs[0, 1].grid(True)

    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axs[1, 0])
    axs[1, 0].set_title("Confusion Matrix")
    axs[1, 0].set_xticklabels(['No Cardio', 'Cardio'])
    axs[1, 0].set_yticklabels(['No Cardio', 'Cardio'], rotation=0)

    axs[1, 1].plot(fpr, tpr, label=f'AUC = {auc:.3f}')
    axs[1, 1].plot([0, 1], [0, 1], 'k--')
    axs[1, 1].set_title('ROC Curve')
    axs[1, 1].legend(loc='lower right')
    axs[1, 1].text(0.05, 0.2,
                f"Accuracy: {acc:.3f}\nF1 Score: {f1:.3f}\nPrecision: {prec:.3f}\nRecall: {rec:.3f}",
                bbox=dict(facecolor='white', alpha=0.7))

    fig.tight_layout()
    # 保存ファイル名を省略せず作成
    fname = (
        f"confusion_matrix_Epoch{EPOCHS}_Fold{fold}_ValAcc{val_acc:.3f}"
        f"_TestAccuracy{test_acc:.3f}.png"
    )
    save_path = os.path.join(save_dir, fname)
    fig.savefig(save_path, dpi=200, bbox_inches='tight')
    plt.show()
    plt.close(fig)

# K-Fold CV
kf = KFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
fold_results = []

for fold, (tr, va) in enumerate(kf.split(X_train_val, y_train_val), 1):
    print(f"\n--- Fold {fold}/{K_FOLDS} ---")
    X_tr, y_tr = X_train_val.iloc[tr], y_train_val.iloc[tr]
    X_va, y_va = X_train_val.iloc[va], y_train_val.iloc[va]
    train_loader = get_loader(X_tr, y_tr, True)
    val_loader = get_loader(X_va, y_va)

    model = FTTransformer(
        categories=[X[c].nunique() for c in categorical_cols],
        num_continuous=len(continuous_cols), dim=64, depth=6, heads=8,
        ff_dropout=0.2, attn_dropout=0.2
    ).to(device)
    optimizer = optim.AdamW(model.parameters(), lr=LR)
    criterion = nn.BCEWithLogitsLoss()

    best_val_acc = 0.0
    best_state = None
    train_losses, train_accs, val_accs = [], [], []

    for epoch in range(1, EPOCHS + 1):
        model.train()
        total_loss = 0.0
        for x_cat, x_cont, labels in train_loader:
            x_cat, x_cont, labels = x_cat.to(device), x_cont.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(x_cat, x_cont)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        avg_loss = total_loss / len(train_loader)
        train_losses.append(avg_loss)

        model.eval()
        tc, tt = 0, 0
        with torch.no_grad():
            for x_cat, x_cont, labels in train_loader:
                preds = (torch.sigmoid(model(x_cat.to(device), x_cont.to(device))) > 0.5).float()
                tc += (preds.cpu() == labels).sum().item()
                tt += labels.size(0)
        train_accs.append(tc / tt)

        preds, probs, labs = [], [], []
        with torch.no_grad():
            for x_cat, x_cont, labels in val_loader:
                pr = torch.sigmoid(model(x_cat.to(device), x_cont.to(device))).cpu().numpy()
                preds.extend((pr > 0.5).astype(int).flatten())
                probs.extend(pr.flatten())
                labs.extend(labels.numpy())
        val_acc = accuracy_score(labs, preds)
        val_accs.append(val_acc)

        # Lossと百分率表示
        print(f"Epoch {epoch}/{EPOCHS} - Loss: {avg_loss:.4f} - Validation Accuracy: {val_acc*100:.2f}%")
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_state = model.state_dict().copy()

    # モデル保存
    model_name = (
        f"best_model_epoch{EPOCHS}_fold{fold}_ValAcc{best_val_acc:.3f}.pth"
    )
    model_path = os.path.join(SAVE_DIR, model_name)
    torch.save(best_state, model_path)
    print(f"Saved model file: {model_name}")

    # テスト評価
    best_model = FTTransformer(
        categories=[X[c].nunique() for c in categorical_cols],
        num_continuous=len(continuous_cols), dim=64, depth=6, heads=8,
        ff_dropout=0.2, attn_dropout=0.2
    ).to(device)
    best_model.load_state_dict(torch.load(model_path))
    best_model.eval()

    y_t, y_p, y_pr = [], [], []
    with torch.no_grad():
        for x_cat, x_cont, labels in test_loader:
            pr = torch.sigmoid(best_model(x_cat.to(device), x_cont.to(device))).cpu().numpy()
            y_p.extend((pr > 0.5).astype(int).flatten())
            y_pr.extend(pr.flatten())
            y_t.extend(labels.numpy())
    test_acc = accuracy_score(y_t, y_p)
    f1s = f1_score(y_t, y_p)
    prec = precision_score(y_t, y_p)
    rec = recall_score(y_t, y_p)
    auc_val = roc_auc_score(y_t, y_pr)
    print(f"Test Fold {fold}: Test Accuracy: {test_acc*100:.2f}%, F1 Score: {f1s:.3f}, Precision: {prec:.3f}, Recall: {rec:.3f}, AUC: {auc_val:.3f}")

    # プロット・保存
    plot_all_metrics(
        train_losses, train_accs, val_accs,
        y_t, y_p, y_pr,
        fold, best_val_acc, test_acc, IMAGE_DIR
    )
    fold_results.append((test_acc, f1s, auc_val, rec))

# 平均結果表示
avg = [np.mean([r[i] for r in fold_results]) for i in range(4)]
print(f"Average test results: Test Accuracy: {avg[0]*100:.2f}%, F1 Score: {avg[1]:.3f}, AUC: {avg[2]:.3f}, Recall: {avg[3]:.3f}")
# Out:
# --- Fold 1/5 ---
# Epoch 1/100 - Loss: 0.5683 - Validation Accuracy: 71.99%
# Epoch 2/100 - Loss: 0.5467 - Validation Accuracy: 72.74%
# Epoch 3/100 - Loss: 0.5439 - Validation Accuracy: 72.96%
# Epoch 4/100 - Loss: 0.5423 - Validation Accuracy: 73.46%
# Epoch 5/100 - Loss: 0.5407 - Validation Accuracy: 73.44%
# Epoch 6/100 - Loss: 0.5415 - Validation Accuracy: 73.46%
# Epoch 7/100 - Loss: 0.5406 - Validation Accuracy: 72.98%
# Epoch 8/100 - Loss: 0.5405 - Validation Accuracy: 73.56%
# Epoch 9/100 - Loss: 0.5398 - Validation Accuracy: 73.32%
# Epoch 10/100 - Loss: 0.5389 - Validation Accuracy: 73.19%
# Epoch 11/100 - Loss: 0.5388 - Validation Accuracy: 73.52%
# Epoch 12/100 - Loss: 0.5386 - Validation Accuracy: 73.28%
# Epoch 13/100 - Loss: 0.5382 - Validation Accuracy: 73.03%
# Epoch 14/100 - Loss: 0.5376 - Validation Accuracy: 73.24%
# Epoch 15/100 - Loss: 0.5372 - Validation Accuracy: 73.04%
# Epoch 16/100 - Loss: 0.5376 - Validation Accuracy: 73.29%
# Epoch 17/100 - Loss: 0.5369 - Validation Accuracy: 73.27%
# Epoch 18/100 - Loss: 0.5365 - Validation Accuracy: 73.07%
# Epoch 19/100 - Loss: 0.5366 - Validation Accuracy: 72.94%
# Epoch 20/100 - Loss: 0.5362 - Validation Accuracy: 73.18%
# Epoch 21/100 - Loss: 0.5365 - Validation Accuracy: 73.47%
# Epoch 22/100 - Loss: 0.5361 - Validation Accuracy: 73.22%
# Epoch 23/100 - Loss: 0.5355 - Validation Accuracy: 73.23%
# Epoch 24/100 - Loss: 0.5354 - Validation Accuracy: 73.40%
# Epoch 25/100 - Loss: 0.5348 - Validation Accuracy: 73.20%
# Epoch 26/100 - Loss: 0.5345 - Validation Accuracy: 73.21%
# Epoch 27/100 - Loss: 0.5341 - Validation Accuracy: 73.33%
# Epoch 28/100 - Loss: 0.5343 - Validation Accuracy: 73.61%
# Epoch 29/100 - Loss: 0.5339 - Validation Accuracy: 73.01%
# Epoch 30/100 - Loss: 0.5338 - Validation Accuracy: 73.53%
# Epoch 31/100 - Loss: 0.5331 - Validation Accuracy: 73.16%
# Epoch 32/100 - Loss: 0.5328 - Validation Accuracy: 73.12%
# Epoch 33/100 - Loss: 0.5320 - Validation Accuracy: 72.84%
# Epoch 34/100 - Loss: 0.5319 - Validation Accuracy: 73.00%
# Epoch 35/100 - Loss: 0.5314 - Validation Accuracy: 73.12%
# Epoch 36/100 - Loss: 0.5303 - Validation Accuracy: 73.15%
# Epoch 37/100 - Loss: 0.5303 - Validation Accuracy: 73.25%
# Epoch 38/100 - Loss: 0.5300 - Validation Accuracy: 73.15%
# Epoch 39/100 - Loss: 0.5293 - Validation Accuracy: 73.04%
# Epoch 40/100 - Loss: 0.5286 - Validation Accuracy: 73.18%
# Epoch 41/100 - Loss: 0.5285 - Validation Accuracy: 73.18%
# Epoch 42/100 - Loss: 0.5276 - Validation Accuracy: 73.05%
# Epoch 43/100 - Loss: 0.5274 - Validation Accuracy: 73.06%
# Epoch 44/100 - Loss: 0.5266 - Validation Accuracy: 73.04%
# Epoch 45/100 - Loss: 0.5261 - Validation Accuracy: 73.21%
# Epoch 46/100 - Loss: 0.5256 - Validation Accuracy: 72.97%
# Epoch 47/100 - Loss: 0.5253 - Validation Accuracy: 73.00%
# Epoch 48/100 - Loss: 0.5243 - Validation Accuracy: 73.02%
# Epoch 49/100 - Loss: 0.5236 - Validation Accuracy: 72.58%
# Epoch 50/100 - Loss: 0.5225 - Validation Accuracy: 72.59%
# Epoch 51/100 - Loss: 0.5211 - Validation Accuracy: 72.84%
# Epoch 52/100 - Loss: 0.5208 - Validation Accuracy: 72.75%
# Epoch 53/100 - Loss: 0.5210 - Validation Accuracy: 72.75%
# Epoch 54/100 - Loss: 0.5205 - Validation Accuracy: 72.83%
# Epoch 55/100 - Loss: 0.5195 - Validation Accuracy: 72.74%
# Epoch 56/100 - Loss: 0.5177 - Validation Accuracy: 72.69%
# Epoch 57/100 - Loss: 0.5176 - Validation Accuracy: 72.64%
# Epoch 58/100 - Loss: 0.5161 - Validation Accuracy: 72.57%
# Epoch 59/100 - Loss: 0.5165 - Validation Accuracy: 72.94%
# Epoch 60/100 - Loss: 0.5141 - Validation Accuracy: 72.40%
# Epoch 61/100 - Loss: 0.5146 - Validation Accuracy: 72.23%
# Epoch 62/100 - Loss: 0.5134 - Validation Accuracy: 72.55%
# Epoch 63/100 - Loss: 0.5124 - Validation Accuracy: 72.32%
# Epoch 64/100 - Loss: 0.5127 - Validation Accuracy: 72.39%
# Epoch 65/100 - Loss: 0.5108 - Validation Accuracy: 72.71%
# Epoch 66/100 - Loss: 0.5103 - Validation Accuracy: 72.42%
# Epoch 67/100 - Loss: 0.5098 - Validation Accuracy: 72.70%
# Epoch 68/100 - Loss: 0.5086 - Validation Accuracy: 71.97%
# Epoch 69/100 - Loss: 0.5070 - Validation Accuracy: 72.13%
# Epoch 70/100 - Loss: 0.5068 - Validation Accuracy: 72.36%
# Epoch 71/100 - Loss: 0.5051 - Validation Accuracy: 72.11%
# Epoch 72/100 - Loss: 0.5034 - Validation Accuracy: 72.02%
# Epoch 73/100 - Loss: 0.5042 - Validation Accuracy: 72.12%
# Epoch 74/100 - Loss: 0.5035 - Validation Accuracy: 72.16%
# Epoch 75/100 - Loss: 0.5014 - Validation Accuracy: 71.99%
# Epoch 76/100 - Loss: 0.5005 - Validation Accuracy: 72.21%
# Epoch 77/100 - Loss: 0.5007 - Validation Accuracy: 72.13%
# Epoch 78/100 - Loss: 0.4985 - Validation Accuracy: 71.76%
# Epoch 79/100 - Loss: 0.4970 - Validation Accuracy: 72.19%
# Epoch 80/100 - Loss: 0.4974 - Validation Accuracy: 72.00%
# Epoch 81/100 - Loss: 0.4954 - Validation Accuracy: 72.15%
# Epoch 82/100 - Loss: 0.4938 - Validation Accuracy: 71.98%
# Epoch 83/100 - Loss: 0.4930 - Validation Accuracy: 71.98%
# Epoch 84/100 - Loss: 0.4919 - Validation Accuracy: 71.79%
# Epoch 85/100 - Loss: 0.4904 - Validation Accuracy: 71.46%
# Epoch 86/100 - Loss: 0.4892 - Validation Accuracy: 71.62%
# Epoch 87/100 - Loss: 0.4886 - Validation Accuracy: 71.75%
# Epoch 88/100 - Loss: 0.4882 - Validation Accuracy: 71.88%
# Epoch 89/100 - Loss: 0.4868 - Validation Accuracy: 71.71%
# Epoch 90/100 - Loss: 0.4869 - Validation Accuracy: 72.12%
# Epoch 91/100 - Loss: 0.4858 - Validation Accuracy: 71.62%
# Epoch 92/100 - Loss: 0.4842 - Validation Accuracy: 71.62%
# Epoch 93/100 - Loss: 0.4837 - Validation Accuracy: 71.40%
# Epoch 94/100 - Loss: 0.4806 - Validation Accuracy: 71.30%
# Epoch 95/100 - Loss: 0.4805 - Validation Accuracy: 71.46%
# Epoch 96/100 - Loss: 0.4778 - Validation Accuracy: 71.08%
# Epoch 97/100 - Loss: 0.4790 - Validation Accuracy: 70.94%
# Epoch 98/100 - Loss: 0.4781 - Validation Accuracy: 71.18%
# Epoch 99/100 - Loss: 0.4783 - Validation Accuracy: 71.13%
# Epoch 100/100 - Loss: 0.4739 - Validation Accuracy: 71.28%
# Saved model file: best_model_epoch100_fold1_ValAcc0.736.pth
# Test Fold 1: Test Accuracy: 71.28%, F1 Score: 0.700, Precision: 0.732, Recall: 0.670, AUC: 0.771
# --- Fold 2/5 ---
# Epoch 1/100 - Loss: 0.5687 - Validation Accuracy: 73.73%
# Epoch 2/100 - Loss: 0.5477 - Validation Accuracy: 73.58%
# Epoch 3/100 - Loss: 0.5450 - Validation Accuracy: 73.20%
# Epoch 4/100 - Loss: 0.5440 - Validation Accuracy: 73.47%
# Epoch 5/100 - Loss: 0.5432 - Validation Accuracy: 73.29%
# Epoch 6/100 - Loss: 0.5419 - Validation Accuracy: 73.71%
# Epoch 7/100 - Loss: 0.5425 - Validation Accuracy: 73.72%
# Epoch 8/100 - Loss: 0.5416 - Validation Accuracy: 73.88%
# Epoch 9/100 - Loss: 0.5403 - Validation Accuracy: 73.54%
# Epoch 10/100 - Loss: 0.5407 - Validation Accuracy: 73.97%
# Epoch 11/100 - Loss: 0.5397 - Validation Accuracy: 73.85%
# Epoch 12/100 - Loss: 0.5400 - Validation Accuracy: 73.94%
# Epoch 13/100 - Loss: 0.5396 - Validation Accuracy: 74.16%
# Epoch 14/100 - Loss: 0.5393 - Validation Accuracy: 74.03%
# Epoch 15/100 - Loss: 0.5393 - Validation Accuracy: 72.96%
# Epoch 16/100 - Loss: 0.5383 - Validation Accuracy: 73.85%
# Epoch 17/100 - Loss: 0.5382 - Validation Accuracy: 73.48%
# Epoch 18/100 - Loss: 0.5380 - Validation Accuracy: 74.19%
# Epoch 19/100 - Loss: 0.5374 - Validation Accuracy: 74.02%
# Epoch 20/100 - Loss: 0.5377 - Validation Accuracy: 74.00%
# Epoch 21/100 - Loss: 0.5370 - Validation Accuracy: 73.88%
# Epoch 22/100 - Loss: 0.5368 - Validation Accuracy: 73.93%
# Epoch 23/100 - Loss: 0.5366 - Validation Accuracy: 73.90%
# Epoch 24/100 - Loss: 0.5361 - Validation Accuracy: 73.81%
# Epoch 25/100 - Loss: 0.5363 - Validation Accuracy: 73.96%
# Epoch 26/100 - Loss: 0.5358 - Validation Accuracy: 74.09%
# Epoch 27/100 - Loss: 0.5356 - Validation Accuracy: 73.66%
# Epoch 28/100 - Loss: 0.5351 - Validation Accuracy: 73.89%
# Epoch 29/100 - Loss: 0.5344 - Validation Accuracy: 73.90%
# Epoch 30/100 - Loss: 0.5347 - Validation Accuracy: 74.12%
# Epoch 31/100 - Loss: 0.5338 - Validation Accuracy: 74.10%
# Epoch 32/100 - Loss: 0.5331 - Validation Accuracy: 73.89%
# Epoch 33/100 - Loss: 0.5334 - Validation Accuracy: 73.86%
# Epoch 34/100 - Loss: 0.5325 - Validation Accuracy: 73.71%
# Epoch 35/100 - Loss: 0.5327 - Validation Accuracy: 73.74%
# Epoch 36/100 - Loss: 0.5318 - Validation Accuracy: 73.70%
# Epoch 37/100 - Loss: 0.5317 - Validation Accuracy: 74.03%
# Epoch 38/100 - Loss: 0.5307 - Validation Accuracy: 73.58%
# Epoch 39/100 - Loss: 0.5306 - Validation Accuracy: 73.87%
# Epoch 40/100 - Loss: 0.5304 - Validation Accuracy: 73.83%
# Epoch 41/100 - Loss: 0.5287 - Validation Accuracy: 73.71%
# Epoch 42/100 - Loss: 0.5293 - Validation Accuracy: 73.74%
# Epoch 43/100 - Loss: 0.5281 - Validation Accuracy: 73.81%
# Epoch 44/100 - Loss: 0.5275 - Validation Accuracy: 73.46%
# Epoch 45/100 - Loss: 0.5268 - Validation Accuracy: 73.62%
# Epoch 46/100 - Loss: 0.5260 - Validation Accuracy: 73.49%
# Epoch 47/100 - Loss: 0.5251 - Validation Accuracy: 73.69%
# Epoch 48/100 - Loss: 0.5262 - Validation Accuracy: 73.94%
# Epoch 49/100 - Loss: 0.5247 - Validation Accuracy: 73.74%
# Epoch 50/100 - Loss: 0.5236 - Validation Accuracy: 73.61%
# Epoch 51/100 - Loss: 0.5232 - Validation Accuracy: 73.41%
# Epoch 52/100 - Loss: 0.5214 - Validation Accuracy: 73.78%
# Epoch 53/100 - Loss: 0.5212 - Validation Accuracy: 73.46%
# Epoch 54/100 - Loss: 0.5201 - Validation Accuracy: 73.56%
# Epoch 55/100 - Loss: 0.5195 - Validation Accuracy: 73.55%
# Epoch 56/100 - Loss: 0.5200 - Validation Accuracy: 73.65%
# Epoch 57/100 - Loss: 0.5180 - Validation Accuracy: 73.29%
# Epoch 58/100 - Loss: 0.5174 - Validation Accuracy: 73.36%
# Epoch 59/100 - Loss: 0.5161 - Validation Accuracy: 73.34%
# Epoch 60/100 - Loss: 0.5156 - Validation Accuracy: 73.36%
# Epoch 61/100 - Loss: 0.5141 - Validation Accuracy: 73.27%
# Epoch 62/100 - Loss: 0.5138 - Validation Accuracy: 73.29%
# Epoch 63/100 - Loss: 0.5128 - Validation Accuracy: 73.31%
# Epoch 64/100 - Loss: 0.5125 - Validation Accuracy: 73.21%
# Epoch 65/100 - Loss: 0.5107 - Validation Accuracy: 73.27%
# Epoch 66/100 - Loss: 0.5096 - Validation Accuracy: 73.23%
# Epoch 67/100 - Loss: 0.5087 - Validation Accuracy: 73.12%
# Epoch 68/100 - Loss: 0.5097 - Validation Accuracy: 73.06%
# Epoch 69/100 - Loss: 0.5067 - Validation Accuracy: 72.90%
# Epoch 70/100 - Loss: 0.5060 - Validation Accuracy: 73.40%
# Epoch 71/100 - Loss: 0.5062 - Validation Accuracy: 72.65%
# Epoch 72/100 - Loss: 0.5049 - Validation Accuracy: 72.85%
# Epoch 73/100 - Loss: 0.5029 - Validation Accuracy: 72.76%
# Epoch 74/100 - Loss: 0.5030 - Validation Accuracy: 72.24%
# Epoch 75/100 - Loss: 0.5020 - Validation Accuracy: 72.47%
# Epoch 76/100 - Loss: 0.5004 - Validation Accuracy: 72.42%
# Epoch 77/100 - Loss: 0.4994 - Validation Accuracy: 72.45%
# Epoch 78/100 - Loss: 0.5005 - Validation Accuracy: 72.41%
# Epoch 79/100 - Loss: 0.4977 - Validation Accuracy: 72.66%
# Epoch 80/100 - Loss: 0.4945 - Validation Accuracy: 72.46%
# Epoch 81/100 - Loss: 0.4950 - Validation Accuracy: 72.36%
# Epoch 82/100 - Loss: 0.4955 - Validation Accuracy: 72.24%
# Epoch 83/100 - Loss: 0.4936 - Validation Accuracy: 72.40%
# Epoch 84/100 - Loss: 0.4926 - Validation Accuracy: 72.44%
# Epoch 85/100 - Loss: 0.4920 - Validation Accuracy: 72.54%
# Epoch 86/100 - Loss: 0.4912 - Validation Accuracy: 72.38%
# Epoch 87/100 - Loss: 0.4902 - Validation Accuracy: 72.38%
# Epoch 88/100 - Loss: 0.4875 - Validation Accuracy: 71.98%
# Epoch 89/100 - Loss: 0.4867 - Validation Accuracy: 72.13%
# Epoch 90/100 - Loss: 0.4866 - Validation Accuracy: 71.69%
# Epoch 91/100 - Loss: 0.4848 - Validation Accuracy: 72.09%
# Epoch 92/100 - Loss: 0.4829 - Validation Accuracy: 71.74%
# Epoch 93/100 - Loss: 0.4821 - Validation Accuracy: 71.54%
# Epoch 94/100 - Loss: 0.4818 - Validation Accuracy: 71.31%
# Epoch 95/100 - Loss: 0.4813 - Validation Accuracy: 71.96%
# Epoch 96/100 - Loss: 0.4788 - Validation Accuracy: 71.79%
# Epoch 97/100 - Loss: 0.4806 - Validation Accuracy: 71.99%
# Epoch 98/100 - Loss: 0.4771 - Validation Accuracy: 71.58%
# Epoch 99/100 - Loss: 0.4763 - Validation Accuracy: 71.75%
# Epoch 100/100 - Loss: 0.4747 - Validation Accuracy: 71.86%
# Saved model file: best_model_epoch100_fold2_ValAcc0.742.pth
# Test Fold 2: Test Accuracy: 71.71%, F1 Score: 0.705, Precision: 0.737, Recall: 0.675, AUC: 0.774
# --- Fold 3/5 ---
# Epoch 1/100 - Loss: 0.5666 - Validation Accuracy: 73.18%
# Epoch 2/100 - Loss: 0.5491 - Validation Accuracy: 73.21%
# Epoch 3/100 - Loss: 0.5456 - Validation Accuracy: 73.56%
# Epoch 4/100 - Loss: 0.5440 - Validation Accuracy: 73.48%
# Epoch 5/100 - Loss: 0.5442 - Validation Accuracy: 73.46%
# Epoch 6/100 - Loss: 0.5427 - Validation Accuracy: 73.31%
# Epoch 7/100 - Loss: 0.5426 - Validation Accuracy: 73.37%
# Epoch 8/100 - Loss: 0.5419 - Validation Accuracy: 73.46%
# Epoch 9/100 - Loss: 0.5412 - Validation Accuracy: 73.70%
# Epoch 10/100 - Loss: 0.5407 - Validation Accuracy: 73.71%
# Epoch 11/100 - Loss: 0.5411 - Validation Accuracy: 73.65%
# Epoch 12/100 - Loss: 0.5399 - Validation Accuracy: 73.36%
# Epoch 13/100 - Loss: 0.5403 - Validation Accuracy: 73.67%
# Epoch 14/100 - Loss: 0.5392 - Validation Accuracy: 73.62%
# Epoch 15/100 - Loss: 0.5391 - Validation Accuracy: 73.66%
# Epoch 16/100 - Loss: 0.5385 - Validation Accuracy: 73.53%
# Epoch 17/100 - Loss: 0.5387 - Validation Accuracy: 73.59%
# Epoch 18/100 - Loss: 0.5380 - Validation Accuracy: 73.59%
# Epoch 19/100 - Loss: 0.5378 - Validation Accuracy: 73.78%
# Epoch 20/100 - Loss: 0.5377 - Validation Accuracy: 73.67%
# Epoch 21/100 - Loss: 0.5375 - Validation Accuracy: 73.64%
# Epoch 22/100 - Loss: 0.5366 - Validation Accuracy: 73.64%
# Epoch 23/100 - Loss: 0.5368 - Validation Accuracy: 73.60%
# Epoch 24/100 - Loss: 0.5365 - Validation Accuracy: 73.62%
# Epoch 25/100 - Loss: 0.5365 - Validation Accuracy: 73.56%
# Epoch 26/100 - Loss: 0.5365 - Validation Accuracy: 73.76%
# Epoch 27/100 - Loss: 0.5360 - Validation Accuracy: 73.63%
# Epoch 28/100 - Loss: 0.5351 - Validation Accuracy: 73.55%
# Epoch 29/100 - Loss: 0.5343 - Validation Accuracy: 73.47%
# Epoch 30/100 - Loss: 0.5345 - Validation Accuracy: 73.77%
# Epoch 31/100 - Loss: 0.5341 - Validation Accuracy: 73.76%
# Epoch 32/100 - Loss: 0.5340 - Validation Accuracy: 73.45%
# Epoch 33/100 - Loss: 0.5328 - Validation Accuracy: 73.62%
# Epoch 34/100 - Loss: 0.5325 - Validation Accuracy: 73.30%
# Epoch 35/100 - Loss: 0.5323 - Validation Accuracy: 73.59%
# Epoch 36/100 - Loss: 0.5316 - Validation Accuracy: 73.50%
# Epoch 37/100 - Loss: 0.5315 - Validation Accuracy: 73.54%
# Epoch 38/100 - Loss: 0.5308 - Validation Accuracy: 73.53%
# Epoch 39/100 - Loss: 0.5300 - Validation Accuracy: 73.50%
# Epoch 40/100 - Loss: 0.5294 - Validation Accuracy: 73.47%
# Epoch 41/100 - Loss: 0.5296 - Validation Accuracy: 73.42%
# Epoch 42/100 - Loss: 0.5283 - Validation Accuracy: 73.60%
# Epoch 43/100 - Loss: 0.5277 - Validation Accuracy: 73.46%
# Epoch 44/100 - Loss: 0.5268 - Validation Accuracy: 73.01%
# Epoch 45/100 - Loss: 0.5268 - Validation Accuracy: 73.44%
# Epoch 46/100 - Loss: 0.5255 - Validation Accuracy: 73.47%
# Epoch 47/100 - Loss: 0.5258 - Validation Accuracy: 73.27%
# Epoch 48/100 - Loss: 0.5248 - Validation Accuracy: 73.03%
# Epoch 49/100 - Loss: 0.5237 - Validation Accuracy: 73.13%
# Epoch 50/100 - Loss: 0.5228 - Validation Accuracy: 73.35%
# Epoch 51/100 - Loss: 0.5227 - Validation Accuracy: 73.21%
# Epoch 52/100 - Loss: 0.5216 - Validation Accuracy: 73.44%
# Epoch 53/100 - Loss: 0.5214 - Validation Accuracy: 73.19%
# Epoch 54/100 - Loss: 0.5199 - Validation Accuracy: 73.09%
# Epoch 55/100 - Loss: 0.5201 - Validation Accuracy: 72.99%
# Epoch 56/100 - Loss: 0.5181 - Validation Accuracy: 73.22%
# Epoch 57/100 - Loss: 0.5170 - Validation Accuracy: 72.88%
# Epoch 58/100 - Loss: 0.5165 - Validation Accuracy: 73.23%
# Epoch 59/100 - Loss: 0.5161 - Validation Accuracy: 72.72%
# Epoch 60/100 - Loss: 0.5146 - Validation Accuracy: 73.26%
# Epoch 61/100 - Loss: 0.5130 - Validation Accuracy: 72.90%
# Epoch 62/100 - Loss: 0.5130 - Validation Accuracy: 73.09%
# Epoch 63/100 - Loss: 0.5128 - Validation Accuracy: 73.11%
# Epoch 64/100 - Loss: 0.5118 - Validation Accuracy: 72.82%
# Epoch 65/100 - Loss: 0.5099 - Validation Accuracy: 72.79%
# Epoch 66/100 - Loss: 0.5085 - Validation Accuracy: 72.78%
# Epoch 67/100 - Loss: 0.5079 - Validation Accuracy: 72.86%
# Epoch 68/100 - Loss: 0.5074 - Validation Accuracy: 72.74%
# Epoch 69/100 - Loss: 0.5067 - Validation Accuracy: 72.40%
# Epoch 70/100 - Loss: 0.5063 - Validation Accuracy: 72.42%
# Epoch 71/100 - Loss: 0.5033 - Validation Accuracy: 72.30%
# Epoch 72/100 - Loss: 0.5037 - Validation Accuracy: 72.16%
# Epoch 73/100 - Loss: 0.5006 - Validation Accuracy: 72.46%
# Epoch 74/100 - Loss: 0.5019 - Validation Accuracy: 72.80%
# Epoch 75/100 - Loss: 0.4996 - Validation Accuracy: 72.27%
# Epoch 76/100 - Loss: 0.4984 - Validation Accuracy: 72.54%
# Epoch 77/100 - Loss: 0.4964 - Validation Accuracy: 72.82%
# Epoch 78/100 - Loss: 0.4970 - Validation Accuracy: 72.74%
# Epoch 79/100 - Loss: 0.4947 - Validation Accuracy: 72.50%
# Epoch 80/100 - Loss: 0.4955 - Validation Accuracy: 71.71%
# Epoch 81/100 - Loss: 0.4928 - Validation Accuracy: 72.27%
# Epoch 82/100 - Loss: 0.4922 - Validation Accuracy: 72.42%
# Epoch 83/100 - Loss: 0.4922 - Validation Accuracy: 72.52%
# Epoch 84/100 - Loss: 0.4892 - Validation Accuracy: 72.67%
# Epoch 85/100 - Loss: 0.4898 - Validation Accuracy: 72.46%
# Epoch 86/100 - Loss: 0.4884 - Validation Accuracy: 72.19%
# Epoch 87/100 - Loss: 0.4869 - Validation Accuracy: 72.08%
# Epoch 88/100 - Loss: 0.4870 - Validation Accuracy: 72.38%
# Epoch 89/100 - Loss: 0.4851 - Validation Accuracy: 71.88%
# Epoch 90/100 - Loss: 0.4838 - Validation Accuracy: 72.05%
# Epoch 91/100 - Loss: 0.4833 - Validation Accuracy: 72.18%
# Epoch 92/100 - Loss: 0.4826 - Validation Accuracy: 71.89%
# Epoch 93/100 - Loss: 0.4796 - Validation Accuracy: 72.04%
# Epoch 94/100 - Loss: 0.4793 - Validation Accuracy: 71.80%
# Epoch 95/100 - Loss: 0.4784 - Validation Accuracy: 71.76%
# Epoch 96/100 - Loss: 0.4772 - Validation Accuracy: 72.04%
# Epoch 97/100 - Loss: 0.4758 - Validation Accuracy: 71.80%
# Epoch 98/100 - Loss: 0.4761 - Validation Accuracy: 71.67%
# Epoch 99/100 - Loss: 0.4740 - Validation Accuracy: 71.85%
# Epoch 100/100 - Loss: 0.4720 - Validation Accuracy: 71.77%
# Saved model file: best_model_epoch100_fold3_ValAcc0.738.pth
# Test Fold 3: Test Accuracy: 71.36%, F1 Score: 0.701, Precision: 0.732, Recall: 0.673, AUC: 0.769
# --- Fold 4/5 ---
# Epoch 1/100 - Loss: 0.5695 - Validation Accuracy: 73.23%
# Epoch 2/100 - Loss: 0.5461 - Validation Accuracy: 73.12%
# Epoch 3/100 - Loss: 0.5455 - Validation Accuracy: 73.09%
# Epoch 4/100 - Loss: 0.5429 - Validation Accuracy: 73.51%
# Epoch 5/100 - Loss: 0.5423 - Validation Accuracy: 73.13%
# Epoch 6/100 - Loss: 0.5412 - Validation Accuracy: 73.30%
# Epoch 7/100 - Loss: 0.5415 - Validation Accuracy: 73.23%
# Epoch 8/100 - Loss: 0.5405 - Validation Accuracy: 73.57%
# Epoch 9/100 - Loss: 0.5398 - Validation Accuracy: 73.51%
# Epoch 10/100 - Loss: 0.5400 - Validation Accuracy: 73.17%
# Epoch 11/100 - Loss: 0.5396 - Validation Accuracy: 73.40%
# Epoch 12/100 - Loss: 0.5393 - Validation Accuracy: 73.48%
# Epoch 13/100 - Loss: 0.5385 - Validation Accuracy: 73.39%
# Epoch 14/100 - Loss: 0.5390 - Validation Accuracy: 73.57%
# Epoch 15/100 - Loss: 0.5389 - Validation Accuracy: 73.52%
# Epoch 16/100 - Loss: 0.5384 - Validation Accuracy: 73.28%
# Epoch 17/100 - Loss: 0.5376 - Validation Accuracy: 73.46%
# Epoch 18/100 - Loss: 0.5375 - Validation Accuracy: 73.01%
# Epoch 19/100 - Loss: 0.5372 - Validation Accuracy: 73.41%
# Epoch 20/100 - Loss: 0.5369 - Validation Accuracy: 73.26%
# Epoch 21/100 - Loss: 0.5367 - Validation Accuracy: 73.54%
# Epoch 22/100 - Loss: 0.5365 - Validation Accuracy: 73.63%
# Epoch 23/100 - Loss: 0.5363 - Validation Accuracy: 73.48%
# Epoch 24/100 - Loss: 0.5359 - Validation Accuracy: 73.54%
# Epoch 25/100 - Loss: 0.5352 - Validation Accuracy: 73.32%
# Epoch 26/100 - Loss: 0.5349 - Validation Accuracy: 73.50%
# Epoch 27/100 - Loss: 0.5355 - Validation Accuracy: 73.54%
# Epoch 28/100 - Loss: 0.5349 - Validation Accuracy: 73.46%
# Epoch 29/100 - Loss: 0.5351 - Validation Accuracy: 73.38%
# Epoch 30/100 - Loss: 0.5345 - Validation Accuracy: 73.62%
# Epoch 31/100 - Loss: 0.5335 - Validation Accuracy: 73.19%
# Epoch 32/100 - Loss: 0.5335 - Validation Accuracy: 73.41%
# Epoch 33/100 - Loss: 0.5333 - Validation Accuracy: 73.42%
# Epoch 34/100 - Loss: 0.5328 - Validation Accuracy: 73.29%
# Epoch 35/100 - Loss: 0.5324 - Validation Accuracy: 73.41%
# Epoch 36/100 - Loss: 0.5321 - Validation Accuracy: 73.24%
# Epoch 37/100 - Loss: 0.5312 - Validation Accuracy: 73.45%
# Epoch 38/100 - Loss: 0.5315 - Validation Accuracy: 73.13%
# Epoch 39/100 - Loss: 0.5306 - Validation Accuracy: 73.17%
# Epoch 40/100 - Loss: 0.5297 - Validation Accuracy: 73.38%
# Epoch 41/100 - Loss: 0.5291 - Validation Accuracy: 73.30%
# Epoch 42/100 - Loss: 0.5287 - Validation Accuracy: 73.29%
# Epoch 43/100 - Loss: 0.5285 - Validation Accuracy: 73.16%
# Epoch 44/100 - Loss: 0.5285 - Validation Accuracy: 73.06%
# Epoch 45/100 - Loss: 0.5274 - Validation Accuracy: 73.16%
# Epoch 46/100 - Loss: 0.5268 - Validation Accuracy: 73.38%
# Epoch 47/100 - Loss: 0.5262 - Validation Accuracy: 73.12%
# Epoch 48/100 - Loss: 0.5260 - Validation Accuracy: 72.99%
# Epoch 49/100 - Loss: 0.5249 - Validation Accuracy: 73.17%
# Epoch 50/100 - Loss: 0.5242 - Validation Accuracy: 73.16%
# Epoch 51/100 - Loss: 0.5246 - Validation Accuracy: 73.37%
# Epoch 52/100 - Loss: 0.5232 - Validation Accuracy: 73.12%
# Epoch 53/100 - Loss: 0.5227 - Validation Accuracy: 72.65%
# Epoch 54/100 - Loss: 0.5211 - Validation Accuracy: 72.74%
# Epoch 55/100 - Loss: 0.5200 - Validation Accuracy: 72.88%
# Epoch 56/100 - Loss: 0.5193 - Validation Accuracy: 73.01%
# Epoch 57/100 - Loss: 0.5195 - Validation Accuracy: 72.77%
# Epoch 58/100 - Loss: 0.5192 - Validation Accuracy: 72.88%
# Epoch 59/100 - Loss: 0.5186 - Validation Accuracy: 72.83%
# Epoch 60/100 - Loss: 0.5167 - Validation Accuracy: 72.87%
# Epoch 61/100 - Loss: 0.5158 - Validation Accuracy: 72.94%
# Epoch 62/100 - Loss: 0.5156 - Validation Accuracy: 72.68%
# Epoch 63/100 - Loss: 0.5137 - Validation Accuracy: 72.70%
# Epoch 64/100 - Loss: 0.5136 - Validation Accuracy: 72.78%
# Epoch 65/100 - Loss: 0.5131 - Validation Accuracy: 72.60%
# Epoch 66/100 - Loss: 0.5115 - Validation Accuracy: 72.62%
# Epoch 67/100 - Loss: 0.5116 - Validation Accuracy: 72.88%
# Epoch 68/100 - Loss: 0.5095 - Validation Accuracy: 72.52%
# Epoch 69/100 - Loss: 0.5084 - Validation Accuracy: 72.58%
# Epoch 70/100 - Loss: 0.5085 - Validation Accuracy: 72.94%
# Epoch 71/100 - Loss: 0.5071 - Validation Accuracy: 72.46%
# Epoch 72/100 - Loss: 0.5060 - Validation Accuracy: 72.71%
# Epoch 73/100 - Loss: 0.5037 - Validation Accuracy: 72.75%
# Epoch 74/100 - Loss: 0.5044 - Validation Accuracy: 72.42%
# Epoch 75/100 - Loss: 0.5033 - Validation Accuracy: 72.93%
# Epoch 76/100 - Loss: 0.5031 - Validation Accuracy: 72.59%
# Epoch 77/100 - Loss: 0.5009 - Validation Accuracy: 72.45%
# Epoch 78/100 - Loss: 0.5007 - Validation Accuracy: 72.45%
# Epoch 79/100 - Loss: 0.4998 - Validation Accuracy: 72.45%
# Epoch 80/100 - Loss: 0.4969 - Validation Accuracy: 72.07%
# Epoch 81/100 - Loss: 0.4977 - Validation Accuracy: 72.68%
# Epoch 82/100 - Loss: 0.4962 - Validation Accuracy: 72.37%
# Epoch 83/100 - Loss: 0.4955 - Validation Accuracy: 72.29%
# Epoch 84/100 - Loss: 0.4944 - Validation Accuracy: 72.13%
# Epoch 85/100 - Loss: 0.4934 - Validation Accuracy: 71.93%
# Epoch 86/100 - Loss: 0.4926 - Validation Accuracy: 72.31%
# Epoch 87/100 - Loss: 0.4917 - Validation Accuracy: 72.03%
# Epoch 88/100 - Loss: 0.4895 - Validation Accuracy: 71.92%
# Epoch 89/100 - Loss: 0.4884 - Validation Accuracy: 72.19%
# Epoch 90/100 - Loss: 0.4870 - Validation Accuracy: 72.28%
# Epoch 91/100 - Loss: 0.4872 - Validation Accuracy: 72.12%
# Epoch 92/100 - Loss: 0.4861 - Validation Accuracy: 71.94%
# Epoch 93/100 - Loss: 0.4856 - Validation Accuracy: 72.37%
# Epoch 94/100 - Loss: 0.4842 - Validation Accuracy: 71.96%
# Epoch 95/100 - Loss: 0.4835 - Validation Accuracy: 72.11%
# Epoch 96/100 - Loss: 0.4814 - Validation Accuracy: 72.17%
# Epoch 97/100 - Loss: 0.4808 - Validation Accuracy: 71.96%
# Epoch 98/100 - Loss: 0.4796 - Validation Accuracy: 71.84%
# Epoch 99/100 - Loss: 0.4800 - Validation Accuracy: 71.43%
# Epoch 100/100 - Loss: 0.4758 - Validation Accuracy: 72.14%
# Saved model file: best_model_epoch100_fold4_ValAcc0.736.pth
# Test Fold 4: Test Accuracy: 71.78%, F1 Score: 0.707, Precision: 0.735, Recall: 0.680, AUC: 0.773
# --- Fold 5/5 ---
# Epoch 1/100 - Loss: 0.5658 - Validation Accuracy: 73.38%
# Epoch 2/100 - Loss: 0.5478 - Validation Accuracy: 73.38%
# Epoch 3/100 - Loss: 0.5454 - Validation Accuracy: 73.61%
# Epoch 4/100 - Loss: 0.5434 - Validation Accuracy: 73.35%
# Epoch 5/100 - Loss: 0.5429 - Validation Accuracy: 73.51%
# Epoch 6/100 - Loss: 0.5429 - Validation Accuracy: 73.87%
# Epoch 7/100 - Loss: 0.5414 - Validation Accuracy: 73.83%
# Epoch 8/100 - Loss: 0.5410 - Validation Accuracy: 73.80%
# Epoch 9/100 - Loss: 0.5406 - Validation Accuracy: 73.79%
# Epoch 10/100 - Loss: 0.5408 - Validation Accuracy: 73.19%
# Epoch 11/100 - Loss: 0.5397 - Validation Accuracy: 73.63%
# Epoch 12/100 - Loss: 0.5396 - Validation Accuracy: 73.58%
# Epoch 13/100 - Loss: 0.5397 - Validation Accuracy: 73.77%
# Epoch 14/100 - Loss: 0.5394 - Validation Accuracy: 73.54%
# Epoch 15/100 - Loss: 0.5389 - Validation Accuracy: 73.73%
# Epoch 16/100 - Loss: 0.5381 - Validation Accuracy: 73.12%
# Epoch 17/100 - Loss: 0.5385 - Validation Accuracy: 73.68%
# Epoch 18/100 - Loss: 0.5378 - Validation Accuracy: 73.62%
# Epoch 19/100 - Loss: 0.5375 - Validation Accuracy: 73.66%
# Epoch 20/100 - Loss: 0.5375 - Validation Accuracy: 73.67%
# Epoch 21/100 - Loss: 0.5378 - Validation Accuracy: 73.85%
# Epoch 22/100 - Loss: 0.5377 - Validation Accuracy: 73.85%
# Epoch 23/100 - Loss: 0.5364 - Validation Accuracy: 73.89%
# Epoch 24/100 - Loss: 0.5365 - Validation Accuracy: 73.68%
# Epoch 25/100 - Loss: 0.5365 - Validation Accuracy: 73.59%
# Epoch 26/100 - Loss: 0.5358 - Validation Accuracy: 73.69%
# Epoch 27/100 - Loss: 0.5360 - Validation Accuracy: 73.85%
# Epoch 28/100 - Loss: 0.5353 - Validation Accuracy: 73.62%
# Epoch 29/100 - Loss: 0.5357 - Validation Accuracy: 73.67%
# Epoch 30/100 - Loss: 0.5347 - Validation Accuracy: 73.62%
# Epoch 31/100 - Loss: 0.5340 - Validation Accuracy: 73.39%
# Epoch 32/100 - Loss: 0.5340 - Validation Accuracy: 73.61%
# Epoch 33/100 - Loss: 0.5338 - Validation Accuracy: 73.71%
# Epoch 34/100 - Loss: 0.5328 - Validation Accuracy: 73.71%
# Epoch 35/100 - Loss: 0.5320 - Validation Accuracy: 73.63%
# Epoch 36/100 - Loss: 0.5326 - Validation Accuracy: 73.82%
# Epoch 37/100 - Loss: 0.5321 - Validation Accuracy: 73.48%
# Epoch 38/100 - Loss: 0.5317 - Validation Accuracy: 73.65%
# Epoch 39/100 - Loss: 0.5309 - Validation Accuracy: 73.59%
# Epoch 40/100 - Loss: 0.5303 - Validation Accuracy: 73.39%
# Epoch 41/100 - Loss: 0.5292 - Validation Accuracy: 73.51%
# Epoch 42/100 - Loss: 0.5289 - Validation Accuracy: 73.57%
# Epoch 43/100 - Loss: 0.5280 - Validation Accuracy: 73.49%
# Epoch 44/100 - Loss: 0.5280 - Validation Accuracy: 73.67%
# Epoch 45/100 - Loss: 0.5267 - Validation Accuracy: 73.43%
# Epoch 46/100 - Loss: 0.5263 - Validation Accuracy: 73.26%
# Epoch 47/100 - Loss: 0.5251 - Validation Accuracy: 73.12%
# Epoch 48/100 - Loss: 0.5241 - Validation Accuracy: 73.25%
# Epoch 49/100 - Loss: 0.5246 - Validation Accuracy: 73.18%
# Epoch 50/100 - Loss: 0.5229 - Validation Accuracy: 73.00%
# Epoch 51/100 - Loss: 0.5221 - Validation Accuracy: 73.21%
# Epoch 52/100 - Loss: 0.5227 - Validation Accuracy: 73.38%
# Epoch 53/100 - Loss: 0.5214 - Validation Accuracy: 73.21%
# Epoch 54/100 - Loss: 0.5193 - Validation Accuracy: 73.19%
# Epoch 55/100 - Loss: 0.5189 - Validation Accuracy: 72.93%
# Epoch 56/100 - Loss: 0.5182 - Validation Accuracy: 72.97%
# Epoch 57/100 - Loss: 0.5178 - Validation Accuracy: 72.97%
# Epoch 58/100 - Loss: 0.5160 - Validation Accuracy: 73.14%
# Epoch 59/100 - Loss: 0.5157 - Validation Accuracy: 72.85%
# Epoch 60/100 - Loss: 0.5140 - Validation Accuracy: 73.07%
# Epoch 61/100 - Loss: 0.5141 - Validation Accuracy: 72.62%
# Epoch 62/100 - Loss: 0.5140 - Validation Accuracy: 72.94%
# Epoch 63/100 - Loss: 0.5112 - Validation Accuracy: 72.75%
# Epoch 64/100 - Loss: 0.5109 - Validation Accuracy: 72.69%
# Epoch 65/100 - Loss: 0.5103 - Validation Accuracy: 72.92%
# Epoch 66/100 - Loss: 0.5086 - Validation Accuracy: 72.86%
# Epoch 67/100 - Loss: 0.5073 - Validation Accuracy: 72.73%
# Epoch 68/100 - Loss: 0.5070 - Validation Accuracy: 72.49%
# Epoch 69/100 - Loss: 0.5064 - Validation Accuracy: 72.52%
# Epoch 70/100 - Loss: 0.5056 - Validation Accuracy: 72.51%
# Epoch 71/100 - Loss: 0.5036 - Validation Accuracy: 72.22%
# Epoch 72/100 - Loss: 0.5024 - Validation Accuracy: 72.76%
# Epoch 73/100 - Loss: 0.5016 - Validation Accuracy: 72.54%
# Epoch 74/100 - Loss: 0.5003 - Validation Accuracy: 72.34%
# Epoch 75/100 - Loss: 0.4985 - Validation Accuracy: 72.36%
# Epoch 76/100 - Loss: 0.4976 - Validation Accuracy: 72.58%
# Epoch 77/100 - Loss: 0.4982 - Validation Accuracy: 72.29%
# Epoch 78/100 - Loss: 0.4953 - Validation Accuracy: 72.24%
# Epoch 79/100 - Loss: 0.4946 - Validation Accuracy: 72.45%
# Epoch 80/100 - Loss: 0.4944 - Validation Accuracy: 72.03%
# Epoch 81/100 - Loss: 0.4932 - Validation Accuracy: 72.53%
# Epoch 82/100 - Loss: 0.4928 - Validation Accuracy: 72.62%
# Epoch 83/100 - Loss: 0.4915 - Validation Accuracy: 72.39%
# Epoch 84/100 - Loss: 0.4912 - Validation Accuracy: 72.59%
# Epoch 85/100 - Loss: 0.4893 - Validation Accuracy: 72.22%
# Epoch 86/100 - Loss: 0.4879 - Validation Accuracy: 72.20%
# Epoch 87/100 - Loss: 0.4871 - Validation Accuracy: 72.01%
# Epoch 88/100 - Loss: 0.4868 - Validation Accuracy: 72.13%
# Epoch 89/100 - Loss: 0.4853 - Validation Accuracy: 72.30%
# Epoch 90/100 - Loss: 0.4849 - Validation Accuracy: 71.95%
# Epoch 91/100 - Loss: 0.4842 - Validation Accuracy: 71.86%
# Epoch 92/100 - Loss: 0.4832 - Validation Accuracy: 72.87%
# Epoch 93/100 - Loss: 0.4803 - Validation Accuracy: 71.31%
# Epoch 94/100 - Loss: 0.4785 - Validation Accuracy: 72.03%
# Epoch 95/100 - Loss: 0.4773 - Validation Accuracy: 71.67%
# Epoch 96/100 - Loss: 0.4756 - Validation Accuracy: 72.19%
# Epoch 97/100 - Loss: 0.4769 - Validation Accuracy: 71.68%
# Epoch 98/100 - Loss: 0.4756 - Validation Accuracy: 71.62%
# Epoch 99/100 - Loss: 0.4732 - Validation Accuracy: 71.60%
# Epoch 100/100 - Loss: 0.4738 - Validation Accuracy: 71.43%
# Saved model file: best_model_epoch100_fold5_ValAcc0.739.pth
# Test Fold 5: Test Accuracy: 71.19%, F1 Score: 0.700, Precision: 0.729, Recall: 0.673, AUC: 0.769
# Average test results: Test Accuracy: 71.46%, F1 Score: 0.702, AUC: 0.771, Recall: 0.674
